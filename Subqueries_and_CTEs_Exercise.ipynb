# %% [markdown]
# #  Subqueries and Common Table Expressions (CTEs)
#
# In this exercise, we will apply **subqueries** and **CTEs** in different parts of a query and for different use cases.
# Ensure that you have downloaded the database file **`Northwind.db`**.
#
#
#
# ##  Learning Objectives
# By the end of this exercise, you should be able to:
#
# - Use **CTEs** to simplify subqueries.
# - Understand **when to use subqueries** vs. **CTEs** by comparing their performance and readability.
#
#
#
# ##  Connect to the Database
# First, let's load our sample database:

# %%
# %load_ext sql

# %%
# %sql sqlite:///Northwind.db

# %% [markdown]
# ###  Exercise 1 — Retrieve UK Customer Orders
#
# Retrieve **product details** from products that have been ordered by **customers from the UK**.

# %%
# %%sql
#
# -- Retrieve products ordered by UK customers
# SELECT
#     p.ProductName,
#     p.QuantityPerUnit,
#     p.UnitPrice,
#     c.CustomerID,
#     c.Country
# FROM Orders o
# JOIN Customers c ON o.CustomerID = c.CustomerID
# JOIN OrderDetails od ON o.OrderID = od.OrderID
# JOIN Products p ON od.ProductID = p.ProductID
# WHERE c.Country = 'UK';
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Aniseed Syrup', '12 - 550 ml bottles', 10, 'BSBEV', 'UK'),
#  ('Wimmers gute Semmelkndel', '20 bags x 4 pieces', 33.25, 'BSBEV', 'UK'),
#  ('Sasquatch Ale', '24 - 12 oz bottles', 14, 'ISLAT', 'UK'),
#  ('Outback Lager', '24 - 355 ml bottles', 15, 'ISLAT', 'UK'),
#  ("Jack's New England Clam Chowder", '12 - 12 oz cans', 9.65, 'ISLAT', 'UK'),
#  ('Lakkalikri', '500 ml', 18, 'ISLAT', 'UK'),
#  ('Steeleye Stout', '24 - 12 oz bottles', 18, 'ISLAT', 'UK'),
#  ('Guaran Fantstica', '12 - 355 ml cans', 4.5, 'AROUT', 'UK'),
#  ('Ravioli Angelo', '24 - 250 g pkgs.', 19.5, 'AROUT', 'UK'),
#  ('Pavlova', '32 - 500 g boxes', 17.45, 'SEVES', 'UK'),
#  ('Gorgonzola Telino', '12 - 100 g pkgs', 12.5, 'SEVES', 'UK'),
#  ('Camembert Pierrot', '15 - 300 g rounds', 34, 'SEVES', 'UK'),
#  ('Gudbrandsdalsost', '10 kg pkg.', 36, 'EASTC', 'UK'),
#  ('Flotemysost', '10 - 500 g pkgs.', 21.5, 'EASTC', 'UK'),
#  ('Rssle Sauerkraut', '25 - 825 g cans', 45.6, 'SEVES', 'UK'),
#  ('Chartreuse verte', '750 cc per bottle', 18, 'SEVES', 'UK'),
#  ('Konbu', '2 kg box', 6, 'AROUT', 'UK'),
#  ('Valkoinen suklaa', '12 - 100 g bars', 16.25, 'AROUT', 'UK'),
#  ('Gnocchi di nonna Alice', '24 - 250 g pkgs.', 38, 'AROUT', 'UK'),
#  ('Rogede sild', '1k pkg.', 9.5, 'SEVES', 'UK'),
#  ('Filo Mix', '16 - 2 kg boxes', 7, 'SEVES', 'UK'),
#  ('Perth Pasties', '48 pieces', 32.8, 'SEVES', 'UK'),
#  ('Thringer Rostbratwurst', '50 bags x 30 sausgs.', 123.79, 'EASTC', 'UK'),
#  ('Steeleye Stout', '24 - 12 oz bottles', 18, 'EASTC', 'UK'),
#  ('Maxilaku', '24 - 50 g pkgs.', 20, 'EASTC', 'UK'),
#  ('Chang', '24 - 12 oz bottles', 19, 'CONSH', 'UK'),
#  ("Gustaf's Knckebrd", '24 - 500 g pkgs.', 21, 'CONSH', 'UK'),
#  ('Mozzarella di Giovanni', '24 - 200 g pkgs.', 34.8, 'CONSH', 'UK'),
#  ('Chocolade', '10 pkgs.', 12.75, 'AROUT', 'UK'),
#  ('Outback Lager', '24 - 355 ml bottles', 15, 'AROUT', 'UK'),
#  ('Konbu', '2 kg box', 6, 'CONSH', 'UK'),
#  ('Tunnbrd', '12 - 250 g pkgs.', 9, 'CONSH', 'UK'),
#  ("Uncle Bob's Organic Dried Pears", '12 - 1 lb pkgs.', 30, 'BSBEV', 'UK'),
#  ('Gnocchi di nonna Alice', '24 - 250 g pkgs.', 38, 'BSBEV', 'UK'),
#  ('Guaran Fantstica', '12 - 355 ml cans', 4.5, 'SEVES', 'UK'),
#  ('Manjimup Dried Apples', '50 - 300 g pkgs.', 53, 'SEVES', 'UK'),
#  ('Geitost', '500 g', 2.5, 'ISLAT', 'UK'),
#  ('Flotemysost', '10 - 500 g pkgs.', 21.5, 'ISLAT', 'UK'),
#  ("Sir Rodney's Scones", '24 pkgs. x 4 pieces', 10, 'BSBEV', 'UK'),
#  ('Boston Crab Meat', '24 - 4 oz tins', 18.4, 'BSBEV', 'UK'),
#  ('Manjimup Dried Apples', '50 - 300 g pkgs.', 53, 'BSBEV', 'UK'),
#  ('Filo Mix', '16 - 2 kg boxes', 7, 'NORTS', 'UK'),
#  ('Raclette Courdavault', '5 kg pkg.', 55, 'NORTS', 'UK'),
#  ('Outback Lager', '24 - 355 ml bottles', 15, 'NORTS', 'UK'),
#  ('Alice Mutton', '20 - 1 kg tins', 39, 'SEVES', 'UK'),
#  ("Sir Rodney's Marmalade", '30 gift boxes', 81, 'SEVES', 'UK'),
#  ('Gravad lax', '12 - 500 g pkgs.', 26, 'SEVES', 'UK'),
#  ("Jack's New England Clam Chowder", '12 - 12 oz cans', 9.65, 'SEVES', 'UK'),
#  ('Nord-Ost Matjeshering', '10 - 200 g glasses', 25.89, 'EASTC', 'UK'),
#  ('Louisiana Hot Spiced Okra', '24 - 8 oz jars', 17, 'EASTC', 'UK'),
#  ('Outback Lager', '24 - 355 ml bottles', 15, 'BSBEV', 'UK'),
#  ('Mozzarella di Giovanni', '24 - 200 g pkgs.', 34.8, 'BSBEV', 'UK'),
#  ('Konbu', '2 kg box', 6, 'BSBEV', 'UK'),
#  ("Sir Rodney's Scones", '24 pkgs. x 4 pieces', 10, 'BSBEV', 'UK'),
#  ('Geitost', '500 g', 2.5, 'BSBEV', 'UK'),
#  ('Maxilaku', '24 - 50 g pkgs.', 20, 'BSBEV', 'UK'),
#  ('Mascarpone Fabioli', '24 - 200 g pkgs.', 32, 'SEVES', 'UK'),
#  ('Inlagd Sill', '24 - 250 g  jars', 19, 'SEVES', 'UK'),
#  ('Zaanse koeken', '10 - 4 oz boxes', 9.5, 'AROUT', 'UK'),
#  ('Manjimup Dried Apples', '50 - 300 g pkgs.', 53, 'AROUT', 'UK'),
#  ('Filo Mix', '16 - 2 kg boxes', 7, 'AROUT', 'UK'),
#  ('Perth Pasties', '48 pieces', 32.8, 'AROUT', 'UK'),
#  ('Rd Kaviar', '24 - 150 g jars', 15, 'AROUT', 'UK'),
#  ('Steeleye Stout', '24 - 12 oz bottles', 18, 'BSBEV', 'UK'),
#  ('Ravioli Angelo', '24 - 250 g pkgs.', 19.5, 'BSBEV', 'UK'),
#  ('Tarte au sucre', '48 pies', 49.3, 'BSBEV', 'UK'),
#  ('Teatime Chocolate Biscuits', '10 boxes x 12 pieces', 9.2, 'ISLAT', 'UK'),
#  ('Tunnbrd', '12 - 250 g pkgs.', 9, 'ISLAT', 'UK'),
#  ('Outback Lager', '24 - 355 ml bottles', 15, 'ISLAT', 'UK'),
#  ('Flotemysost', '10 - 500 g pkgs.', 21.5, 'ISLAT', 'UK'),
#  ('Tunnbrd', '12 - 250 g pkgs.', 9, 'ISLAT', 'UK'),
#  ('Pt chinois', '24 boxes x 2 pies', 24, 'AROUT', 'UK'),
#  ('Ravioli Angelo', '24 - 250 g pkgs.', 19.5, 'AROUT', 'UK'),
#  ('Outback Lager', '24 - 355 ml bottles', 15, 'AROUT', 'UK'),
#  ("Chef Anton's Cajun Seasoning", '48 - 6 oz jars', 22, 'EASTC', 'UK'),
#  ('Queso Cabrales', '1 kg pkg.', 21, 'EASTC', 'UK'),
#  ('Chang', '24 - 12 oz bottles', 19, 'AROUT', 'UK'),
#  ('Spegesild', '4 - 450 g glasses', 12, 'AROUT', 'UK'),
#  ('Gnocchi di nonna Alice', '24 - 250 g pkgs.', 38, 'ISLAT', 'UK'),
#  ('Raclette Courdavault', '5 kg pkg.', 55, 'ISLAT', 'UK'),
#  ('Lakkalikri', '500 ml', 18, 'ISLAT', 'UK'),
#  ('Chai', '10 boxes x 20 bags', 18, 'NORTS', 'UK'),
#  ('Gudbrandsdalsost', '10 kg pkg.', 36, 'NORTS', 'UK'),
#  ("Gustaf's Knckebrd", '24 - 500 g pkgs.', 21, 'AROUT', 'UK'),
#  ('Gorgonzola Telino', '12 - 100 g pkgs', 12.5, 'AROUT', 'UK'),
#  ('Camembert Pierrot', '15 - 300 g rounds', 34, 'AROUT', 'UK'),
#  ('Flotemysost', '10 - 500 g pkgs.', 21.5, 'AROUT', 'UK'),
#  ("Jack's New England Clam Chowder", '12 - 12 oz cans', 9.65, 'AROUT', 'UK'),
#  ('Filo Mix', '16 - 2 kg boxes', 7, 'AROUT', 'UK'),
#  ('Tarte au sucre', '48 pies', 49.3, 'ISLAT', 'UK'),
#  ('Mozzarella di Giovanni', '24 - 200 g pkgs.', 34.8, 'ISLAT', 'UK'),
#  ('Queso Cabrales', '1 kg pkg.', 21, 'SEVES', 'UK'),
#  ('Manjimup Dried Apples', '50 - 300 g pkgs.', 53, 'SEVES', 'UK'),
#  ('Tourtire', '16 pies', 7.45, 'SEVES', 'UK'),
#  ('Ikura', '12 - 200 ml jars', 31, 'SEVES', 'UK'),
#  ('Rssle Sauerkraut', '25 - 825 g cans', 45.6, 'SEVES', 'UK'),
#  ('Maxilaku', '24 - 50 g pkgs.', 20, 'SEVES', 'UK'),
#  ('Chang', '24 - 12 oz bottles', 19, 'ISLAT', 'UK'),
#  ('Northwoods Cranberry Sauce', '12 - 12 oz jars', 40, 'ISLAT', 'UK'),
#  ('Konbu', '2 kg box', 6, 'ISLAT', 'UK'),
#  ('Camembert Pierrot', '15 - 300 g rounds', 34, 'ISLAT', 'UK'),
#  ("Chef Anton's Gumbo Mix", '36 boxes', 21.35, 'CONSH', 'UK'),
#  ('Mishi Kobe Niku', '18 - 500 g pkgs.', 97, 'CONSH', 'UK'),
#  ('Steeleye Stout', '24 - 12 oz bottles', 18, 'AROUT', 'UK'),
#  ('Laughing Lumberjack Lager', '24 - 12 oz bottles', 14, 'AROUT', 'UK'),
#  ('Chai', '10 boxes x 20 bags', 18, 'SEVES', 'UK'),
#  ('Queso Cabrales', '1 kg pkg.', 21, 'SEVES', 'UK'),
#  ('Tunnbrd', '12 - 250 g pkgs.', 9, 'SEVES', 'UK'),
#  ('Scottish Longbreads', '10 boxes x 8 pieces', 12.5, 'SEVES', 'UK'),
#  ('Valkoinen suklaa', '12 - 100 g bars', 16.25, 'AROUT', 'UK'),
#  ('Perth Pasties', '48 pieces', 32.8, 'ISLAT', 'UK'),
#  ("Sirop d'rable", '24 - 500 ml bottles', 28.5, 'ISLAT', 'UK'),
#  ('Konbu', '2 kg box', 6, 'BSBEV', 'UK'),
#  ("Gustaf's Knckebrd", '24 - 500 g pkgs.', 21, 'BSBEV', 'UK'),
#  ('Spegesild', '4 - 450 g glasses', 12, 'BSBEV', 'UK'),
#  ('Raclette Courdavault', '5 kg pkg.', 55, 'BSBEV', 'UK'),
#  ("Sir Rodney's Marmalade", '30 gift boxes', 81, 'AROUT', 'UK'),
#  ('Gorgonzola Telino', '12 - 100 g pkgs', 12.5, 'AROUT', 'UK'),
#  ("Uncle Bob's Organic Dried Pears", '12 - 1 lb pkgs.', 30, 'EASTC', 'UK'),
#  ('Ipoh Coffee', '16 - 500 g tins', 46, 'EASTC', 'UK'),
#  ('Mozzarella di Giovanni', '24 - 200 g pkgs.', 34.8, 'EASTC', 'UK'),
#  ('Gorgonzola Telino', '12 - 100 g pkgs', 12.5, 'AROUT', 'UK'),
#  ('Inlagd Sill', '24 - 250 g  jars', 19, 'AROUT', 'UK'),
#  ("Uncle Bob's Organic Dried Pears", '12 - 1 lb pkgs.', 30, 'BSBEV', 'UK'),
#  ('Ipoh Coffee', '16 - 500 g tins', 46, 'BSBEV', 'UK'),
#  ('Gumbr Gummibrchen', '100 - 250 g bags', 31.23, 'EASTC', 'UK'),
#  ('Geitost', '500 g', 2.5, 'EASTC', 'UK'),
#  ('Louisiana Fiery Hot Pepper Sauce', '32 - 8 oz bottles', 21.05, 'EASTC', 'UK'),
#  ('Flotemysost', '10 - 500 g pkgs.', 21.5, 'EASTC', 'UK'),
#  ('Chai', '10 boxes x 20 bags', 18, 'EASTC', 'UK'),
#  ("Chef Anton's Gumbo Mix", '36 boxes', 21.35, 'EASTC', 'UK'),
#  ("Uncle Bob's Organic Dried Pears", '12 - 1 lb pkgs.', 30, 'EASTC', 'UK'),
#  ('Pt chinois', '24 boxes x 2 pies', 24, 'EASTC', 'UK'),
#  ('Camembert Pierrot', '15 - 300 g rounds', 34, 'EASTC', 'UK'),
#  ('Outback Lager', '24 - 355 ml bottles', 15, 'NORTS', 'UK')]

# %% [markdown]
# ###  Exercise 2 — Customers with Orders Above Average Value
#
# Find the **names of customers** who have placed orders worth **more than the average order value**.

# %%
# %%sql
#
# -- Find customers whose total order value is above the average
# SELECT
#     c.CustomerID,
#     c.CompanyName,
#     SUM(od.UnitPrice * od.Quantity) AS TotalOrderValue
# FROM Orders o
# JOIN Customers c ON o.CustomerID = c.CustomerID
# JOIN OrderDetails od ON o.OrderID = od.OrderID
# GROUP BY c.CustomerID, c.CompanyName
# HAVING TotalOrderValue > (
#     SELECT AVG(CustomerTotal)
#     FROM (
#         SELECT SUM(od2.UnitPrice * od2.Quantity) AS CustomerTotal
#         FROM Orders o2
#         JOIN OrderDetails od2 ON o2.OrderID = od2.OrderID
#         GROUP BY o2.CustomerID
#     )
# );
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('BERGS', 'Berglunds snabbkp', 26968.149999999998),
#  ('BLONP', 'Blondesddsl pre et fils', 19088.0),
#  ('BONAP', "Bon app'", 23850.95),
#  ('BOTTM', 'Bottom-Dollar Markets', 22607.7),
#  ('ERNSH', 'Ernst Handel', 113236.68),
#  ('FOLKO', 'Folk och f HB', 32555.55),
#  ('FRANK', 'Frankenversand', 28722.71),
#  ('GREAL', 'Great Lakes Food Market', 19711.13),
#  ('HANAR', 'Hanari Carnes', 34101.15),
#  ('HILAA', 'HILARION-Abastos', 23611.58),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 57317.39),
#  ('KOENE', 'Kniglich Essen', 31745.75),
#  ('LEHMS', 'Lehmanns Marktstand', 21282.02),
#  ('LILAS', 'LILA-Supermercado', 17825.06),
#  ('LINOD', 'LINO-Delicateses', 17889.55),
#  ('MEREP', 'Mre Paillarde', 32203.9),
#  ('OLDWO', 'Old World Delicatessen', 16325.15),
#  ('PICCO', 'Piccolo und mehr', 26259.95),
#  ('QUEEN', 'Queen Cozinha', 30226.1),
#  ('QUICK', 'QUICK-Stop', 117483.39),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 52245.9),
#  ('RICSU', 'Richter Supermarkt', 20033.2),
#  ('SAVEA', 'Save-a-lot Markets', 115673.39),
#  ('SEVES', 'Seven Seas Imports', 17172.05),
#  ('SIMOB', 'Simons bistro', 18138.45),
#  ('SUPRD', 'Suprmes dlices', 24704.4),
#  ('VAFFE', 'Vaffeljernet', 16643.8),
#  ('WARTH', 'Wartian Herkku', 16617.1),
#  ('WHITC', 'White Clover Markets', 29073.45)]

# %% [markdown]
# ###  Exercise 3 — Most Ordered Product by Each Customer (CTE)
#
# Use a **CTE** to find the **most ordered product** by each customer.

# %%
# %%sql
#
# -- Use a CTE to find each customer's most ordered product
# WITH CustomerOrders AS (
#     SELECT
#         c.CustomerID,
#         c.CompanyName,
#         p.ProductName,
#         SUM(od.Quantity) AS TotalQuantity,
#         RANK() OVER (PARTITION BY c.CustomerID ORDER BY SUM(od.Quantity) DESC) AS RankOrder
#     FROM Customers c
#     JOIN Orders o ON c.CustomerID = o.CustomerID
#     JOIN OrderDetails od ON o.OrderID = od.OrderID
#     JOIN Products p ON od.ProductID = p.ProductID
#     GROUP BY c.CustomerID, c.CompanyName, p.ProductName
# )
# SELECT
#     CustomerID,
#     CompanyName,
#     ProductName,
#     TotalQuantity
# FROM CustomerOrders
# WHERE RankOrder = 1;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Escargots de Bourgogne', 40),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Camembert Pierrot', 10),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Konbu', 10),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Mascarpone Fabioli', 10),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Mozzarella di Giovanni', 10),
#  ('ANTON', 'Antonio Moreno Taquera', 'Queso Cabrales', 74),
#  ('AROUT', 'Around the Horn', 'Gorgonzola Telino', 115),
#  ('BERGS', 'Berglunds snabbkp', 'Boston Crab Meat', 75),
#  ('BLAUS', 'Blauer See Delikatessen', "Sir Rodney's Scones", 23),
#  ('BLONP', 'Blondesddsl pre et fils', 'Gorgonzola Telino', 85),
#  ('BOLID', 'Blido Comidas preparadas', 'Rhnbru Klosterbier', 50),
#  ('BONAP', "Bon app'", "Grandma's Boysenberry Spread", 70),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Tarte au sucre', 101),
#  ('BSBEV', "B's Beverages", "Uncle Bob's Organic Dried Pears", 34),
#  ('CACTU', 'Cactus Comidas para llevar', 'Laughing Lumberjack Lager', 20),
#  ('CACTU', 'Cactus Comidas para llevar', 'Rhnbru Klosterbier', 20),
#  ('CACTU', 'Cactus Comidas para llevar', 'Sasquatch Ale', 20),
#  ('CENTC', 'Centro comercial Moctezuma', "Sir Rodney's Scones", 10),
#  ('CHOPS', 'Chop-suey Chinese', 'Gnocchi di nonna Alice', 72),
#  ('COMMI', 'Comrcio Mineiro', 'Gnocchi di nonna Alice', 30),
#  ('CONSH', 'Consolidated Holdings', "Chef Anton's Gumbo Mix", 30),
#  ('DRACD', 'Drachenblut Delikatessen', 'Raclette Courdavault', 30),
#  ('DUMON', 'Du monde entier', 'Alice Mutton', 15),
#  ('EASTC', 'Eastern Connection', "Uncle Bob's Organic Dried Pears", 100),
#  ('ERNSH', 'Ernst Handel', 'Guaran Fantstica', 248),
#  ('FAMIA', 'Familia Arquibaldo', 'Rhnbru Klosterbier', 56),
#  ('FOLIG', 'Folies gourmandes', 'Carnarvon Tigers', 80),
#  ('FOLKO', 'Folk och f HB', 'Manjimup Dried Apples', 88),
#  ('FRANK', 'Frankenversand', 'Flotemysost', 120),
#  ('FRANR', 'France restauration', 'Lakkalikri', 20),
#  ('FRANS', 'Franchi S.p.A.', 'Manjimup Dried Apples', 10),
#  ('FRANS', 'Franchi S.p.A.', 'Original Frankfurter grne Soe', 10),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Gula Malacca', 55),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Louisiana Fiery Hot Pepper Sauce', 55),
#  ('GALED', 'Galera del gastrnomo', 'Wimmers gute Semmelkndel', 7),
#  ('GODOS', 'Godos Cocina Tpica', 'Louisiana Fiery Hot Pepper Sauce', 51),
#  ('GOURL', 'Gourmet Lanchonetes', 'Northwoods Cranberry Sauce', 40),
#  ('GOURL', 'Gourmet Lanchonetes', 'Singaporean Hokkien Fried Mee', 40),
#  ('GREAL', 'Great Lakes Food Market', 'Cte de Blaye', 45),
#  ('GROSR', 'GROSELLA-Restaurante', 'Ikura', 10),
#  ('GROSR', 'GROSELLA-Restaurante', 'Rhnbru Klosterbier', 10),
#  ('GROSR', 'GROSELLA-Restaurante', 'Thringer Rostbratwurst', 10),
#  ('HANAR', 'Hanari Carnes', 'Louisiana Fiery Hot Pepper Sauce', 72),
#  ('HILAA', 'HILARION-Abastos', 'Rhnbru Klosterbier', 106),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Rd Kaviar', 30),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Thringer Rostbratwurst', 150),
#  ('ISLAT', 'Island Trading', 'Outback Lager', 50),
#  ('KOENE', 'Kniglich Essen', 'Raclette Courdavault', 85),
#  ('LACOR', "La corne d'abondance", 'Lakkalikri', 20),
#  ('LAMAI', "La maison d'Asie", 'Inlagd Sill', 47),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', "Jack's New England Clam Chowder", 20),
#  ('LAZYK', 'Lazy K Kountry Store', 'Boston Crab Meat', 10),
#  ('LAZYK', 'Lazy K Kountry Store', 'Queso Cabrales', 10),
#  ('LEHMS', 'Lehmanns Marktstand', 'Chai', 80),
#  ('LEHMS', 'Lehmanns Marktstand', 'Wimmers gute Semmelkndel', 80),
#  ('LETSS', "Let's Stop N Shop", "Sir Rodney's Scones", 40),
#  ('LETSS', "Let's Stop N Shop", 'Tourtire', 40),
#  ('LILAS', 'LILA-Supermercado', 'Tunnbrd', 70),
#  ('LINOD', 'LINO-Delicateses', 'Outback Lager', 90),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Chai', 20),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Manjimup Dried Apples', 20),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Queso Manchego La Pastora', 20),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Guaran Fantstica', 40),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', "Gustaf's Knckebrd", 40),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Laughing Lumberjack Lager', 40),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Singaporean Hokkien Fried Mee', 40),
#  ('MAISD', 'Maison Dewey', 'Raclette Courdavault', 40),
#  ('MAISD', 'Maison Dewey', 'Schoggi Schokolade', 40),
#  ('MAISD', 'Maison Dewey', "Sir Rodney's Scones", 40),
#  ('MEREP', 'Mre Paillarde', 'Gnocchi di nonna Alice', 80),
#  ('MORGK', 'Morgenstern Gesundkost', 'Tarte au sucre', 32),
#  ('NORTS', 'North/South', 'Outback Lager', 9),
#  ('OCEAN', 'Ocano Atlntico Ltda.', 'Queso Cabrales', 30),
#  ('OLDWO', 'Old World Delicatessen', 'Pavlova', 120),
#  ('OTTIK', 'Ottilies Kseladen', "Uncle Bob's Organic Dried Pears", 55),
#  ('PERIC', 'Pericles Comidas clsicas', 'Laughing Lumberjack Lager', 30),
#  ('PICCO', 'Piccolo und mehr', 'Gudbrandsdalsost', 80),
#  ('PRINI', 'Princesa Isabel Vinhos', "Sir Rodney's Scones", 31),
#  ('QUEDE', 'Que Delcia', 'Steeleye Stout', 61),
#  ('QUEEN', 'Queen Cozinha', 'Camembert Pierrot', 85),
#  ('QUICK', 'QUICK-Stop', 'Camembert Pierrot', 243),
#  ('RANCH', 'Rancho grande', 'Boston Crab Meat', 20),
#  ('RANCH', 'Rancho grande', 'Ravioli Angelo', 20),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Tarte au sucre', 185),
#  ('REGGC', 'Reggiani Caseifici', 'Mozzarella di Giovanni', 40),
#  ('REGGC', 'Reggiani Caseifici', "Uncle Bob's Organic Dried Pears", 40),
#  ('RICAR', 'Ricardo Adocicados', 'Camembert Pierrot', 75),
#  ('RICSU', 'Richter Supermarkt', 'Perth Pasties', 70),
#  ('ROMEY', 'Romero y tomillo', 'Rogede sild', 20),
#  ('SANTG', 'Sant Gourmet', 'Guaran Fantstica', 23),
#  ('SAVEA', 'Save-a-lot Markets', 'Konbu', 248),
#  ('SEVES', 'Seven Seas Imports', 'Camembert Pierrot', 80),
#  ('SEVES', 'Seven Seas Imports', 'Guaran Fantstica', 80),
#  ('SIMOB', 'Simons bistro', 'Pt chinois', 60),
#  ('SPECD', 'Spcialits du monde', 'Rhnbru Klosterbier', 14),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Tourtire', 64),
#  ('SUPRD', 'Suprmes dlices', 'Singaporean Hokkien Fried Mee', 82),
#  ('THEBI', 'The Big Cheese', 'Cte de Blaye', 10),
#  ('THEBI', 'The Big Cheese', 'Pavlova', 10),
#  ('THEBI', 'The Big Cheese', 'Sasquatch Ale', 10),
#  ('THECR', 'The Cracker Box', 'Boston Crab Meat', 10),
#  ('THECR', 'The Cracker Box', 'Filo Mix', 10),
#  ('THECR', 'The Cracker Box', 'Gula Malacca', 10),
#  ('THECR', 'The Cracker Box', 'Rssle Sauerkraut', 10),
#  ('TOMSP', 'Toms Spezialitten', 'Manjimup Dried Apples', 40),
#  ('TOMSP', 'Toms Spezialitten', 'Maxilaku', 40),
#  ('TORTU', 'Tortuga Restaurante', 'Gula Malacca', 51),
#  ('TRADH', 'Tradio Hipermercados', 'Camembert Pierrot', 30),
#  ('TRADH', 'Tradio Hipermercados', 'Escargots de Bourgogne', 30),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Rhnbru Klosterbier', 20),
#  ('VAFFE', 'Vaffeljernet', 'Boston Crab Meat', 70),
#  ('VICTE', 'Victuailles en stock', 'Ikura', 40),
#  ('VICTE', 'Victuailles en stock', 'Mozzarella di Giovanni', 40),
#  ('VICTE', 'Victuailles en stock', 'Tarte au sucre', 40),
#  ('VINET', 'Vins et alcools Chevalier', 'Flotemysost', 20),
#  ('WANDK', 'Die Wandernde Kuh', 'Mascarpone Fabioli', 65),
#  ('WARTH', 'Wartian Herkku', 'Flotemysost', 100),
#  ('WELLI', 'Wellington Importadora', 'Chai', 41),
#  ('WHITC', 'White Clover Markets', 'Geitost', 95),
#  ('WILMK', 'Wilman Kala', 'Guaran Fantstica', 20),
#  ('WILMK', 'Wilman Kala', "Sir Rodney's Scones", 20),
#  ('WOLZA', 'Wolski  Zajazd', 'Gorgonzola Telino', 30),
#  ('WOLZA', 'Wolski  Zajazd', 'Rhnbru Klosterbier', 30)]

# %% [markdown]
# ###  Exercise 4 — Employees with Above-Average Reports (CTE)
#
# Using a **CTE**, list **employees** who have **more than the average number of direct reports**.

# %%
# %%sql
#
# -- Use a CTE to find employees who manage more than the average number of reports
# WITH EmployeeReports AS (
#     SELECT
#         e.EmployeeID,
#         e.FirstName || ' ' || e.LastName AS EmployeeName,
#         COUNT(sub.EmployeeID) AS NumReports
#     FROM Employees e
#     LEFT JOIN Employees sub ON e.EmployeeID = sub.ReportsTo
#     GROUP BY e.EmployeeID, e.FirstName, e.LastName
# ),
# AverageReports AS (
#     SELECT AVG(NumReports) AS AvgReports FROM EmployeeReports
# )
# SELECT
#     er.EmployeeID,
#     er.EmployeeName,
#     er.NumReports
# FROM EmployeeReports er, AverageReports ar
# WHERE er.NumReports > ar.AvgReports;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(2, 'Andrew Fuller', 5), (5, 'Steven Buchanan', 3)]
