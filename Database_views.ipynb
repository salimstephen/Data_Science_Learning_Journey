# %% [markdown]
# ##  Database Views
#
# ###  Learning Objectives
# By the end of this lesson, you should be able to:
# - Understand what a **view** is and why it’s needed.
# - Learn how to **create a view** in MySQL.
# - **Join tables** using views.
# - **Impute NULL values** using views.
#
#
#
# ###  Connecting to the MySQL Database
# We will connect to the `united_nations` database using the `%sql` magic command.
# Ensure that `mysql` and `pymysql` are correctly installed in your environment.

# %%
# %load_ext sql

# %% [markdown]
# ###  Task 1 — Join Economic_Indicators and Geographic_Locations Tables
# We begin by joining the `Economic_Indicators` table to the `Geographic_Locations` table.
# This allows us to associate each country’s economic data with its corresponding region.

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 6 rows affected.
# [('information_schema',),
#  ('md_water_services',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('united_nations',)]

# %%
# %%sql
# USE united_nations;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('access_to_basic_services',),
#  ('basic_services',),
#  ('economic_indicators',),
#  ('geographic_location',),
#  ('unemployment_summary',)]

# %%
# %%sql
# SELECT
#     g.Country_name,
#     g.Region,
#     e.Time_period,
#     e.Pct_unemployment
# FROM
#     united_nations.Economic_Indicators AS e
# JOIN
#     united_nations.Geographic_Location AS g
# ON
#     e.Country_name = g.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 'Central and Southern Asia', 2015, Decimal('4.93')),
#  ('Kazakhstan', 'Central and Southern Asia', 2016, Decimal('4.96')),
#  ('Kazakhstan', 'Central and Southern Asia', 2017, Decimal('4.90')),
#  ('Kazakhstan', 'Central and Southern Asia', 2018, Decimal('4.85')),
#  ('Kazakhstan', 'Central and Southern Asia', 2019, Decimal('4.80')),
#  ('Kazakhstan', 'Central and Southern Asia', 2020, Decimal('4.89')),
#  ('Kyrgyzstan', 'Central and Southern Asia', 2015, None),
#  ('Kyrgyzstan', 'Central and Southern Asia', 2016, None),
#  ('Kyrgyzstan', 'Central and Southern Asia', 2017, None),
#  ('Kyrgyzstan', 'Central and Southern Asia', 2018, None),
#  ('Kyrgyzstan', 'Central and Southern Asia', 2019, None),
#  ('Kyrgyzstan', 'Central and Southern Asia', 2020, None),
#  ('Tajikistan', 'Central and Southern Asia', 2015, None),
#  ('Tajikistan', 'Central and Southern Asia', 2016, Decimal('6.90')),
#  ('Tajikistan', 'Central and Southern Asia', 2017, None),
#  ('Tajikistan', 'Central and Southern Asia', 2018, None),
#  ('Tajikistan', 'Central and Southern Asia', 2019, None),
#  ('Tajikistan', 'Central and Southern Asia', 2020, None),
#  ('Turkmenistan', 'Central and Southern Asia', 2015, None),
#  ('Turkmenistan', 'Central and Southern Asia', 2016, None),
#  ('Turkmenistan', 'Central and Southern Asia', 2017, None),
#  ('Turkmenistan', 'Central and Southern Asia', 2018, None),
#  ('Turkmenistan', 'Central and Southern Asia', 2019, None),
#  ('Turkmenistan', 'Central and Southern Asia', 2020, None),
#  ('Uzbekistan', 'Central and Southern Asia', 2015, Decimal('5.15')),
#  ('Uzbekistan', 'Central and Southern Asia', 2016, Decimal('5.16')),
#  ('Uzbekistan', 'Central and Southern Asia', 2017, Decimal('5.83')),
#  ('Uzbekistan', 'Central and Southern Asia', 2018, Decimal('9.35')),
#  ('Uzbekistan', 'Central and Southern Asia', 2019, Decimal('8.98')),
#  ('Uzbekistan', 'Central and Southern Asia', 2020, Decimal('5.29')),
#  ('Afghanistan', 'Central and Southern Asia', 2015, None),
#  ('Afghanistan', 'Central and Southern Asia', 2016, None),
#  ('Afghanistan', 'Central and Southern Asia', 2017, Decimal('11.18')),
#  ('Afghanistan', 'Central and Southern Asia', 2018, None),
#  ('Afghanistan', 'Central and Southern Asia', 2019, None),
#  ('Afghanistan', 'Central and Southern Asia', 2020, Decimal('11.71')),
#  ('Bangladesh', 'Central and Southern Asia', 2015, None),
#  ('Bangladesh', 'Central and Southern Asia', 2016, Decimal('4.35')),
#  ('Bangladesh', 'Central and Southern Asia', 2017, Decimal('4.37')),
#  ('Bangladesh', 'Central and Southern Asia', 2018, None),
#  ('Bangladesh', 'Central and Southern Asia', 2019, None),
#  ('Bangladesh', 'Central and Southern Asia', 2020, None),
#  ('Bhutan', 'Central and Southern Asia', 2015, Decimal('2.45')),
#  ('Bhutan', 'Central and Southern Asia', 2016, None),
#  ('Bhutan', 'Central and Southern Asia', 2017, None),
#  ('Bhutan', 'Central and Southern Asia', 2018, Decimal('3.35')),
#  ('Bhutan', 'Central and Southern Asia', 2019, Decimal('2.72')),
#  ('Bhutan', 'Central and Southern Asia', 2020, Decimal('5.03')),
#  ('India', 'Central and Southern Asia', 2015, None),
#  ('India', 'Central and Southern Asia', 2016, None),
#  ('India', 'Central and Southern Asia', 2017, None),
#  ('India', 'Central and Southern Asia', 2018, Decimal('7.65')),
#  ('India', 'Central and Southern Asia', 2019, Decimal('6.51')),
#  ('India', 'Central and Southern Asia', 2020, Decimal('7.86')),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', 2015, None),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', 2016, None),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', 2017, None),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', 2018, None),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', 2019, None),
#  ('Iran (Islamic Republic of)', 'Central and Southern Asia', 2020, None),
#  ('Maldives', 'Central and Southern Asia', 2015, None),
#  ('Maldives', 'Central and Southern Asia', 2016, Decimal('5.77')),
#  ('Maldives', 'Central and Southern Asia', 2017, None),
#  ('Maldives', 'Central and Southern Asia', 2018, None),
#  ('Maldives', 'Central and Southern Asia', 2019, Decimal('4.56')),
#  ('Maldives', 'Central and Southern Asia', 2020, None),
#  ('Nepal', 'Central and Southern Asia', 2015, Decimal('3.10')),
#  ('Nepal', 'Central and Southern Asia', 2016, None),
#  ('Nepal', 'Central and Southern Asia', 2017, Decimal('10.66')),
#  ('Nepal', 'Central and Southern Asia', 2018, None),
#  ('Nepal', 'Central and Southern Asia', 2019, None),
#  ('Nepal', 'Central and Southern Asia', 2020, None),
#  ('Pakistan', 'Central and Southern Asia', 2015, Decimal('3.57')),
#  ('Pakistan', 'Central and Southern Asia', 2016, None),
#  ('Pakistan', 'Central and Southern Asia', 2017, None),
#  ('Pakistan', 'Central and Southern Asia', 2018, Decimal('4.08')),
#  ('Pakistan', 'Central and Southern Asia', 2019, Decimal('4.83')),
#  ('Pakistan', 'Central and Southern Asia', 2020, None),
#  ('Sri Lanka', 'Central and Southern Asia', 2015, Decimal('4.52')),
#  ('Sri Lanka', 'Central and Southern Asia', 2016, Decimal('4.24')),
#  ('Sri Lanka', 'Central and Southern Asia', 2017, Decimal('4.05')),
#  ('Sri Lanka', 'Central and Southern Asia', 2018, Decimal('4.32')),
#  ('Sri Lanka', 'Central and Southern Asia', 2019, Decimal('4.67')),
#  ('Sri Lanka', 'Central and Southern Asia', 2020, Decimal('5.36')),
#  ('China', 'Eastern and South-Eastern Asia', 2015, None),
#  ('China', 'Eastern and South-Eastern Asia', 2016, None),
#  ('China', 'Eastern and South-Eastern Asia', 2017, Decimal('3.90')),
#  ('China', 'Eastern and South-Eastern Asia', 2018, Decimal('4.93')),
#  ('China', 'Eastern and South-Eastern Asia', 2019, Decimal('5.15')),
#  ('China', 'Eastern and South-Eastern Asia', 2020, Decimal('5.61')),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', 2015, None),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', 2016, None),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', 2017, None),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', 2018, None),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', 2019, None),
#  ("Democratic People's Republic of Korea", 'Eastern and South-Eastern Asia', 2020, None),
#  ('Japan', 'Eastern and South-Eastern Asia', 2015, Decimal('3.39')),
#  ('Japan', 'Eastern and South-Eastern Asia', 2016, Decimal('3.13')),
#  ('Japan', 'Eastern and South-Eastern Asia', 2017, Decimal('2.82')),
#  ('Japan', 'Eastern and South-Eastern Asia', 2018, Decimal('2.47')),
#  ('Japan', 'Eastern and South-Eastern Asia', 2019, Decimal('2.35')),
#  ('Japan', 'Eastern and South-Eastern Asia', 2020, Decimal('2.81')),
#  ('Mongolia', 'Eastern and South-Eastern Asia', 2015, Decimal('4.86')),
#  ('Mongolia', 'Eastern and South-Eastern Asia', 2016, Decimal('7.24')),
#  ('Mongolia', 'Eastern and South-Eastern Asia', 2017, Decimal('6.36')),
#  ('Mongolia', 'Eastern and South-Eastern Asia', 2018, Decimal('5.38')),
#  ('Mongolia', 'Eastern and South-Eastern Asia', 2019, Decimal('9.27')),
#  ('Mongolia', 'Eastern and South-Eastern Asia', 2020, Decimal('6.59')),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', 2015, None),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', 2016, None),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', 2017, None),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', 2018, None),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', 2019, None),
#  ('Republic of Korea', 'Eastern and South-Eastern Asia', 2020, None),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', 2015, None),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', 2016, None),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', 2017, Decimal('9.32')),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', 2018, Decimal('8.70')),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', 2019, Decimal('6.60')),
#  ('Brunei Darussalam', 'Eastern and South-Eastern Asia', 2020, Decimal('7.41')),
#  ('Cambodia', 'Eastern and South-Eastern Asia', 2015, Decimal('0.39')),
#  ('Cambodia', 'Eastern and South-Eastern Asia', 2016, Decimal('0.72')),
#  ('Cambodia', 'Eastern and South-Eastern Asia', 2017, Decimal('0.14')),
#  ('Cambodia', 'Eastern and South-Eastern Asia', 2018, None),
#  ('Cambodia', 'Eastern and South-Eastern Asia', 2019, Decimal('0.50')),
#  ('Cambodia', 'Eastern and South-Eastern Asia', 2020, None),
#  ('Indonesia', 'Eastern and South-Eastern Asia', 2015, Decimal('4.51')),
#  ('Indonesia', 'Eastern and South-Eastern Asia', 2016, Decimal('4.30')),
#  ('Indonesia', 'Eastern and South-Eastern Asia', 2017, Decimal('3.78')),
#  ('Indonesia', 'Eastern and South-Eastern Asia', 2018, Decimal('4.39')),
#  ('Indonesia', 'Eastern and South-Eastern Asia', 2019, Decimal('3.59')),
#  ('Indonesia', 'Eastern and South-Eastern Asia', 2020, Decimal('4.25')),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', 2015, None),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', 2016, None),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', 2017, None),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', 2018, None),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', 2019, None),
#  ("Lao People's Democratic Republic", 'Eastern and South-Eastern Asia', 2020, None),
#  ('Malaysia', 'Eastern and South-Eastern Asia', 2015, Decimal('3.10')),
#  ('Malaysia', 'Eastern and South-Eastern Asia', 2016, Decimal('3.44')),
#  ('Malaysia', 'Eastern and South-Eastern Asia', 2017, Decimal('3.41')),
#  ('Malaysia', 'Eastern and South-Eastern Asia', 2018, Decimal('3.30')),
#  ('Malaysia', 'Eastern and South-Eastern Asia', 2019, Decimal('3.26')),
#  ('Malaysia', 'Eastern and South-Eastern Asia', 2020, Decimal('4.54')),
#  ('Myanmar', 'Eastern and South-Eastern Asia', 2015, Decimal('0.77')),
#  ('Myanmar', 'Eastern and South-Eastern Asia', 2016, None),
#  ('Myanmar', 'Eastern and South-Eastern Asia', 2017, Decimal('1.36')),
#  ('Myanmar', 'Eastern and South-Eastern Asia', 2018, Decimal('0.77')),
#  ('Myanmar', 'Eastern and South-Eastern Asia', 2019, Decimal('0.41')),
#  ('Myanmar', 'Eastern and South-Eastern Asia', 2020, Decimal('1.48')),
#  ('Philippines', 'Eastern and South-Eastern Asia', 2015, Decimal('3.07')),
#  ('Philippines', 'Eastern and South-Eastern Asia', 2016, Decimal('2.70')),
#  ('Philippines', 'Eastern and South-Eastern Asia', 2017, Decimal('2.55')),
#  ('Philippines', 'Eastern and South-Eastern Asia', 2018, Decimal('2.34')),
#  ('Philippines', 'Eastern and South-Eastern Asia', 2019, Decimal('2.24')),
#  ('Philippines', 'Eastern and South-Eastern Asia', 2020, Decimal('2.52')),
#  ('Singapore', 'Eastern and South-Eastern Asia', 2015, Decimal('3.79')),
#  ('Singapore', 'Eastern and South-Eastern Asia', 2016, Decimal('4.08')),
#  ('Singapore', 'Eastern and South-Eastern Asia', 2017, Decimal('4.20')),
#  ('Singapore', 'Eastern and South-Eastern Asia', 2018, None),
#  ('Singapore', 'Eastern and South-Eastern Asia', 2019, Decimal('3.10')),
#  ('Singapore', 'Eastern and South-Eastern Asia', 2020, Decimal('4.10')),
#  ('Thailand', 'Eastern and South-Eastern Asia', 2015, Decimal('0.60')),
#  ('Thailand', 'Eastern and South-Eastern Asia', 2016, Decimal('0.69')),
#  ('Thailand', 'Eastern and South-Eastern Asia', 2017, Decimal('0.83')),
#  ('Thailand', 'Eastern and South-Eastern Asia', 2018, Decimal('0.77')),
#  ('Thailand', 'Eastern and South-Eastern Asia', 2019, Decimal('0.72')),
#  ('Thailand', 'Eastern and South-Eastern Asia', 2020, Decimal('1.10')),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', 2015, None),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', 2016, Decimal('4.66')),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', 2017, None),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', 2018, None),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', 2019, None),
#  ('Timor-Leste', 'Eastern and South-Eastern Asia', 2020, None),
#  ('Viet Nam', 'Eastern and South-Eastern Asia', 2015, None),
#  ('Viet Nam', 'Eastern and South-Eastern Asia', 2016, None),
#  ('Viet Nam', 'Eastern and South-Eastern Asia', 2017, None),
#  ('Viet Nam', 'Eastern and South-Eastern Asia', 2018, None),
#  ('Viet Nam', 'Eastern and South-Eastern Asia', 2019, None),
#  ('Viet Nam', 'Eastern and South-Eastern Asia', 2020, None),
#  ('Bermuda', 'Europe and Northern America', 2015, None),
#  ('Bermuda', 'Europe and Northern America', 2016, None),
#  ('Bermuda', 'Europe and Northern America', 2017, None),
#  ('Bermuda', 'Europe and Northern America', 2018, None),
#  ('Bermuda', 'Europe and Northern America', 2019, None),
#  ('Bermuda', 'Europe and Northern America', 2020, None),
#  ('Canada', 'Europe and Northern America', 2015, Decimal('6.91')),
#  ('Canada', 'Europe and Northern America', 2016, Decimal('7.00')),
#  ('Canada', 'Europe and Northern America', 2017, Decimal('6.34')),
#  ('Canada', 'Europe and Northern America', 2018, Decimal('5.83')),
#  ('Canada', 'Europe and Northern America', 2019, Decimal('5.66')),
#  ('Canada', 'Europe and Northern America', 2020, Decimal('9.46')),
#  ('Greenland', 'Europe and Northern America', 2015, Decimal('9.10')),
#  ('Greenland', 'Europe and Northern America', 2016, None),
#  ('Greenland', 'Europe and Northern America', 2017, None),
#  ('Greenland', 'Europe and Northern America', 2018, None),
#  ('Greenland', 'Europe and Northern America', 2019, None),
#  ('Greenland', 'Europe and Northern America', 2020, None),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', 2015, None),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', 2016, None),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', 2017, None),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', 2018, None),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', 2019, None),
#  ('Saint Pierre and Miquelon', 'Europe and Northern America', 2020, None),
#  ('United States of America', 'Europe and Northern America', 2015, None),
#  ('United States of America', 'Europe and Northern America', 2016, None),
#  ('United States of America', 'Europe and Northern America', 2017, None),
#  ('United States of America', 'Europe and Northern America', 2018, None),
#  ('United States of America', 'Europe and Northern America', 2019, None),
#  ('United States of America', 'Europe and Northern America', 2020, None),
#  ('Anguilla', 'Latin America and the Caribbean', 2015, None),
#  ('Anguilla', 'Latin America and the Caribbean', 2016, None),
#  ('Anguilla', 'Latin America and the Caribbean', 2017, None),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', 2015, None),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', 2016, None),
#  ('Antigua and Barbuda', 'Latin America and the Caribbean', 2017, None),
#  ('Aruba', 'Latin America and the Caribbean', 2015, None),
#  ('Aruba', 'Latin America and the Caribbean', 2016, None),
#  ('Bahamas', 'Latin America and the Caribbean', 2015, None),
#  ('Bahamas', 'Latin America and the Caribbean', 2016, None),
#  ('Bahamas', 'Latin America and the Caribbean', 2017, None),
#  ('Bahamas', 'Latin America and the Caribbean', 2018, None),
#  ('Bahamas', 'Latin America and the Caribbean', 2019, None),
#  ('Barbados', 'Latin America and the Caribbean', 2015, Decimal('9.80')),
#  ('Barbados', 'Latin America and the Caribbean', 2016, Decimal('8.25')),
#  ('Barbados', 'Latin America and the Caribbean', 2017, Decimal('8.62')),
#  ('Barbados', 'Latin America and the Caribbean', 2018, Decimal('8.32')),
#  ('Barbados', 'Latin America and the Caribbean', 2019, Decimal('8.41')),
#  ('Barbados', 'Latin America and the Caribbean', 2020, None),
#  ('British Virgin Islands', 'Latin America and the Caribbean', 2015, None),
#  ('British Virgin Islands', 'Latin America and the Caribbean', 2016, None),
#  ('British Virgin Islands', 'Latin America and the Caribbean', 2017, None),
#  ('British Virgin Islands', 'Latin America and the Caribbean', 2018, None),
#  ('British Virgin Islands', 'Latin America and the Caribbean', 2019, None),
#  ('British Virgin Islands', 'Latin America and the Caribbean', 2020, None),
#  ('Cayman Islands', 'Latin America and the Caribbean', 2015, Decimal('4.24')),
#  ('Cayman Islands', 'Latin America and the Caribbean', 2016, None),
#  ('Cuba', 'Latin America and the Caribbean', 2015, Decimal('2.40')),
#  ('Cuba', 'Latin America and the Caribbean', 2016, Decimal('2.00')),
#  ('Cuba', 'Latin America and the Caribbean', 2017, Decimal('1.70')),
#  ('Cuba', 'Latin America and the Caribbean', 2018, Decimal('1.70')),
#  ('Cuba', 'Latin America and the Caribbean', 2019, None),
#  ('Cuba', 'Latin America and the Caribbean', 2020, None),
#  ('Curaçao', 'Latin America and the Caribbean', 2015, None),
#  ('Curaçao', 'Latin America and the Caribbean', 2016, None),
#  ('Curaçao', 'Latin America and the Caribbean', 2017, None),
#  ('Dominica', 'Latin America and the Caribbean', 2015, None),
#  ('Dominica', 'Latin America and the Caribbean', 2016, None),
#  ('Dominica', 'Latin America and the Caribbean', 2017, None),
#  ('Dominican Republic', 'Latin America and the Caribbean', 2015, Decimal('7.61')),
#  ('Dominican Republic', 'Latin America and the Caribbean', 2016, Decimal('7.28')),
#  ('Dominican Republic', 'Latin America and the Caribbean', 2017, Decimal('5.83')),
#  ('Dominican Republic', 'Latin America and the Caribbean', 2018, Decimal('5.86')),
#  ('Dominican Republic', 'Latin America and the Caribbean', 2019, Decimal('6.18')),
#  ('Dominican Republic', 'Latin America and the Caribbean', 2020, Decimal('6.13')),
#  ('Grenada', 'Latin America and the Caribbean', 2015, Decimal('22.90')),
#  ('Grenada', 'Latin America and the Caribbean', 2016, None),
#  ('Grenada', 'Latin America and the Caribbean', 2017, None),
#  ('Guadeloupe', 'Latin America and the Caribbean', 2015, None),
#  ('Guadeloupe', 'Latin America and the Caribbean', 2016, None),
#  ('Guadeloupe', 'Latin America and the Caribbean', 2017, None),
#  ('Guadeloupe', 'Latin America and the Caribbean', 2018, None),
#  ('Guadeloupe', 'Latin America and the Caribbean', 2019, None),
#  ('Guadeloupe', 'Latin America and the Caribbean', 2020, None),
#  ('Haiti', 'Latin America and the Caribbean', 2015, None),
#  ('Haiti', 'Latin America and the Caribbean', 2016, None),
#  ('Haiti', 'Latin America and the Caribbean', 2017, None),
#  ('Haiti', 'Latin America and the Caribbean', 2018, None),
#  ('Haiti', 'Latin America and the Caribbean', 2019, None),
#  ('Haiti', 'Latin America and the Caribbean', 2020, None),
#  ('Jamaica', 'Latin America and the Caribbean', 2015, Decimal('13.51')),
#  ('Jamaica', 'Latin America and the Caribbean', 2016, Decimal('8.63')),
#  ('Jamaica', 'Latin America and the Caribbean', 2017, Decimal('7.40')),
#  ('Jamaica', 'Latin America and the Caribbean', 2018, Decimal('5.47')),
#  ('Jamaica', 'Latin America and the Caribbean', 2019, Decimal('4.99')),
#  ('Jamaica', 'Latin America and the Caribbean', 2020, Decimal('6.50')),
#  ('Martinique', 'Latin America and the Caribbean', 2015, None),
#  ('Martinique', 'Latin America and the Caribbean', 2016, None),
#  ('Martinique', 'Latin America and the Caribbean', 2017, None),
#  ('Martinique', 'Latin America and the Caribbean', 2018, None),
#  ('Martinique', 'Latin America and the Caribbean', 2019, None),
#  ('Martinique', 'Latin America and the Caribbean', 2020, None),
#  ('Montserrat', 'Latin America and the Caribbean', 2015, None),
#  ('Montserrat', 'Latin America and the Caribbean', 2016, None),
#  ('Montserrat', 'Latin America and the Caribbean', 2017, None),
#  ('Montserrat', 'Latin America and the Caribbean', 2018, None),
#  ('Montserrat', 'Latin America and the Caribbean', 2019, None),
#  ('Montserrat', 'Latin America and the Caribbean', 2020, None),
#  ('Puerto Rico', 'Latin America and the Caribbean', 2015, Decimal('12.00')),
#  ('Puerto Rico', 'Latin America and the Caribbean', 2016, Decimal('11.80')),
#  ('Puerto Rico', 'Latin America and the Caribbean', 2017, Decimal('10.80')),
#  ('Puerto Rico', 'Latin America and the Caribbean', 2018, Decimal('9.20')),
#  ('Puerto Rico', 'Latin America and the Caribbean', 2019, Decimal('8.30')),
#  ('Puerto Rico', 'Latin America and the Caribbean', 2020, None),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', 2015, None),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', 2016, None),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', 2017, None),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', 2018, None),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', 2019, None),
#  ('Saint Barthélemy', 'Latin America and the Caribbean', 2020, None),
#  ('Saint Kitts and Nevis', 'Latin America and the Caribbean', 2015, None),
#  ('Saint Kitts and Nevis', 'Latin America and the Caribbean', 2016, None),
#  ('Saint Kitts and Nevis', 'Latin America and the Caribbean', 2017, None),
#  ('Saint Lucia', 'Latin America and the Caribbean', 2015, None),
#  ('Saint Lucia', 'Latin America and the Caribbean', 2016, None),
#  ('Saint Lucia', 'Latin America and the Caribbean', 2017, None),
#  ('Saint Lucia', 'Latin America and the Caribbean', 2018, None),
#  ('Saint Lucia', 'Latin America and the Caribbean', 2019, None),
#  ('Saint Lucia', 'Latin America and the Caribbean', 2020, None),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', 2015, None),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', 2016, None),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', 2017, None),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', 2018, None),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', 2019, None),
#  ('Saint Martin (French Part)', 'Latin America and the Caribbean', 2020, None),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', 2015, None),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', 2016, None),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', 2017, None),
#  ('Saint Vincent and the Grenadines', 'Latin America and the Caribbean', 2018, None),
#  ('Sint Maarten (Dutch part)', 'Latin America and the Caribbean', 2015, None),
#  ('Sint Maarten (Dutch part)', 'Latin America and the Caribbean', 2016, None),
#  ('Sint Maarten (Dutch part)', 'Latin America and the Caribbean', 2017, None),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', 2015, Decimal('2.43')),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', 2016, Decimal('3.21')),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', 2017, None),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', 2018, None),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', 2019, Decimal('3.52')),
#  ('Trinidad and Tobago', 'Latin America and the Caribbean', 2020, Decimal('4.21')),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', 2015, None),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', 2016, None),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', 2017, None),
#  ('Turks and Caicos Islands', 'Latin America and the Caribbean', 2018, None),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', 2015, None),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', 2016, None),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', 2017, None),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', 2018, None),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', 2019, None),
#  ('United States Virgin Islands', 'Latin America and the Caribbean', 2020, None),
#  ('Belize', 'Latin America and the Caribbean', 2015, Decimal('7.58')),
#  ('Belize', 'Latin America and the Caribbean', 2016, Decimal('7.00')),
#  ('Belize', 'Latin America and the Caribbean', 2017, Decimal('6.60')),
#  ('Belize', 'Latin America and the Caribbean', 2018, None),
#  ('Belize', 'Latin America and the Caribbean', 2019, Decimal('9.05')),
#  ('Belize', 'Latin America and the Caribbean', 2020, None),
#  ('Costa Rica', 'Latin America and the Caribbean', 2015, Decimal('8.42')),
#  ('Costa Rica', 'Latin America and the Caribbean', 2016, Decimal('8.09')),
#  ('Costa Rica', 'Latin America and the Caribbean', 2017, Decimal('7.73')),
#  ('Costa Rica', 'Latin America and the Caribbean', 2018, Decimal('9.01')),
#  ('Costa Rica', 'Latin America and the Caribbean', 2019, Decimal('10.81')),
#  ('Costa Rica', 'Latin America and the Caribbean', 2020, Decimal('16.43')),
#  ('El Salvador', 'Latin America and the Caribbean', 2015, Decimal('4.00')),
#  ('El Salvador', 'Latin America and the Caribbean', 2016, Decimal('4.42')),
#  ('El Salvador', 'Latin America and the Caribbean', 2017, Decimal('4.39')),
#  ('El Salvador', 'Latin America and the Caribbean', 2018, Decimal('4.01')),
#  ('El Salvador', 'Latin America and the Caribbean', 2019, Decimal('4.17')),
#  ('El Salvador', 'Latin America and the Caribbean', 2020, Decimal('5.01')),
#  ('Guatemala', 'Latin America and the Caribbean', 2015, Decimal('2.51')),
#  ('Guatemala', 'Latin America and the Caribbean', 2016, Decimal('2.58')),
#  ('Guatemala', 'Latin America and the Caribbean', 2017, Decimal('2.46')),
#  ('Guatemala', 'Latin America and the Caribbean', 2018, Decimal('2.28')),
#  ('Guatemala', 'Latin America and the Caribbean', 2019, Decimal('2.19')),
#  ('Guatemala', 'Latin America and the Caribbean', 2020, None),
#  ('Honduras', 'Latin America and the Caribbean', 2015, Decimal('6.15')),
#  ('Honduras', 'Latin America and the Caribbean', 2016, Decimal('6.73')),
#  ('Honduras', 'Latin America and the Caribbean', 2017, Decimal('5.53')),
#  ('Honduras', 'Latin America and the Caribbean', 2018, Decimal('5.62')),
#  ('Honduras', 'Latin America and the Caribbean', 2019, Decimal('5.55')),
#  ('Honduras', 'Latin America and the Caribbean', 2020, Decimal('10.68')),
#  ('Mexico', 'Latin America and the Caribbean', 2015, Decimal('4.31')),
#  ('Mexico', 'Latin America and the Caribbean', 2016, Decimal('3.85')),
#  ('Mexico', 'Latin America and the Caribbean', 2017, Decimal('3.42')),
#  ('Mexico', 'Latin America and the Caribbean', 2018, Decimal('3.27')),
#  ('Mexico', 'Latin America and the Caribbean', 2019, Decimal('3.48')),
#  ('Mexico', 'Latin America and the Caribbean', 2020, Decimal('4.44')),
#  ('Nicaragua', 'Latin America and the Caribbean', 2015, Decimal('4.70')),
#  ('Nicaragua', 'Latin America and the Caribbean', 2016, Decimal('3.90')),
#  ('Nicaragua', 'Latin America and the Caribbean', 2017, Decimal('3.30')),
#  ('Nicaragua', 'Latin America and the Caribbean', 2018, Decimal('5.20')),
#  ('Nicaragua', 'Latin America and the Caribbean', 2019, None),
#  ('Nicaragua', 'Latin America and the Caribbean', 2020, None),
#  ('Panama', 'Latin America and the Caribbean', 2015, Decimal('4.40')),
#  ('Panama', 'Latin America and the Caribbean', 2016, Decimal('4.84')),
#  ('Panama', 'Latin America and the Caribbean', 2017, Decimal('5.46')),
#  ('Panama', 'Latin America and the Caribbean', 2018, Decimal('5.31')),
#  ('Panama', 'Latin America and the Caribbean', 2019, Decimal('6.41')),
#  ('Panama', 'Latin America and the Caribbean', 2020, Decimal('18.55')),
#  ('Argentina', 'Latin America and the Caribbean', 2015, None),
#  ('Argentina', 'Latin America and the Caribbean', 2016, None),
#  ('Argentina', 'Latin America and the Caribbean', 2017, Decimal('8.35')),
#  ('Argentina', 'Latin America and the Caribbean', 2018, Decimal('9.22')),
#  ('Argentina', 'Latin America and the Caribbean', 2019, Decimal('9.84')),
#  ('Argentina', 'Latin America and the Caribbean', 2020, Decimal('11.46')),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', 2015, None),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', 2016, None),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', 2017, None),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', 2018, None),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', 2019, None),
#  ('Bolivia (Plurinational State of)', 'Latin America and the Caribbean', 2020, None),
#  ('Brazil', 'Latin America and the Caribbean', 2015, Decimal('8.54')),
#  ('Brazil', 'Latin America and the Caribbean', 2016, Decimal('11.58')),
#  ('Brazil', 'Latin America and the Caribbean', 2017, Decimal('12.79')),
#  ('Brazil', 'Latin America and the Caribbean', 2018, Decimal('12.33')),
#  ('Brazil', 'Latin America and the Caribbean', 2019, Decimal('11.94')),
#  ('Brazil', 'Latin America and the Caribbean', 2020, Decimal('13.70')),
#  ('Chile', 'Latin America and the Caribbean', 2015, Decimal('6.49')),
#  ('Chile', 'Latin America and the Caribbean', 2016, Decimal('6.73')),
#  ('Chile', 'Latin America and the Caribbean', 2017, Decimal('6.95')),
#  ('Chile', 'Latin America and the Caribbean', 2018, Decimal('7.21')),
#  ('Chile', 'Latin America and the Caribbean', 2019, Decimal('7.27')),
#  ('Chile', 'Latin America and the Caribbean', 2020, Decimal('10.94')),
#  ('Colombia', 'Latin America and the Caribbean', 2015, Decimal('8.57')),
#  ('Colombia', 'Latin America and the Caribbean', 2016, Decimal('8.92')),
#  ('Colombia', 'Latin America and the Caribbean', 2017, Decimal('9.09')),
#  ('Colombia', 'Latin America and the Caribbean', 2018, Decimal('9.36')),
#  ('Colombia', 'Latin America and the Caribbean', 2019, Decimal('10.28')),
#  ('Colombia', 'Latin America and the Caribbean', 2020, Decimal('15.98')),
#  ('Ecuador', 'Latin America and the Caribbean', 2015, Decimal('3.62')),
#  ('Ecuador', 'Latin America and the Caribbean', 2016, Decimal('4.60')),
#  ('Ecuador', 'Latin America and the Caribbean', 2017, Decimal('3.84')),
#  ('Ecuador', 'Latin America and the Caribbean', 2018, Decimal('3.53')),
#  ('Ecuador', 'Latin America and the Caribbean', 2019, Decimal('3.81')),
#  ('Ecuador', 'Latin America and the Caribbean', 2020, Decimal('6.11')),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', 2015, None),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', 2016, None),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', 2017, None),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', 2018, None),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', 2019, None),
#  ('Falkland Islands (Malvinas)', 'Latin America and the Caribbean', 2020, None),
#  ('French Guiana', 'Latin America and the Caribbean', 2015, None),
#  ('French Guiana', 'Latin America and the Caribbean', 2016, None),
#  ('French Guiana', 'Latin America and the Caribbean', 2017, None),
#  ('French Guiana', 'Latin America and the Caribbean', 2018, None),
#  ('French Guiana', 'Latin America and the Caribbean', 2019, None),
#  ('French Guiana', 'Latin America and the Caribbean', 2020, None),
#  ('Guyana', 'Latin America and the Caribbean', 2015, None),
#  ('Guyana', 'Latin America and the Caribbean', 2016, None),
#  ('Guyana', 'Latin America and the Caribbean', 2017, None),
#  ('Guyana', 'Latin America and the Caribbean', 2018, Decimal('14.02')),
#  ('Guyana', 'Latin America and the Caribbean', 2019, Decimal('13.52')),
#  ('Guyana', 'Latin America and the Caribbean', 2020, None),
#  ('Paraguay', 'Latin America and the Caribbean', 2015, Decimal('4.56')),
#  ('Paraguay', 'Latin America and the Caribbean', 2016, Decimal('5.25')),
#  ('Paraguay', 'Latin America and the Caribbean', 2017, Decimal('4.61')),
#  ('Paraguay', 'Latin America and the Caribbean', 2018, Decimal('6.22')),
#  ('Paraguay', 'Latin America and the Caribbean', 2019, Decimal('6.59')),
#  ('Paraguay', 'Latin America and the Caribbean', 2020, Decimal('7.55')),
#  ('Peru', 'Latin America and the Caribbean', 2015, Decimal('3.27')),
#  ('Peru', 'Latin America and the Caribbean', 2016, Decimal('3.74')),
#  ('Peru', 'Latin America and the Caribbean', 2017, Decimal('3.69')),
#  ('Peru', 'Latin America and the Caribbean', 2018, Decimal('3.49')),
#  ('Peru', 'Latin America and the Caribbean', 2019, Decimal('3.38')),
#  ('Peru', 'Latin America and the Caribbean', 2020, Decimal('7.18')),
#  ('Suriname', 'Latin America and the Caribbean', 2015, Decimal('7.22')),
#  ('Suriname', 'Latin America and the Caribbean', 2016, Decimal('7.92')),
#  ('Suriname', 'Latin America and the Caribbean', 2017, None),
#  ('Suriname', 'Latin America and the Caribbean', 2018, None),
#  ('Suriname', 'Latin America and the Caribbean', 2019, None),
#  ('Suriname', 'Latin America and the Caribbean', 2020, None),
#  ('Uruguay', 'Latin America and the Caribbean', 2015, Decimal('7.49')),
#  ('Uruguay', 'Latin America and the Caribbean', 2016, Decimal('7.84')),
#  ('Uruguay', 'Latin America and the Caribbean', 2017, Decimal('7.89')),
#  ('Uruguay', 'Latin America and the Caribbean', 2018, Decimal('8.34')),
#  ('Uruguay', 'Latin America and the Caribbean', 2019, Decimal('8.73')),
#  ('Uruguay', 'Latin America and the Caribbean', 2020, Decimal('10.33')),
#  ('Venezuela (Bolivarian Republic of)', 'Latin America and the Caribbean', 2015, None),
#  ('Venezuela (Bolivarian Republic of)', 'Latin America and the Caribbean', 2016, None),
#  ('Venezuela (Bolivarian Republic of)', 'Latin America and the Caribbean', 2017, None),
#  ('Venezuela (Bolivarian Republic of)', 'Latin America and the Caribbean', 2018, None),
#  ('Venezuela (Bolivarian Republic of)', 'Latin America and the Caribbean', 2019, None),
#  ('Venezuela (Bolivarian Republic of)', 'Latin America and the Caribbean', 2020, None),
#  ('Algeria', 'Northern Africa and Western Asia', 2015, Decimal('11.21')),
#  ('Algeria', 'Northern Africa and Western Asia', 2016, Decimal('10.20')),
#  ('Algeria', 'Northern Africa and Western Asia', 2017, Decimal('12.00')),
#  ('Algeria', 'Northern Africa and Western Asia', 2018, None),
#  ('Algeria', 'Northern Africa and Western Asia', 2019, None),
#  ('Algeria', 'Northern Africa and Western Asia', 2020, None),
#  ('Egypt', 'Northern Africa and Western Asia', 2015, None),
#  ('Egypt', 'Northern Africa and Western Asia', 2016, None),
#  ('Egypt', 'Northern Africa and Western Asia', 2017, None),
#  ('Egypt', 'Northern Africa and Western Asia', 2018, None),
#  ('Egypt', 'Northern Africa and Western Asia', 2019, None),
#  ('Egypt', 'Northern Africa and Western Asia', 2020, None),
#  ('Libya', 'Northern Africa and Western Asia', 2015, None),
#  ('Libya', 'Northern Africa and Western Asia', 2016, None),
#  ('Libya', 'Northern Africa and Western Asia', 2017, None),
#  ('Libya', 'Northern Africa and Western Asia', 2018, None),
#  ('Libya', 'Northern Africa and Western Asia', 2019, None),
#  ('Libya', 'Northern Africa and Western Asia', 2020, None),
#  ('Morocco', 'Northern Africa and Western Asia', 2015, Decimal('9.46')),
#  ('Morocco', 'Northern Africa and Western Asia', 2016, Decimal('9.30')),
#  ('Morocco', 'Northern Africa and Western Asia', 2017, None),
#  ('Morocco', 'Northern Africa and Western Asia', 2018, None),
#  ('Morocco', 'Northern Africa and Western Asia', 2019, None),
#  ('Morocco', 'Northern Africa and Western Asia', 2020, None),
#  ('Sudan', 'Northern Africa and Western Asia', 2015, None),
#  ('Sudan', 'Northern Africa and Western Asia', 2016, None),
#  ('Sudan', 'Northern Africa and Western Asia', 2017, None),
#  ('Sudan', 'Northern Africa and Western Asia', 2018, None),
#  ('Sudan', 'Northern Africa and Western Asia', 2019, None),
#  ('Sudan', 'Northern Africa and Western Asia', 2020, None),
#  ('Tunisia', 'Northern Africa and Western Asia', 2015, Decimal('15.16')),
#  ('Tunisia', 'Northern Africa and Western Asia', 2016, Decimal('15.56')),
#  ('Tunisia', 'Northern Africa and Western Asia', 2017, Decimal('15.33')),
#  ('Tunisia', 'Northern Africa and Western Asia', 2018, Decimal('15.46')),
#  ('Tunisia', 'Northern Africa and Western Asia', 2019, Decimal('15.13')),
#  ('Tunisia', 'Northern Africa and Western Asia', 2020, None),
#  ('Armenia', 'Northern Africa and Western Asia', 2015, Decimal('18.26')),
#  ('Armenia', 'Northern Africa and Western Asia', 2016, Decimal('17.62')),
#  ('Armenia', 'Northern Africa and Western Asia', 2017, Decimal('17.70')),
#  ('Armenia', 'Northern Africa and Western Asia', 2018, Decimal('13.21')),
#  ('Armenia', 'Northern Africa and Western Asia', 2019, Decimal('12.20')),
#  ('Armenia', 'Northern Africa and Western Asia', 2020, Decimal('12.18')),
#  ('Azerbaijan', 'Northern Africa and Western Asia', 2015, Decimal('4.96')),
#  ('Azerbaijan', 'Northern Africa and Western Asia', 2016, Decimal('5.00')),
#  ('Azerbaijan', 'Northern Africa and Western Asia', 2017, Decimal('4.96')),
#  ('Azerbaijan', 'Northern Africa and Western Asia', 2018, Decimal('4.94')),
#  ('Azerbaijan', 'Northern Africa and Western Asia', 2019, Decimal('4.85')),
#  ('Azerbaijan', 'Northern Africa and Western Asia', 2020, Decimal('7.16')),
#  ('Bahrain', 'Northern Africa and Western Asia', 2015, None),
#  ('Bahrain', 'Northern Africa and Western Asia', 2016, None),
#  ('Bahrain', 'Northern Africa and Western Asia', 2017, None),
#  ('Bahrain', 'Northern Africa and Western Asia', 2018, None),
#  ('Bahrain', 'Northern Africa and Western Asia', 2019, None),
#  ('Bahrain', 'Northern Africa and Western Asia', 2020, None),
#  ('Cyprus', 'Northern Africa and Western Asia', 2015, Decimal('15.03')),
#  ('Cyprus', 'Northern Africa and Western Asia', 2016, Decimal('13.01')),
#  ('Cyprus', 'Northern Africa and Western Asia', 2017, Decimal('11.16')),
#  ('Cyprus', 'Northern Africa and Western Asia', 2018, Decimal('8.50')),
#  ('Cyprus', 'Northern Africa and Western Asia', 2019, Decimal('7.15')),
#  ('Cyprus', 'Northern Africa and Western Asia', 2020, Decimal('7.76')),
#  ('Georgia', 'Northern Africa and Western Asia', 2015, Decimal('16.51')),
#  ('Georgia', 'Northern Africa and Western Asia', 2016, Decimal('16.60')),
#  ('Georgia', 'Northern Africa and Western Asia', 2017, Decimal('13.94')),
#  ('Georgia', 'Northern Africa and Western Asia', 2018, Decimal('12.67')),
#  ('Georgia', 'Northern Africa and Western Asia', 2019, Decimal('11.57')),
#  ('Georgia', 'Northern Africa and Western Asia', 2020, Decimal('11.73')),
#  ('Iraq', 'Northern Africa and Western Asia', 2015, None),
#  ('Iraq', 'Northern Africa and Western Asia', 2016, Decimal('10.82')),
#  ('Iraq', 'Northern Africa and Western Asia', 2017, Decimal('13.02')),
#  ('Iraq', 'Northern Africa and Western Asia', 2018, None),
#  ('Iraq', 'Northern Africa and Western Asia', 2019, None),
#  ('Iraq', 'Northern Africa and Western Asia', 2020, None),
#  ('Israel', 'Northern Africa and Western Asia', 2015, Decimal('5.18')),
#  ('Israel', 'Northern Africa and Western Asia', 2016, Decimal('4.72')),
#  ('Israel', 'Northern Africa and Western Asia', 2017, Decimal('4.14')),
#  ('Israel', 'Northern Africa and Western Asia', 2018, Decimal('3.92')),
#  ('Israel', 'Northern Africa and Western Asia', 2019, Decimal('3.73')),
#  ('Israel', 'Northern Africa and Western Asia', 2020, Decimal('4.17')),
#  ('Jordan', 'Northern Africa and Western Asia', 2015, Decimal('13.08')),
#  ('Jordan', 'Northern Africa and Western Asia', 2016, Decimal('15.28')),
#  ('Jordan', 'Northern Africa and Western Asia', 2017, Decimal('18.12')),
#  ('Jordan', 'Northern Africa and Western Asia', 2018, Decimal('18.26')),
#  ('Jordan', 'Northern Africa and Western Asia', 2019, Decimal('16.80')),
#  ('Jordan', 'Northern Africa and Western Asia', 2020, Decimal('19.21')),
#  ('Kuwait', 'Northern Africa and Western Asia', 2015, Decimal('2.20')),
#  ('Kuwait', 'Northern Africa and Western Asia', 2016, Decimal('2.16')),
#  ('Kuwait', 'Northern Africa and Western Asia', 2017, None),
#  ('Kuwait', 'Northern Africa and Western Asia', 2018, None),
#  ('Kuwait', 'Northern Africa and Western Asia', 2019, None),
#  ('Kuwait', 'Northern Africa and Western Asia', 2020, None),
#  ('Lebanon', 'Northern Africa and Western Asia', 2015, None),
#  ('Lebanon', 'Northern Africa and Western Asia', 2016, None),
#  ('Lebanon', 'Northern Africa and Western Asia', 2017, None),
#  ('Lebanon', 'Northern Africa and Western Asia', 2018, None),
#  ('Lebanon', 'Northern Africa and Western Asia', 2019, Decimal('11.30')),
#  ('Lebanon', 'Northern Africa and Western Asia', 2020, None),
#  ('Oman', 'Northern Africa and Western Asia', 2015, None),
#  ('Oman', 'Northern Africa and Western Asia', 2016, Decimal('3.27')),
#  ('Oman', 'Northern Africa and Western Asia', 2017, None),
#  ('Oman', 'Northern Africa and Western Asia', 2018, Decimal('1.80')),
#  ('Oman', 'Northern Africa and Western Asia', 2019, None),
#  ('Oman', 'Northern Africa and Western Asia', 2020, Decimal('2.94')),
#  ('Qatar', 'Northern Africa and Western Asia', 2015, Decimal('0.17')),
#  ('Qatar', 'Northern Africa and Western Asia', 2016, Decimal('0.15')),
#  ('Qatar', 'Northern Africa and Western Asia', 2017, Decimal('0.14')),
#  ('Qatar', 'Northern Africa and Western Asia', 2018, Decimal('0.11')),
#  ('Qatar', 'Northern Africa and Western Asia', 2019, Decimal('0.10')),
#  ('Qatar', 'Northern Africa and Western Asia', 2020, Decimal('0.14')),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', 2015, Decimal('5.60')),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', 2016, Decimal('5.60')),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', 2017, Decimal('5.89')),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', 2018, Decimal('6.03')),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', 2019, Decimal('5.64')),
#  ('Saudi Arabia', 'Northern Africa and Western Asia', 2020, Decimal('7.66')),
#  ('State of Palestine', 'Northern Africa and Western Asia', 2015, None),
#  ('State of Palestine', 'Northern Africa and Western Asia', 2016, None),
#  ('State of Palestine', 'Northern Africa and Western Asia', 2017, None),
#  ('State of Palestine', 'Northern Africa and Western Asia', 2018, None),
#  ('State of Palestine', 'Northern Africa and Western Asia', 2019, None),
#  ('State of Palestine', 'Northern Africa and Western Asia', 2020, None),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', 2015, None),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', 2016, None),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', 2017, None),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', 2018, None),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', 2019, None),
#  ('Syrian Arab Republic', 'Northern Africa and Western Asia', 2020, None),
#  ('Türkiye', 'Northern Africa and Western Asia', 2015, None),
#  ('Türkiye', 'Northern Africa and Western Asia', 2016, None),
#  ('Türkiye', 'Northern Africa and Western Asia', 2017, None),
#  ('Türkiye', 'Northern Africa and Western Asia', 2018, None),
#  ('Türkiye', 'Northern Africa and Western Asia', 2019, None),
#  ('Türkiye', 'Northern Africa and Western Asia', 2020, None),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', 2015, None),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', 2016, Decimal('1.64')),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', 2017, Decimal('2.46')),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', 2018, Decimal('2.24')),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', 2019, Decimal('2.33')),
#  ('United Arab Emirates', 'Northern Africa and Western Asia', 2020, Decimal('4.29')),
#  ('Yemen', 'Northern Africa and Western Asia', 2015, None),
#  ('Yemen', 'Northern Africa and Western Asia', 2016, None),
#  ('Yemen', 'Northern Africa and Western Asia', 2017, None),
#  ('Yemen', 'Northern Africa and Western Asia', 2018, None),
#  ('Yemen', 'Northern Africa and Western Asia', 2019, None),
#  ('Yemen', 'Northern Africa and Western Asia', 2020, None),
#  ('Australia', 'Oceania', 2015, Decimal('6.06')),
#  ('Australia', 'Oceania', 2016, Decimal('5.71')),
#  ('Australia', 'Oceania', 2017, Decimal('5.59')),
#  ('Australia', 'Oceania', 2018, Decimal('5.30')),
#  ('Australia', 'Oceania', 2019, Decimal('5.16')),
#  ('Australia', 'Oceania', 2020, Decimal('6.46')),
#  ('New Zealand', 'Oceania', 2015, Decimal('5.42')),
#  ('New Zealand', 'Oceania', 2016, Decimal('5.15')),
#  ('New Zealand', 'Oceania', 2017, Decimal('4.74')),
#  ('New Zealand', 'Oceania', 2018, Decimal('4.34')),
#  ('New Zealand', 'Oceania', 2019, Decimal('4.11')),
#  ('New Zealand', 'Oceania', 2020, Decimal('4.60')),
#  ('Fiji', 'Oceania', 2015, None),
#  ('Fiji', 'Oceania', 2016, Decimal('4.32')),
#  ('Fiji', 'Oceania', 2017, None),
#  ('Fiji', 'Oceania', 2018, None),
#  ('Fiji', 'Oceania', 2019, None),
#  ('Fiji', 'Oceania', 2020, None),
#  ('New Caledonia', 'Oceania', 2015, None),
#  ('New Caledonia', 'Oceania', 2016, None),
#  ('New Caledonia', 'Oceania', 2017, Decimal('11.68')),
#  ('New Caledonia', 'Oceania', 2018, Decimal('11.70')),
#  ('New Caledonia', 'Oceania', 2019, Decimal('10.88')),
#  ('New Caledonia', 'Oceania', 2020, Decimal('13.56')),
#  ('Papua New Guinea', 'Oceania', 2015, None),
#  ('Papua New Guinea', 'Oceania', 2016, None),
#  ('Papua New Guinea', 'Oceania', 2017, None),
#  ('Papua New Guinea', 'Oceania', 2018, None),
#  ('Papua New Guinea', 'Oceania', 2019, None),
#  ('Papua New Guinea', 'Oceania', 2020, None),
#  ('Solomon Islands', 'Oceania', 2015, None),
#  ('Solomon Islands', 'Oceania', 2016, None),
#  ('Solomon Islands', 'Oceania', 2017, None),
#  ('Solomon Islands', 'Oceania', 2018, None),
#  ('Solomon Islands', 'Oceania', 2019, None),
#  ('Solomon Islands', 'Oceania', 2020, None),
#  ('Vanuatu', 'Oceania', 2015, None),
#  ('Vanuatu', 'Oceania', 2016, None),
#  ('Vanuatu', 'Oceania', 2017, None),
#  ('Vanuatu', 'Oceania', 2018, None),
#  ('Vanuatu', 'Oceania', 2019, Decimal('5.44')),
#  ('Vanuatu', 'Oceania', 2020, Decimal('4.05')),
#  ('Guam', 'Oceania', 2015, Decimal('6.90')),
#  ('Guam', 'Oceania', 2016, Decimal('5.40')),
#  ('Guam', 'Oceania', 2017, None),
#  ('Guam', 'Oceania', 2018, None),
#  ('Guam', 'Oceania', 2019, None),
#  ('Guam', 'Oceania', 2020, None),
#  ('Kiribati', 'Oceania', 2015, Decimal('9.33')),
#  ('Kiribati', 'Oceania', 2016, None),
#  ('Kiribati', 'Oceania', 2017, None),
#  ('Kiribati', 'Oceania', 2018, None),
#  ('Kiribati', 'Oceania', 2019, Decimal('8.56')),
#  ('Kiribati', 'Oceania', 2020, Decimal('10.97')),
#  ('Marshall Islands', 'Oceania', 2015, None),
#  ('Marshall Islands', 'Oceania', 2016, None),
#  ('Marshall Islands', 'Oceania', 2017, None),
#  ('Marshall Islands', 'Oceania', 2018, None),
#  ('Marshall Islands', 'Oceania', 2019, Decimal('6.34')),
#  ('Marshall Islands', 'Oceania', 2020, None),
#  ('Micronesia (Federated States of)', 'Oceania', 2015, None),
#  ('Micronesia (Federated States of)', 'Oceania', 2016, None),
#  ('Micronesia (Federated States of)', 'Oceania', 2017, None),
#  ('Micronesia (Federated States of)', 'Oceania', 2018, None),
#  ('Micronesia (Federated States of)', 'Oceania', 2019, None),
#  ('Nauru', 'Oceania', 2015, None),
#  ('Nauru', 'Oceania', 2016, None),
#  ('Nauru', 'Oceania', 2017, None),
#  ('Nauru', 'Oceania', 2018, None),
#  ('Nauru', 'Oceania', 2019, None),
#  ('Nauru', 'Oceania', 2020, None),
#  ('Northern Mariana Islands', 'Oceania', 2015, None),
#  ('Northern Mariana Islands', 'Oceania', 2016, None),
#  ('Northern Mariana Islands', 'Oceania', 2017, None),
#  ('Northern Mariana Islands', 'Oceania', 2018, None),
#  ('Northern Mariana Islands', 'Oceania', 2019, None),
#  ('Northern Mariana Islands', 'Oceania', 2020, None),
#  ('Palau', 'Oceania', 2015, None),
#  ('Palau', 'Oceania', 2016, None),
#  ('Palau', 'Oceania', 2017, None),
#  ('Palau', 'Oceania', 2018, None),
#  ('Palau', 'Oceania', 2019, None),
#  ('Palau', 'Oceania', 2020, Decimal('0.77')),
#  ('American Samoa', 'Oceania', 2015, None),
#  ('American Samoa', 'Oceania', 2016, None),
#  ('American Samoa', 'Oceania', 2017, None),
#  ('American Samoa', 'Oceania', 2018, None),
#  ('American Samoa', 'Oceania', 2019, None),
#  ('American Samoa', 'Oceania', 2020, None),
#  ('Cook Islands', 'Oceania', 2015, None),
#  ('Cook Islands', 'Oceania', 2016, None),
#  ('Cook Islands', 'Oceania', 2017, None),
#  ('Cook Islands', 'Oceania', 2018, None),
#  ('Cook Islands', 'Oceania', 2019, None),
#  ('Cook Islands', 'Oceania', 2020, None),
#  ('French Polynesia', 'Oceania', 2015, None),
#  ('French Polynesia', 'Oceania', 2016, None),
#  ('French Polynesia', 'Oceania', 2017, None),
#  ('French Polynesia', 'Oceania', 2018, None),
#  ('French Polynesia', 'Oceania', 2019, None),
#  ('French Polynesia', 'Oceania', 2020, None),
#  ('Niue', 'Oceania', 2015, None),
#  ('Niue', 'Oceania', 2016, None),
#  ('Niue', 'Oceania', 2017, None),
#  ('Niue', 'Oceania', 2018, None),
#  ('Niue', 'Oceania', 2019, None),
#  ('Niue', 'Oceania', 2020, None),
#  ('Samoa', 'Oceania', 2015, None),
#  ('Samoa', 'Oceania', 2016, None),
#  ('Samoa', 'Oceania', 2017, Decimal('9.40')),
#  ('Samoa', 'Oceania', 2018, None),
#  ('Samoa', 'Oceania', 2019, None),
#  ('Samoa', 'Oceania', 2020, None),
#  ('Tokelau', 'Oceania', 2015, None),
#  ('Tokelau', 'Oceania', 2016, None),
#  ('Tokelau', 'Oceania', 2017, None),
#  ('Tokelau', 'Oceania', 2018, None),
#  ('Tokelau', 'Oceania', 2019, None),
#  ('Tokelau', 'Oceania', 2020, None),
#  ('Tonga', 'Oceania', 2015, None),
#  ('Tonga', 'Oceania', 2016, None),
#  ('Tonga', 'Oceania', 2017, None),
#  ('Tonga', 'Oceania', 2018, Decimal('2.25')),
#  ('Tonga', 'Oceania', 2019, None),
#  ('Tonga', 'Oceania', 2020, None),
#  ('Tuvalu', 'Oceania', 2015, None),
#  ('Tuvalu', 'Oceania', 2016, Decimal('8.49')),
#  ('Tuvalu', 'Oceania', 2017, Decimal('26.55')),
#  ('Tuvalu', 'Oceania', 2018, None),
#  ('Tuvalu', 'Oceania', 2019, None),
#  ('Tuvalu', 'Oceania', 2020, None),
#  ('Wallis and Futuna Islands', 'Oceania', 2015, None),
#  ('Wallis and Futuna Islands', 'Oceania', 2016, None),
#  ('Wallis and Futuna Islands', 'Oceania', 2017, None),
#  ('Wallis and Futuna Islands', 'Oceania', 2018, None),
#  ('Wallis and Futuna Islands', 'Oceania', 2019, None),
#  ('Wallis and Futuna Islands', 'Oceania', 2020, None),
#  ('Burundi', 'Sub-Saharan Africa', 2015, None),
#  ('Burundi', 'Sub-Saharan Africa', 2016, None),
#  ('Burundi', 'Sub-Saharan Africa', 2017, None),
#  ('Burundi', 'Sub-Saharan Africa', 2018, None),
#  ('Burundi', 'Sub-Saharan Africa', 2019, None),
#  ('Burundi', 'Sub-Saharan Africa', 2020, Decimal('1.03')),
#  ('Comoros', 'Sub-Saharan Africa', 2015, None),
#  ('Comoros', 'Sub-Saharan Africa', 2016, None),
#  ('Comoros', 'Sub-Saharan Africa', 2017, None),
#  ('Comoros', 'Sub-Saharan Africa', 2018, None),
#  ('Comoros', 'Sub-Saharan Africa', 2019, None),
#  ('Djibouti', 'Sub-Saharan Africa', 2015, None),
#  ('Djibouti', 'Sub-Saharan Africa', 2016, None),
#  ('Djibouti', 'Sub-Saharan Africa', 2017, Decimal('26.06')),
#  ('Djibouti', 'Sub-Saharan Africa', 2018, None),
#  ('Djibouti', 'Sub-Saharan Africa', 2019, None),
#  ('Djibouti', 'Sub-Saharan Africa', 2020, None),
#  ('Eritrea', 'Sub-Saharan Africa', 2015, None),
#  ('Eritrea', 'Sub-Saharan Africa', 2016, None),
#  ('Ethiopia', 'Sub-Saharan Africa', 2015, None),
#  ('Ethiopia', 'Sub-Saharan Africa', 2016, None),
#  ('Ethiopia', 'Sub-Saharan Africa', 2017, None),
#  ('Ethiopia', 'Sub-Saharan Africa', 2018, None),
#  ('Ethiopia', 'Sub-Saharan Africa', 2019, None),
#  ('Ethiopia', 'Sub-Saharan Africa', 2020, None),
#  ('Kenya', 'Sub-Saharan Africa', 2015, None),
#  ('Kenya', 'Sub-Saharan Africa', 2016, Decimal('2.76')),
#  ('Kenya', 'Sub-Saharan Africa', 2017, None),
#  ('Kenya', 'Sub-Saharan Africa', 2018, None),
#  ('Kenya', 'Sub-Saharan Africa', 2019, Decimal('5.01')),
#  ('Kenya', 'Sub-Saharan Africa', 2020, None),
#  ('Madagascar', 'Sub-Saharan Africa', 2015, Decimal('1.79')),
#  ('Madagascar', 'Sub-Saharan Africa', 2016, None),
#  ('Madagascar', 'Sub-Saharan Africa', 2017, None),
#  ('Madagascar', 'Sub-Saharan Africa', 2018, None),
#  ('Madagascar', 'Sub-Saharan Africa', 2019, None),
#  ('Madagascar', 'Sub-Saharan Africa', 2020, None),
#  ('Malawi', 'Sub-Saharan Africa', 2015, None),
#  ('Malawi', 'Sub-Saharan Africa', 2016, None),
#  ('Malawi', 'Sub-Saharan Africa', 2017, Decimal('3.54')),
#  ('Malawi', 'Sub-Saharan Africa', 2018, None),
#  ('Malawi', 'Sub-Saharan Africa', 2019, None),
#  ('Malawi', 'Sub-Saharan Africa', 2020, Decimal('0.91')),
#  ('Mauritius', 'Sub-Saharan Africa', 2015, Decimal('7.41')),
#  ('Mauritius', 'Sub-Saharan Africa', 2016, Decimal('6.81')),
#  ('Mauritius', 'Sub-Saharan Africa', 2017, Decimal('6.75')),
#  ('Mauritius', 'Sub-Saharan Africa', 2018, Decimal('6.43')),
#  ('Mauritius', 'Sub-Saharan Africa', 2019, Decimal('6.33')),
#  ('Mauritius', 'Sub-Saharan Africa', 2020, Decimal('8.63')),
#  ('Mayotte', 'Sub-Saharan Africa', 2015, None),
#  ('Mayotte', 'Sub-Saharan Africa', 2016, None),
#  ('Mayotte', 'Sub-Saharan Africa', 2017, None),
#  ('Mayotte', 'Sub-Saharan Africa', 2018, None),
#  ('Mayotte', 'Sub-Saharan Africa', 2019, None),
#  ('Mayotte', 'Sub-Saharan Africa', 2020, None),
#  ('Mozambique', 'Sub-Saharan Africa', 2015, Decimal('3.43')),
#  ('Mozambique', 'Sub-Saharan Africa', 2016, None),
#  ('Mozambique', 'Sub-Saharan Africa', 2017, None),
#  ('Mozambique', 'Sub-Saharan Africa', 2018, None),
#  ('Mozambique', 'Sub-Saharan Africa', 2019, None),
#  ('Mozambique', 'Sub-Saharan Africa', 2020, None),
#  ('Rwanda', 'Sub-Saharan Africa', 2015, None),
#  ('Rwanda', 'Sub-Saharan Africa', 2016, None),
#  ('Rwanda', 'Sub-Saharan Africa', 2017, Decimal('11.88')),
#  ('Rwanda', 'Sub-Saharan Africa', 2018, Decimal('10.76')),
#  ('Rwanda', 'Sub-Saharan Africa', 2019, Decimal('11.24')),
#  ('Rwanda', 'Sub-Saharan Africa', 2020, Decimal('11.83')),
#  ('Réunion', 'Sub-Saharan Africa', 2015, None),
#  ('Réunion', 'Sub-Saharan Africa', 2016, None),
#  ('Réunion', 'Sub-Saharan Africa', 2017, None),
#  ('Réunion', 'Sub-Saharan Africa', 2018, None),
#  ('Réunion', 'Sub-Saharan Africa', 2019, None),
#  ('Réunion', 'Sub-Saharan Africa', 2020, None),
#  ('Seychelles', 'Sub-Saharan Africa', 2015, Decimal('4.15')),
#  ('Seychelles', 'Sub-Saharan Africa', 2016, Decimal('3.96')),
#  ('Seychelles', 'Sub-Saharan Africa', 2017, Decimal('3.71')),
#  ('Seychelles', 'Sub-Saharan Africa', 2018, Decimal('3.53')),
#  ('Seychelles', 'Sub-Saharan Africa', 2019, Decimal('2.97')),
#  ('Somalia', 'Sub-Saharan Africa', 2015, None),
#  ('Somalia', 'Sub-Saharan Africa', 2016, None),
#  ('Somalia', 'Sub-Saharan Africa', 2017, None),
#  ('Somalia', 'Sub-Saharan Africa', 2018, None),
#  ('Somalia', 'Sub-Saharan Africa', 2019, Decimal('18.83')),
#  ('Somalia', 'Sub-Saharan Africa', 2020, None),
#  ('South Sudan', 'Sub-Saharan Africa', 2015, None),
#  ('South Sudan', 'Sub-Saharan Africa', 2016, None),
#  ('South Sudan', 'Sub-Saharan Africa', 2017, None),
#  ('South Sudan', 'Sub-Saharan Africa', 2018, None),
#  ('South Sudan', 'Sub-Saharan Africa', 2019, None),
#  ('South Sudan', 'Sub-Saharan Africa', 2020, None),
#  ('Uganda', 'Sub-Saharan Africa', 2015, None),
#  ('Uganda', 'Sub-Saharan Africa', 2016, None),
#  ('Uganda', 'Sub-Saharan Africa', 2017, Decimal('3.64')),
#  ('Uganda', 'Sub-Saharan Africa', 2018, None),
#  ('Uganda', 'Sub-Saharan Africa', 2019, None),
#  ('Uganda', 'Sub-Saharan Africa', 2020, None),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', 2015, None),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', 2016, None),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', 2017, None),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', 2018, None),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', 2019, None),
#  ('United Republic of Tanzania', 'Sub-Saharan Africa', 2020, None),
#  ('Zambia', 'Sub-Saharan Africa', 2015, None),
#  ('Zambia', 'Sub-Saharan Africa', 2016, None),
#  ('Zambia', 'Sub-Saharan Africa', 2017, Decimal('8.52')),
#  ('Zambia', 'Sub-Saharan Africa', 2018, Decimal('5.03')),
#  ('Zambia', 'Sub-Saharan Africa', 2019, Decimal('5.54')),
#  ('Zambia', 'Sub-Saharan Africa', 2020, Decimal('6.03')),
#  ('Zimbabwe', 'Sub-Saharan Africa', 2015, None),
#  ('Zimbabwe', 'Sub-Saharan Africa', 2016, None),
#  ('Zimbabwe', 'Sub-Saharan Africa', 2017, None),
#  ('Zimbabwe', 'Sub-Saharan Africa', 2018, None),
#  ('Zimbabwe', 'Sub-Saharan Africa', 2019, Decimal('7.37')),
#  ('Zimbabwe', 'Sub-Saharan Africa', 2020, None),
#  ('Angola', 'Sub-Saharan Africa', 2015, None),
#  ('Angola', 'Sub-Saharan Africa', 2016, None),
#  ('Angola', 'Sub-Saharan Africa', 2017, None),
#  ('Angola', 'Sub-Saharan Africa', 2018, None),
#  ('Angola', 'Sub-Saharan Africa', 2019, Decimal('16.50')),
#  ('Angola', 'Sub-Saharan Africa', 2020, None),
#  ('Cameroon', 'Sub-Saharan Africa', 2015, None),
#  ('Cameroon', 'Sub-Saharan Africa', 2016, None),
#  ('Cameroon', 'Sub-Saharan Africa', 2017, None),
#  ('Cameroon', 'Sub-Saharan Africa', 2018, None),
#  ('Cameroon', 'Sub-Saharan Africa', 2019, None),
#  ('Cameroon', 'Sub-Saharan Africa', 2020, None),
#  ('Central African Republic', 'Sub-Saharan Africa', 2015, None),
#  ('Central African Republic', 'Sub-Saharan Africa', 2016, None),
#  ('Central African Republic', 'Sub-Saharan Africa', 2017, None),
#  ('Central African Republic', 'Sub-Saharan Africa', 2018, None),
#  ('Central African Republic', 'Sub-Saharan Africa', 2019, None),
#  ('Central African Republic', 'Sub-Saharan Africa', 2020, None),
#  ('Chad', 'Sub-Saharan Africa', 2015, None),
#  ('Chad', 'Sub-Saharan Africa', 2016, None),
#  ('Chad', 'Sub-Saharan Africa', 2017, None),
#  ('Chad', 'Sub-Saharan Africa', 2018, Decimal('1.13')),
#  ('Chad', 'Sub-Saharan Africa', 2019, None),
#  ('Chad', 'Sub-Saharan Africa', 2020, None),
#  ('Congo', 'Sub-Saharan Africa', 2015, None),
#  ('Congo', 'Sub-Saharan Africa', 2016, None),
#  ('Congo', 'Sub-Saharan Africa', 2017, None),
#  ('Congo', 'Sub-Saharan Africa', 2018, None),
#  ('Congo', 'Sub-Saharan Africa', 2019, None),
#  ('Congo', 'Sub-Saharan Africa', 2020, None),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', 2015, None),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', 2016, None),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', 2017, None),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', 2018, None),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', 2019, None),
#  ('Democratic Republic of the Congo', 'Sub-Saharan Africa', 2020, None),
#  ('Equatorial Guinea', 'Sub-Saharan Africa', 2015, None),
#  ('Equatorial Guinea', 'Sub-Saharan Africa', 2016, None),
#  ('Equatorial Guinea', 'Sub-Saharan Africa', 2017, None),
#  ('Gabon', 'Sub-Saharan Africa', 2015, None),
#  ('Gabon', 'Sub-Saharan Africa', 2016, None),
#  ('Gabon', 'Sub-Saharan Africa', 2017, None),
#  ('Gabon', 'Sub-Saharan Africa', 2018, None),
#  ('Gabon', 'Sub-Saharan Africa', 2019, None),
#  ('Gabon', 'Sub-Saharan Africa', 2020, None),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', 2015, None),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', 2016, None),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', 2017, None),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', 2018, None),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', 2019, None),
#  ('Sao Tome and Principe', 'Sub-Saharan Africa', 2020, None),
#  ('Botswana', 'Sub-Saharan Africa', 2015, None),
#  ('Botswana', 'Sub-Saharan Africa', 2016, None),
#  ('Botswana', 'Sub-Saharan Africa', 2017, None),
#  ('Botswana', 'Sub-Saharan Africa', 2018, None),
#  ('Botswana', 'Sub-Saharan Africa', 2019, Decimal('20.09')),
#  ('Botswana', 'Sub-Saharan Africa', 2020, Decimal('21.02')),
#  ('Eswatini', 'Sub-Saharan Africa', 2015, None),
#  ('Eswatini', 'Sub-Saharan Africa', 2016, Decimal('22.72')),
#  ('Eswatini', 'Sub-Saharan Africa', 2017, None),
#  ('Eswatini', 'Sub-Saharan Africa', 2018, None),
#  ('Eswatini', 'Sub-Saharan Africa', 2019, None),
#  ('Eswatini', 'Sub-Saharan Africa', 2020, None),
#  ('Lesotho', 'Sub-Saharan Africa', 2015, None),
#  ('Lesotho', 'Sub-Saharan Africa', 2016, None),
#  ('Lesotho', 'Sub-Saharan Africa', 2017, None),
#  ('Lesotho', 'Sub-Saharan Africa', 2018, None),
#  ('Lesotho', 'Sub-Saharan Africa', 2019, Decimal('16.88')),
#  ('Lesotho', 'Sub-Saharan Africa', 2020, None),
#  ('Namibia', 'Sub-Saharan Africa', 2015, None),
#  ('Namibia', 'Sub-Saharan Africa', 2016, Decimal('23.35')),
#  ('Namibia', 'Sub-Saharan Africa', 2017, None),
#  ('Namibia', 'Sub-Saharan Africa', 2018, Decimal('19.88')),
#  ('Namibia', 'Sub-Saharan Africa', 2019, None),
#  ('Namibia', 'Sub-Saharan Africa', 2020, None),
#  ('South Africa', 'Sub-Saharan Africa', 2015, Decimal('22.87')),
#  ('South Africa', 'Sub-Saharan Africa', 2016, Decimal('24.02')),
#  ('South Africa', 'Sub-Saharan Africa', 2017, Decimal('23.99')),
#  ('South Africa', 'Sub-Saharan Africa', 2018, Decimal('24.22')),
#  ('South Africa', 'Sub-Saharan Africa', 2019, Decimal('25.54')),
#  ('South Africa', 'Sub-Saharan Africa', 2020, Decimal('24.34')),
#  ('Benin', 'Sub-Saharan Africa', 2015, None),
#  ('Benin', 'Sub-Saharan Africa', 2016, None),
#  ('Benin', 'Sub-Saharan Africa', 2017, None),
#  ('Benin', 'Sub-Saharan Africa', 2018, Decimal('1.47')),
#  ('Benin', 'Sub-Saharan Africa', 2019, None),
#  ('Benin', 'Sub-Saharan Africa', 2020, None),
#  ('Burkina Faso', 'Sub-Saharan Africa', 2015, None),
#  ('Burkina Faso', 'Sub-Saharan Africa', 2016, None),
#  ('Burkina Faso', 'Sub-Saharan Africa', 2017, None),
#  ('Burkina Faso', 'Sub-Saharan Africa', 2018, Decimal('4.69')),
#  ('Burkina Faso', 'Sub-Saharan Africa', 2019, None),
#  ('Burkina Faso', 'Sub-Saharan Africa', 2020, None),
#  ('Cabo Verde', 'Sub-Saharan Africa', 2015, Decimal('31.31')),
#  ('Cabo Verde', 'Sub-Saharan Africa', 2016, None),
#  ('Cabo Verde', 'Sub-Saharan Africa', 2017, Decimal('12.24')),
#  ('Cabo Verde', 'Sub-Saharan Africa', 2018, Decimal('12.17')),
#  ('Cabo Verde', 'Sub-Saharan Africa', 2019, Decimal('11.29')),
#  ('Cabo Verde', 'Sub-Saharan Africa', 2020, None),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', 2015, None),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', 2016, None),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', 2017, None),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', 2018, None),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', 2019, None),
#  ("Côte d'Ivoire", 'Sub-Saharan Africa', 2020, None),
#  ('Gambia', 'Sub-Saharan Africa', 2015, None),
#  ('Gambia', 'Sub-Saharan Africa', 2016, None),
#  ('Gambia', 'Sub-Saharan Africa', 2017, None),
#  ('Gambia', 'Sub-Saharan Africa', 2018, None),
#  ('Gambia', 'Sub-Saharan Africa', 2019, None),
#  ('Gambia', 'Sub-Saharan Africa', 2020, None),
#  ('Ghana', 'Sub-Saharan Africa', 2015, Decimal('6.81')),
#  ('Ghana', 'Sub-Saharan Africa', 2016, None),
#  ('Ghana', 'Sub-Saharan Africa', 2017, Decimal('3.37')),
#  ('Ghana', 'Sub-Saharan Africa', 2018, None),
#  ('Ghana', 'Sub-Saharan Africa', 2019, None),
#  ('Ghana', 'Sub-Saharan Africa', 2020, None),
#  ('Guinea', 'Sub-Saharan Africa', 2015, None),
#  ('Guinea', 'Sub-Saharan Africa', 2016, None),
#  ('Guinea', 'Sub-Saharan Africa', 2017, None),
#  ('Guinea', 'Sub-Saharan Africa', 2018, None),
#  ('Guinea', 'Sub-Saharan Africa', 2019, Decimal('5.02')),
#  ('Guinea', 'Sub-Saharan Africa', 2020, None),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', 2015, None),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', 2016, None),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', 2017, None),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', 2019, None),
#  ('Guinea-Bissau', 'Sub-Saharan Africa', 2020, None),
#  ('Liberia', 'Sub-Saharan Africa', 2015, None),
#  ('Liberia', 'Sub-Saharan Africa', 2016, Decimal('3.08')),
#  ('Liberia', 'Sub-Saharan Africa', 2017, Decimal('5.95')),
#  ('Liberia', 'Sub-Saharan Africa', 2018, None),
#  ('Liberia', 'Sub-Saharan Africa', 2019, None),
#  ('Liberia', 'Sub-Saharan Africa', 2020, None),
#  ...]

# %% [markdown]
# ###  Task 2 — Filter for Sub-Saharan Africa
# Next, we filter our joined dataset to only include countries located in **Sub-Saharan Africa**.
# The resulting table should display `Country_name`, `Time_period`, and `Pct_unemployment`.

# %%
# %%sql
#
# SELECT
#     g.Country_name,
#     e.Time_period,
#     e.Pct_unemployment
# FROM
#     united_nations.Economic_Indicators AS e
# JOIN
#     united_nations.Geographic_Location AS g
# ON
#     e.Country_name = g.Country_name
# WHERE
#     g.Region = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Burundi', 2015, None),
#  ('Burundi', 2016, None),
#  ('Burundi', 2017, None),
#  ('Burundi', 2018, None),
#  ('Burundi', 2019, None),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Comoros', 2015, None),
#  ('Comoros', 2016, None),
#  ('Comoros', 2017, None),
#  ('Comoros', 2018, None),
#  ('Comoros', 2019, None),
#  ('Djibouti', 2015, None),
#  ('Djibouti', 2016, None),
#  ('Djibouti', 2017, Decimal('26.06')),
#  ('Djibouti', 2018, None),
#  ('Djibouti', 2019, None),
#  ('Djibouti', 2020, None),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Ethiopia', 2015, None),
#  ('Ethiopia', 2016, None),
#  ('Ethiopia', 2017, None),
#  ('Ethiopia', 2018, None),
#  ('Ethiopia', 2019, None),
#  ('Ethiopia', 2020, None),
#  ('Kenya', 2015, None),
#  ('Kenya', 2016, Decimal('2.76')),
#  ('Kenya', 2017, None),
#  ('Kenya', 2018, None),
#  ('Kenya', 2019, Decimal('5.01')),
#  ('Kenya', 2020, None),
#  ('Madagascar', 2015, Decimal('1.79')),
#  ('Madagascar', 2016, None),
#  ('Madagascar', 2017, None),
#  ('Madagascar', 2018, None),
#  ('Madagascar', 2019, None),
#  ('Madagascar', 2020, None),
#  ('Malawi', 2015, None),
#  ('Malawi', 2016, None),
#  ('Malawi', 2017, Decimal('3.54')),
#  ('Malawi', 2018, None),
#  ('Malawi', 2019, None),
#  ('Malawi', 2020, Decimal('0.91')),
#  ('Mauritius', 2015, Decimal('7.41')),
#  ('Mauritius', 2016, Decimal('6.81')),
#  ('Mauritius', 2017, Decimal('6.75')),
#  ('Mauritius', 2018, Decimal('6.43')),
#  ('Mauritius', 2019, Decimal('6.33')),
#  ('Mauritius', 2020, Decimal('8.63')),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, Decimal('3.43')),
#  ('Mozambique', 2016, None),
#  ('Mozambique', 2017, None),
#  ('Mozambique', 2018, None),
#  ('Mozambique', 2019, None),
#  ('Mozambique', 2020, None),
#  ('Rwanda', 2015, None),
#  ('Rwanda', 2016, None),
#  ('Rwanda', 2017, Decimal('11.88')),
#  ('Rwanda', 2018, Decimal('10.76')),
#  ('Rwanda', 2019, Decimal('11.24')),
#  ('Rwanda', 2020, Decimal('11.83')),
#  ('Réunion', 2015, None),
#  ('Réunion', 2016, None),
#  ('Réunion', 2017, None),
#  ('Réunion', 2018, None),
#  ('Réunion', 2019, None),
#  ('Réunion', 2020, None),
#  ('Seychelles', 2015, Decimal('4.15')),
#  ('Seychelles', 2016, Decimal('3.96')),
#  ('Seychelles', 2017, Decimal('3.71')),
#  ('Seychelles', 2018, Decimal('3.53')),
#  ('Seychelles', 2019, Decimal('2.97')),
#  ('Somalia', 2015, None),
#  ('Somalia', 2016, None),
#  ('Somalia', 2017, None),
#  ('Somalia', 2018, None),
#  ('Somalia', 2019, Decimal('18.83')),
#  ('Somalia', 2020, None),
#  ('South Sudan', 2015, None),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Uganda', 2015, None),
#  ('Uganda', 2016, None),
#  ('Uganda', 2017, Decimal('3.64')),
#  ('Uganda', 2018, None),
#  ('Uganda', 2019, None),
#  ('Uganda', 2020, None),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, None),
#  ('Zambia', 2016, None),
#  ('Zambia', 2017, Decimal('8.52')),
#  ('Zambia', 2018, Decimal('5.03')),
#  ('Zambia', 2019, Decimal('5.54')),
#  ('Zambia', 2020, Decimal('6.03')),
#  ('Zimbabwe', 2015, None),
#  ('Zimbabwe', 2016, None),
#  ('Zimbabwe', 2017, None),
#  ('Zimbabwe', 2018, None),
#  ('Zimbabwe', 2019, Decimal('7.37')),
#  ('Zimbabwe', 2020, None),
#  ('Angola', 2015, None),
#  ('Angola', 2016, None),
#  ('Angola', 2017, None),
#  ('Angola', 2018, None),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, None),
#  ('Cameroon', 2015, None),
#  ('Cameroon', 2016, None),
#  ('Cameroon', 2017, None),
#  ('Cameroon', 2018, None),
#  ('Cameroon', 2019, None),
#  ('Cameroon', 2020, None),
#  ('Central African Republic', 2015, None),
#  ('Central African Republic', 2016, None),
#  ('Central African Republic', 2017, None),
#  ('Central African Republic', 2018, None),
#  ('Central African Republic', 2019, None),
#  ('Central African Republic', 2020, None),
#  ('Chad', 2015, None),
#  ('Chad', 2016, None),
#  ('Chad', 2017, None),
#  ('Chad', 2018, Decimal('1.13')),
#  ('Chad', 2019, None),
#  ('Chad', 2020, None),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Equatorial Guinea', 2015, None),
#  ('Equatorial Guinea', 2016, None),
#  ('Equatorial Guinea', 2017, None),
#  ('Gabon', 2015, None),
#  ('Gabon', 2016, None),
#  ('Gabon', 2017, None),
#  ('Gabon', 2018, None),
#  ('Gabon', 2019, None),
#  ('Gabon', 2020, None),
#  ('Sao Tome and Principe', 2015, None),
#  ('Sao Tome and Principe', 2016, None),
#  ('Sao Tome and Principe', 2017, None),
#  ('Sao Tome and Principe', 2018, None),
#  ('Sao Tome and Principe', 2019, None),
#  ('Sao Tome and Principe', 2020, None),
#  ('Botswana', 2015, None),
#  ('Botswana', 2016, None),
#  ('Botswana', 2017, None),
#  ('Botswana', 2018, None),
#  ('Botswana', 2019, Decimal('20.09')),
#  ('Botswana', 2020, Decimal('21.02')),
#  ('Eswatini', 2015, None),
#  ('Eswatini', 2016, Decimal('22.72')),
#  ('Eswatini', 2017, None),
#  ('Eswatini', 2018, None),
#  ('Eswatini', 2019, None),
#  ('Eswatini', 2020, None),
#  ('Lesotho', 2015, None),
#  ('Lesotho', 2016, None),
#  ('Lesotho', 2017, None),
#  ('Lesotho', 2018, None),
#  ('Lesotho', 2019, Decimal('16.88')),
#  ('Lesotho', 2020, None),
#  ('Namibia', 2015, None),
#  ('Namibia', 2016, Decimal('23.35')),
#  ('Namibia', 2017, None),
#  ('Namibia', 2018, Decimal('19.88')),
#  ('Namibia', 2019, None),
#  ('Namibia', 2020, None),
#  ('South Africa', 2015, Decimal('22.87')),
#  ('South Africa', 2016, Decimal('24.02')),
#  ('South Africa', 2017, Decimal('23.99')),
#  ('South Africa', 2018, Decimal('24.22')),
#  ('South Africa', 2019, Decimal('25.54')),
#  ('South Africa', 2020, Decimal('24.34')),
#  ('Benin', 2015, None),
#  ('Benin', 2016, None),
#  ('Benin', 2017, None),
#  ('Benin', 2018, Decimal('1.47')),
#  ('Benin', 2019, None),
#  ('Benin', 2020, None),
#  ('Burkina Faso', 2015, None),
#  ('Burkina Faso', 2016, None),
#  ('Burkina Faso', 2017, None),
#  ('Burkina Faso', 2018, Decimal('4.69')),
#  ('Burkina Faso', 2019, None),
#  ('Burkina Faso', 2020, None),
#  ('Cabo Verde', 2015, Decimal('31.31')),
#  ('Cabo Verde', 2016, None),
#  ('Cabo Verde', 2017, Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('11.29')),
#  ('Cabo Verde', 2020, None),
#  ("Côte d'Ivoire", 2015, None),
#  ("Côte d'Ivoire", 2016, None),
#  ("Côte d'Ivoire", 2017, None),
#  ("Côte d'Ivoire", 2018, None),
#  ("Côte d'Ivoire", 2019, None),
#  ("Côte d'Ivoire", 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, Decimal('6.81')),
#  ('Ghana', 2016, None),
#  ('Ghana', 2017, Decimal('3.37')),
#  ('Ghana', 2018, None),
#  ('Ghana', 2019, None),
#  ('Ghana', 2020, None),
#  ('Guinea', 2015, None),
#  ('Guinea', 2016, None),
#  ('Guinea', 2017, None),
#  ('Guinea', 2018, None),
#  ('Guinea', 2019, Decimal('5.02')),
#  ('Guinea', 2020, None),
#  ('Guinea-Bissau', 2015, None),
#  ('Guinea-Bissau', 2016, None),
#  ('Guinea-Bissau', 2017, None),
#  ('Guinea-Bissau', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 2019, None),
#  ('Guinea-Bissau', 2020, None),
#  ('Liberia', 2015, None),
#  ('Liberia', 2016, Decimal('3.08')),
#  ('Liberia', 2017, Decimal('5.95')),
#  ('Liberia', 2018, None),
#  ('Liberia', 2019, None),
#  ('Liberia', 2020, None),
#  ('Mali', 2015, Decimal('7.73')),
#  ('Mali', 2016, Decimal('1.37')),
#  ('Mali', 2017, Decimal('7.41')),
#  ('Mali', 2018, Decimal('1.62')),
#  ('Mali', 2019, None),
#  ('Mali', 2020, Decimal('3.53')),
#  ('Mauritania', 2015, None),
#  ('Mauritania', 2016, None),
#  ('Mauritania', 2017, Decimal('10.34')),
#  ('Mauritania', 2018, None),
#  ('Mauritania', 2019, Decimal('10.42')),
#  ('Mauritania', 2020, None),
#  ('Niger', 2015, None),
#  ('Niger', 2016, None),
#  ('Niger', 2017, Decimal('7.77')),
#  ('Niger', 2018, None),
#  ('Niger', 2019, None),
#  ('Niger', 2020, None),
#  ('Nigeria', 2015, Decimal('4.31')),
#  ('Nigeria', 2016, Decimal('7.06')),
#  ('Nigeria', 2017, Decimal('8.39')),
#  ('Nigeria', 2018, None),
#  ('Nigeria', 2019, Decimal('10.70')),
#  ('Nigeria', 2020, None),
#  ('Saint Helena', 2015, None),
#  ('Saint Helena', 2016, None),
#  ('Saint Helena', 2017, None),
#  ('Saint Helena', 2018, None),
#  ('Saint Helena', 2019, None),
#  ('Saint Helena', 2020, None),
#  ('Senegal', 2015, Decimal('6.76')),
#  ('Senegal', 2016, Decimal('4.46')),
#  ('Senegal', 2017, Decimal('4.08')),
#  ('Senegal', 2018, Decimal('3.57')),
#  ('Senegal', 2019, Decimal('2.86')),
#  ('Senegal', 2020, None),
#  ('Sierra Leone', 2015, None),
#  ('Sierra Leone', 2016, None),
#  ('Sierra Leone', 2017, None),
#  ('Sierra Leone', 2018, Decimal('3.19')),
#  ('Sierra Leone', 2019, None),
#  ('Sierra Leone', 2020, None),
#  ('Togo', 2015, Decimal('2.20')),
#  ('Togo', 2016, None),
#  ('Togo', 2017, Decimal('3.74')),
#  ('Togo', 2018, None),
#  ('Togo', 2019, None),
#  ('Togo', 2020, None)]

# %% [markdown]
# ###  Task 3 — Impute None Values
# Some countries may have missing unemployment data.
# We will **replace None values** in the `Pct_unemployment` column with a default value of `33.65` and rename the new column as `Pct_unemployment_imputed`.

# %%
# %%sql
#
# SELECT
#     g.Country_name,
#     e.Time_period,
#     COALESCE(e.Pct_unemployment, 33.65) AS Pct_unemployment_imputed
# FROM
#     united_nations.Economic_Indicators AS e
# JOIN
#     united_nations.Geographic_Location AS g
# ON
#     e.Country_name = g.Country_name
# WHERE
#     g.Region = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Burundi', 2015, Decimal('33.65')),
#  ('Burundi', 2016, Decimal('33.65')),
#  ('Burundi', 2017, Decimal('33.65')),
#  ('Burundi', 2018, Decimal('33.65')),
#  ('Burundi', 2019, Decimal('33.65')),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Comoros', 2015, Decimal('33.65')),
#  ('Comoros', 2016, Decimal('33.65')),
#  ('Comoros', 2017, Decimal('33.65')),
#  ('Comoros', 2018, Decimal('33.65')),
#  ('Comoros', 2019, Decimal('33.65')),
#  ('Djibouti', 2015, Decimal('33.65')),
#  ('Djibouti', 2016, Decimal('33.65')),
#  ('Djibouti', 2017, Decimal('26.06')),
#  ('Djibouti', 2018, Decimal('33.65')),
#  ('Djibouti', 2019, Decimal('33.65')),
#  ('Djibouti', 2020, Decimal('33.65')),
#  ('Eritrea', 2015, Decimal('33.65')),
#  ('Eritrea', 2016, Decimal('33.65')),
#  ('Ethiopia', 2015, Decimal('33.65')),
#  ('Ethiopia', 2016, Decimal('33.65')),
#  ('Ethiopia', 2017, Decimal('33.65')),
#  ('Ethiopia', 2018, Decimal('33.65')),
#  ('Ethiopia', 2019, Decimal('33.65')),
#  ('Ethiopia', 2020, Decimal('33.65')),
#  ('Kenya', 2015, Decimal('33.65')),
#  ('Kenya', 2016, Decimal('2.76')),
#  ('Kenya', 2017, Decimal('33.65')),
#  ('Kenya', 2018, Decimal('33.65')),
#  ('Kenya', 2019, Decimal('5.01')),
#  ('Kenya', 2020, Decimal('33.65')),
#  ('Madagascar', 2015, Decimal('1.79')),
#  ('Madagascar', 2016, Decimal('33.65')),
#  ('Madagascar', 2017, Decimal('33.65')),
#  ('Madagascar', 2018, Decimal('33.65')),
#  ('Madagascar', 2019, Decimal('33.65')),
#  ('Madagascar', 2020, Decimal('33.65')),
#  ('Malawi', 2015, Decimal('33.65')),
#  ('Malawi', 2016, Decimal('33.65')),
#  ('Malawi', 2017, Decimal('3.54')),
#  ('Malawi', 2018, Decimal('33.65')),
#  ('Malawi', 2019, Decimal('33.65')),
#  ('Malawi', 2020, Decimal('0.91')),
#  ('Mauritius', 2015, Decimal('7.41')),
#  ('Mauritius', 2016, Decimal('6.81')),
#  ('Mauritius', 2017, Decimal('6.75')),
#  ('Mauritius', 2018, Decimal('6.43')),
#  ('Mauritius', 2019, Decimal('6.33')),
#  ('Mauritius', 2020, Decimal('8.63')),
#  ('Mayotte', 2015, Decimal('33.65')),
#  ('Mayotte', 2016, Decimal('33.65')),
#  ('Mayotte', 2017, Decimal('33.65')),
#  ('Mayotte', 2018, Decimal('33.65')),
#  ('Mayotte', 2019, Decimal('33.65')),
#  ('Mayotte', 2020, Decimal('33.65')),
#  ('Mozambique', 2015, Decimal('3.43')),
#  ('Mozambique', 2016, Decimal('33.65')),
#  ('Mozambique', 2017, Decimal('33.65')),
#  ('Mozambique', 2018, Decimal('33.65')),
#  ('Mozambique', 2019, Decimal('33.65')),
#  ('Mozambique', 2020, Decimal('33.65')),
#  ('Rwanda', 2015, Decimal('33.65')),
#  ('Rwanda', 2016, Decimal('33.65')),
#  ('Rwanda', 2017, Decimal('11.88')),
#  ('Rwanda', 2018, Decimal('10.76')),
#  ('Rwanda', 2019, Decimal('11.24')),
#  ('Rwanda', 2020, Decimal('11.83')),
#  ('Réunion', 2015, Decimal('33.65')),
#  ('Réunion', 2016, Decimal('33.65')),
#  ('Réunion', 2017, Decimal('33.65')),
#  ('Réunion', 2018, Decimal('33.65')),
#  ('Réunion', 2019, Decimal('33.65')),
#  ('Réunion', 2020, Decimal('33.65')),
#  ('Seychelles', 2015, Decimal('4.15')),
#  ('Seychelles', 2016, Decimal('3.96')),
#  ('Seychelles', 2017, Decimal('3.71')),
#  ('Seychelles', 2018, Decimal('3.53')),
#  ('Seychelles', 2019, Decimal('2.97')),
#  ('Somalia', 2015, Decimal('33.65')),
#  ('Somalia', 2016, Decimal('33.65')),
#  ('Somalia', 2017, Decimal('33.65')),
#  ('Somalia', 2018, Decimal('33.65')),
#  ('Somalia', 2019, Decimal('18.83')),
#  ('Somalia', 2020, Decimal('33.65')),
#  ('South Sudan', 2015, Decimal('33.65')),
#  ('South Sudan', 2016, Decimal('33.65')),
#  ('South Sudan', 2017, Decimal('33.65')),
#  ('South Sudan', 2018, Decimal('33.65')),
#  ('South Sudan', 2019, Decimal('33.65')),
#  ('South Sudan', 2020, Decimal('33.65')),
#  ('Uganda', 2015, Decimal('33.65')),
#  ('Uganda', 2016, Decimal('33.65')),
#  ('Uganda', 2017, Decimal('3.64')),
#  ('Uganda', 2018, Decimal('33.65')),
#  ('Uganda', 2019, Decimal('33.65')),
#  ('Uganda', 2020, Decimal('33.65')),
#  ('United Republic of Tanzania', 2015, Decimal('33.65')),
#  ('United Republic of Tanzania', 2016, Decimal('33.65')),
#  ('United Republic of Tanzania', 2017, Decimal('33.65')),
#  ('United Republic of Tanzania', 2018, Decimal('33.65')),
#  ('United Republic of Tanzania', 2019, Decimal('33.65')),
#  ('United Republic of Tanzania', 2020, Decimal('33.65')),
#  ('Zambia', 2015, Decimal('33.65')),
#  ('Zambia', 2016, Decimal('33.65')),
#  ('Zambia', 2017, Decimal('8.52')),
#  ('Zambia', 2018, Decimal('5.03')),
#  ('Zambia', 2019, Decimal('5.54')),
#  ('Zambia', 2020, Decimal('6.03')),
#  ('Zimbabwe', 2015, Decimal('33.65')),
#  ('Zimbabwe', 2016, Decimal('33.65')),
#  ('Zimbabwe', 2017, Decimal('33.65')),
#  ('Zimbabwe', 2018, Decimal('33.65')),
#  ('Zimbabwe', 2019, Decimal('7.37')),
#  ('Zimbabwe', 2020, Decimal('33.65')),
#  ('Angola', 2015, Decimal('33.65')),
#  ('Angola', 2016, Decimal('33.65')),
#  ('Angola', 2017, Decimal('33.65')),
#  ('Angola', 2018, Decimal('33.65')),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, Decimal('33.65')),
#  ('Cameroon', 2015, Decimal('33.65')),
#  ('Cameroon', 2016, Decimal('33.65')),
#  ('Cameroon', 2017, Decimal('33.65')),
#  ('Cameroon', 2018, Decimal('33.65')),
#  ('Cameroon', 2019, Decimal('33.65')),
#  ('Cameroon', 2020, Decimal('33.65')),
#  ('Central African Republic', 2015, Decimal('33.65')),
#  ('Central African Republic', 2016, Decimal('33.65')),
#  ('Central African Republic', 2017, Decimal('33.65')),
#  ('Central African Republic', 2018, Decimal('33.65')),
#  ('Central African Republic', 2019, Decimal('33.65')),
#  ('Central African Republic', 2020, Decimal('33.65')),
#  ('Chad', 2015, Decimal('33.65')),
#  ('Chad', 2016, Decimal('33.65')),
#  ('Chad', 2017, Decimal('33.65')),
#  ('Chad', 2018, Decimal('1.13')),
#  ('Chad', 2019, Decimal('33.65')),
#  ('Chad', 2020, Decimal('33.65')),
#  ('Congo', 2015, Decimal('33.65')),
#  ('Congo', 2016, Decimal('33.65')),
#  ('Congo', 2017, Decimal('33.65')),
#  ('Congo', 2018, Decimal('33.65')),
#  ('Congo', 2019, Decimal('33.65')),
#  ('Congo', 2020, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2015, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2016, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2017, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2018, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2019, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2020, Decimal('33.65')),
#  ('Equatorial Guinea', 2015, Decimal('33.65')),
#  ('Equatorial Guinea', 2016, Decimal('33.65')),
#  ('Equatorial Guinea', 2017, Decimal('33.65')),
#  ('Gabon', 2015, Decimal('33.65')),
#  ('Gabon', 2016, Decimal('33.65')),
#  ('Gabon', 2017, Decimal('33.65')),
#  ('Gabon', 2018, Decimal('33.65')),
#  ('Gabon', 2019, Decimal('33.65')),
#  ('Gabon', 2020, Decimal('33.65')),
#  ('Sao Tome and Principe', 2015, Decimal('33.65')),
#  ('Sao Tome and Principe', 2016, Decimal('33.65')),
#  ('Sao Tome and Principe', 2017, Decimal('33.65')),
#  ('Sao Tome and Principe', 2018, Decimal('33.65')),
#  ('Sao Tome and Principe', 2019, Decimal('33.65')),
#  ('Sao Tome and Principe', 2020, Decimal('33.65')),
#  ('Botswana', 2015, Decimal('33.65')),
#  ('Botswana', 2016, Decimal('33.65')),
#  ('Botswana', 2017, Decimal('33.65')),
#  ('Botswana', 2018, Decimal('33.65')),
#  ('Botswana', 2019, Decimal('20.09')),
#  ('Botswana', 2020, Decimal('21.02')),
#  ('Eswatini', 2015, Decimal('33.65')),
#  ('Eswatini', 2016, Decimal('22.72')),
#  ('Eswatini', 2017, Decimal('33.65')),
#  ('Eswatini', 2018, Decimal('33.65')),
#  ('Eswatini', 2019, Decimal('33.65')),
#  ('Eswatini', 2020, Decimal('33.65')),
#  ('Lesotho', 2015, Decimal('33.65')),
#  ('Lesotho', 2016, Decimal('33.65')),
#  ('Lesotho', 2017, Decimal('33.65')),
#  ('Lesotho', 2018, Decimal('33.65')),
#  ('Lesotho', 2019, Decimal('16.88')),
#  ('Lesotho', 2020, Decimal('33.65')),
#  ('Namibia', 2015, Decimal('33.65')),
#  ('Namibia', 2016, Decimal('23.35')),
#  ('Namibia', 2017, Decimal('33.65')),
#  ('Namibia', 2018, Decimal('19.88')),
#  ('Namibia', 2019, Decimal('33.65')),
#  ('Namibia', 2020, Decimal('33.65')),
#  ('South Africa', 2015, Decimal('22.87')),
#  ('South Africa', 2016, Decimal('24.02')),
#  ('South Africa', 2017, Decimal('23.99')),
#  ('South Africa', 2018, Decimal('24.22')),
#  ('South Africa', 2019, Decimal('25.54')),
#  ('South Africa', 2020, Decimal('24.34')),
#  ('Benin', 2015, Decimal('33.65')),
#  ('Benin', 2016, Decimal('33.65')),
#  ('Benin', 2017, Decimal('33.65')),
#  ('Benin', 2018, Decimal('1.47')),
#  ('Benin', 2019, Decimal('33.65')),
#  ('Benin', 2020, Decimal('33.65')),
#  ('Burkina Faso', 2015, Decimal('33.65')),
#  ('Burkina Faso', 2016, Decimal('33.65')),
#  ('Burkina Faso', 2017, Decimal('33.65')),
#  ('Burkina Faso', 2018, Decimal('4.69')),
#  ('Burkina Faso', 2019, Decimal('33.65')),
#  ('Burkina Faso', 2020, Decimal('33.65')),
#  ('Cabo Verde', 2015, Decimal('31.31')),
#  ('Cabo Verde', 2016, Decimal('33.65')),
#  ('Cabo Verde', 2017, Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('11.29')),
#  ('Cabo Verde', 2020, Decimal('33.65')),
#  ("Côte d'Ivoire", 2015, Decimal('33.65')),
#  ("Côte d'Ivoire", 2016, Decimal('33.65')),
#  ("Côte d'Ivoire", 2017, Decimal('33.65')),
#  ("Côte d'Ivoire", 2018, Decimal('33.65')),
#  ("Côte d'Ivoire", 2019, Decimal('33.65')),
#  ("Côte d'Ivoire", 2020, Decimal('33.65')),
#  ('Gambia', 2015, Decimal('33.65')),
#  ('Gambia', 2016, Decimal('33.65')),
#  ('Gambia', 2017, Decimal('33.65')),
#  ('Gambia', 2018, Decimal('33.65')),
#  ('Gambia', 2019, Decimal('33.65')),
#  ('Gambia', 2020, Decimal('33.65')),
#  ('Ghana', 2015, Decimal('6.81')),
#  ('Ghana', 2016, Decimal('33.65')),
#  ('Ghana', 2017, Decimal('3.37')),
#  ('Ghana', 2018, Decimal('33.65')),
#  ('Ghana', 2019, Decimal('33.65')),
#  ('Ghana', 2020, Decimal('33.65')),
#  ('Guinea', 2015, Decimal('33.65')),
#  ('Guinea', 2016, Decimal('33.65')),
#  ('Guinea', 2017, Decimal('33.65')),
#  ('Guinea', 2018, Decimal('33.65')),
#  ('Guinea', 2019, Decimal('5.02')),
#  ('Guinea', 2020, Decimal('33.65')),
#  ('Guinea-Bissau', 2015, Decimal('33.65')),
#  ('Guinea-Bissau', 2016, Decimal('33.65')),
#  ('Guinea-Bissau', 2017, Decimal('33.65')),
#  ('Guinea-Bissau', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 2019, Decimal('33.65')),
#  ('Guinea-Bissau', 2020, Decimal('33.65')),
#  ('Liberia', 2015, Decimal('33.65')),
#  ('Liberia', 2016, Decimal('3.08')),
#  ('Liberia', 2017, Decimal('5.95')),
#  ('Liberia', 2018, Decimal('33.65')),
#  ('Liberia', 2019, Decimal('33.65')),
#  ('Liberia', 2020, Decimal('33.65')),
#  ('Mali', 2015, Decimal('7.73')),
#  ('Mali', 2016, Decimal('1.37')),
#  ('Mali', 2017, Decimal('7.41')),
#  ('Mali', 2018, Decimal('1.62')),
#  ('Mali', 2019, Decimal('33.65')),
#  ('Mali', 2020, Decimal('3.53')),
#  ('Mauritania', 2015, Decimal('33.65')),
#  ('Mauritania', 2016, Decimal('33.65')),
#  ('Mauritania', 2017, Decimal('10.34')),
#  ('Mauritania', 2018, Decimal('33.65')),
#  ('Mauritania', 2019, Decimal('10.42')),
#  ('Mauritania', 2020, Decimal('33.65')),
#  ('Niger', 2015, Decimal('33.65')),
#  ('Niger', 2016, Decimal('33.65')),
#  ('Niger', 2017, Decimal('7.77')),
#  ('Niger', 2018, Decimal('33.65')),
#  ('Niger', 2019, Decimal('33.65')),
#  ('Niger', 2020, Decimal('33.65')),
#  ('Nigeria', 2015, Decimal('4.31')),
#  ('Nigeria', 2016, Decimal('7.06')),
#  ('Nigeria', 2017, Decimal('8.39')),
#  ('Nigeria', 2018, Decimal('33.65')),
#  ('Nigeria', 2019, Decimal('10.70')),
#  ('Nigeria', 2020, Decimal('33.65')),
#  ('Saint Helena', 2015, Decimal('33.65')),
#  ('Saint Helena', 2016, Decimal('33.65')),
#  ('Saint Helena', 2017, Decimal('33.65')),
#  ('Saint Helena', 2018, Decimal('33.65')),
#  ('Saint Helena', 2019, Decimal('33.65')),
#  ('Saint Helena', 2020, Decimal('33.65')),
#  ('Senegal', 2015, Decimal('6.76')),
#  ('Senegal', 2016, Decimal('4.46')),
#  ('Senegal', 2017, Decimal('4.08')),
#  ('Senegal', 2018, Decimal('3.57')),
#  ('Senegal', 2019, Decimal('2.86')),
#  ('Senegal', 2020, Decimal('33.65')),
#  ('Sierra Leone', 2015, Decimal('33.65')),
#  ('Sierra Leone', 2016, Decimal('33.65')),
#  ('Sierra Leone', 2017, Decimal('33.65')),
#  ('Sierra Leone', 2018, Decimal('3.19')),
#  ('Sierra Leone', 2019, Decimal('33.65')),
#  ('Sierra Leone', 2020, Decimal('33.65')),
#  ('Togo', 2015, Decimal('2.20')),
#  ('Togo', 2016, Decimal('33.65')),
#  ('Togo', 2017, Decimal('3.74')),
#  ('Togo', 2018, Decimal('33.65')),
#  ('Togo', 2019, Decimal('33.65')),
#  ('Togo', 2020, Decimal('33.65'))]

# %% [markdown]
# ###  Task 4 — Create a VIEW
# Now that we have our full query, let’s create a **VIEW** to store it for easy reference and reusability.
# We’ll name the view `Country_Unemployment_Rate` under the `united_nations` schema.

# %%
# %%sql
#
# CREATE OR REPLACE VIEW united_nations.Country_Unemployment_Rate AS
# SELECT
#     g.Country_name,
#     e.Time_period,
#     COALESCE(e.Pct_unemployment, 33.65) AS Pct_unemployment_imputed
# FROM
#     united_nations.Economic_Indicators AS e
# JOIN
#     united_nations.Geographic_Location AS g
# ON
#     e.Country_name = g.Country_name
# WHERE
#     g.Region = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ###  Task 5 — View the Data from Our Created VIEW
# Finally, we’ll retrieve and display data from the newly created view `Country_Unemployment_Rate` to confirm that it was created successfully.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     united_nations.Country_Unemployment_Rate
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Burundi', 2015, Decimal('33.65')),
#  ('Burundi', 2016, Decimal('33.65')),
#  ('Burundi', 2017, Decimal('33.65')),
#  ('Burundi', 2018, Decimal('33.65')),
#  ('Burundi', 2019, Decimal('33.65')),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Comoros', 2015, Decimal('33.65')),
#  ('Comoros', 2016, Decimal('33.65')),
#  ('Comoros', 2017, Decimal('33.65')),
#  ('Comoros', 2018, Decimal('33.65'))]

# %% [markdown]
# ##  Summary
#
# In this notebook, we successfully performed a series of SQL operations to analyze unemployment data across different regions.
#
# - We **joined** the `Economic_Indicators` table with the `Geographic_Locations` table to combine economic and regional data.
# - This join enabled us to **filter** our dataset specifically for the **Sub-Saharan Africa** region.
# - We then **handled missing values** in the `Pct_unemployment` column by imputing `NULL` entries with a default value of **33.65** using the `COALESCE()` function.
# - Finally, we **saved our complete query as a SQL VIEW** named `united_nations.Country_Unemployment_Rate`, allowing for easier future access, simplified queries, and better data management.
#
# This exercise demonstrated how **views** can simplify complex queries, ensure data consistency, and provide a reusable structure for analytical tasks.
