# %% [markdown]
# ## Control Flow Functions in SQL
#
# In this section, we will use control flow functions to break down a complex problem into its core logic.
# Control flow functions allow us to apply **conditional logic** to our SQL queries, enabling smarter data manipulation and classification.
#
# ###  Learning Objectives
# By the end of this exercise, you should be able to:
# - Use the **IIF** control function to check for a condition and return a value for each scenario.
# - Use the **CASE** statement to categorize data in an existing column.
#
#
#
# ###  Connecting to the Database
# We’ll start by loading the **Northwind** database in our Jupyter Notebook.
# Ensure the `Northwind.db` file is stored in the same folder as your notebook.

# %%
# %load_ext sql

# %%
# %sql sqlite:///Northwind.db

# %% [markdown]
# ###  Exercise 1: Categorize Employees Based on Salaries
#
# In this exercise, we will categorize employees based on their salary levels.
#
# We’ll write a SQL query that returns all employees along with a new column called **`HighSalary`**, which shows:
#
# - **'Yes'** → if the employee’s salary is **above $50,000**
# - **'No'** → otherwise
#
# This exercise demonstrates how to use the **IIF()** control function in SQL to apply conditional logic when analyzing employee compensation data.

# %%
# %%sql
#
# SELECT
#        FirstName,
#        LastName,
#        IIF(Salary > 50000, 'Yes', 'No') AS HighSalary
# FROM
#        Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'No'),
#  ('Andrew', 'Fuller', 'No'),
#  ('Janet', 'Leverling', 'No'),
#  ('Margaret', 'Peacock', 'No'),
#  ('Steven', 'Buchanan', 'No'),
#  ('Michael', 'Suyama', 'No'),
#  ('Robert', 'King', 'No'),
#  ('Laura', 'Callahan', 'No'),
#  ('Anne', 'Dodsworth', 'No')]

# %% [markdown]
# ###  Exercise 2: Categorize Orders Based on Quantity
# Using the **OrderDetails** table, categorize orders into:
# - `'Small'` if Quantity < 20
# - `'Medium'` if Quantity BETWEEN 20 and 100
# - `'Large'` if Quantity > 100

# %%
# %%sql
#
# SELECT
#     OrderID,
#     Quantity,
#     CASE
#         WHEN Quantity < 20 THEN 'Small'
#         WHEN Quantity BETWEEN 20 AND 100 THEN 'Medium'
#         ELSE 'Large'
#     END AS OrderSize
# FROM OrderDetails;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(10248, 12, 'Small'),
#  (10248, 10, 'Small'),
#  (10248, 5, 'Small'),
#  (10249, 9, 'Small'),
#  (10249, 40, 'Medium'),
#  (10250, 10, 'Small'),
#  (10250, 35, 'Medium'),
#  (10250, 15, 'Small'),
#  (10251, 6, 'Small'),
#  (10251, 15, 'Small'),
#  (10251, 20, 'Medium'),
#  (10252, 40, 'Medium'),
#  (10252, 25, 'Medium'),
#  (10252, 40, 'Medium'),
#  (10253, 20, 'Medium'),
#  (10253, 42, 'Medium'),
#  (10253, 40, 'Medium'),
#  (10254, 15, 'Small'),
#  (10254, 21, 'Medium'),
#  (10254, 21, 'Medium'),
#  (10255, 20, 'Medium'),
#  (10255, 35, 'Medium'),
#  (10255, 25, 'Medium'),
#  (10255, 30, 'Medium'),
#  (10256, 15, 'Small'),
#  (10256, 12, 'Small'),
#  (10257, 25, 'Medium'),
#  (10257, 6, 'Small'),
#  (10257, 15, 'Small'),
#  (10258, 50, 'Medium'),
#  (10258, 65, 'Medium'),
#  (10258, 6, 'Small'),
#  (10259, 10, 'Small'),
#  (10259, 1, 'Small'),
#  (10260, 16, 'Small'),
#  (10260, 50, 'Medium'),
#  (10260, 15, 'Small'),
#  (10260, 21, 'Medium'),
#  (10261, 20, 'Medium'),
#  (10261, 20, 'Medium'),
#  (10262, 12, 'Small'),
#  (10262, 15, 'Small'),
#  (10262, 2, 'Small'),
#  (10263, 60, 'Medium'),
#  (10263, 28, 'Medium'),
#  (10263, 60, 'Medium'),
#  (10263, 36, 'Medium'),
#  (10264, 35, 'Medium'),
#  (10264, 25, 'Medium'),
#  (10265, 30, 'Medium'),
#  (10265, 20, 'Medium'),
#  (10266, 12, 'Small'),
#  (10267, 50, 'Medium'),
#  (10267, 70, 'Medium'),
#  (10267, 15, 'Small'),
#  (10268, 10, 'Small'),
#  (10268, 4, 'Small'),
#  (10269, 60, 'Medium'),
#  (10269, 20, 'Medium'),
#  (10270, 30, 'Medium'),
#  (10270, 25, 'Medium'),
#  (10271, 24, 'Medium'),
#  (10272, 6, 'Small'),
#  (10272, 40, 'Medium'),
#  (10272, 24, 'Medium'),
#  (10273, 24, 'Medium'),
#  (10273, 15, 'Small'),
#  (10273, 20, 'Medium'),
#  (10273, 60, 'Medium'),
#  (10273, 33, 'Medium'),
#  (10274, 20, 'Medium'),
#  (10274, 7, 'Small'),
#  (10275, 12, 'Small'),
#  (10275, 6, 'Small'),
#  (10276, 15, 'Small'),
#  (10276, 10, 'Small'),
#  (10277, 20, 'Medium'),
#  (10277, 12, 'Small'),
#  (10278, 16, 'Small'),
#  (10278, 15, 'Small'),
#  (10278, 8, 'Small'),
#  (10278, 25, 'Medium'),
#  (10279, 15, 'Small'),
#  (10280, 12, 'Small'),
#  (10280, 20, 'Medium'),
#  (10280, 30, 'Medium'),
#  (10281, 1, 'Small'),
#  (10281, 6, 'Small'),
#  (10281, 4, 'Small'),
#  (10282, 6, 'Small'),
#  (10282, 2, 'Small'),
#  (10283, 20, 'Medium'),
#  (10283, 18, 'Small'),
#  (10283, 35, 'Medium'),
#  (10283, 3, 'Small'),
#  (10284, 15, 'Small'),
#  (10284, 21, 'Medium'),
#  (10284, 20, 'Medium'),
#  (10284, 5, 'Small'),
#  (10285, 45, 'Medium'),
#  (10285, 40, 'Medium'),
#  (10285, 36, 'Medium'),
#  (10286, 100, 'Medium'),
#  (10286, 40, 'Medium'),
#  (10287, 40, 'Medium'),
#  (10287, 20, 'Medium'),
#  (10287, 15, 'Small'),
#  (10288, 10, 'Small'),
#  (10288, 3, 'Small'),
#  (10289, 30, 'Medium'),
#  (10289, 9, 'Small'),
#  (10290, 20, 'Medium'),
#  (10290, 15, 'Small'),
#  (10290, 15, 'Small'),
#  (10290, 10, 'Small'),
#  (10291, 20, 'Medium'),
#  (10291, 24, 'Medium'),
#  (10291, 2, 'Small'),
#  (10292, 20, 'Medium'),
#  (10293, 12, 'Small'),
#  (10293, 10, 'Small'),
#  (10293, 5, 'Small'),
#  (10293, 6, 'Small'),
#  (10294, 18, 'Small'),
#  (10294, 15, 'Small'),
#  (10294, 15, 'Small'),
#  (10294, 21, 'Medium'),
#  (10294, 6, 'Small'),
#  (10295, 4, 'Small'),
#  (10296, 12, 'Small'),
#  (10296, 30, 'Medium'),
#  (10296, 15, 'Small'),
#  (10297, 60, 'Medium'),
#  (10297, 20, 'Medium'),
#  (10298, 40, 'Medium'),
#  (10298, 40, 'Medium'),
#  (10298, 30, 'Medium'),
#  (10298, 15, 'Small'),
#  (10299, 15, 'Small'),
#  (10299, 20, 'Medium'),
#  (10300, 30, 'Medium'),
#  (10300, 20, 'Medium'),
#  (10301, 10, 'Small'),
#  (10301, 20, 'Medium'),
#  (10302, 40, 'Medium'),
#  (10302, 28, 'Medium'),
#  (10302, 12, 'Small'),
#  (10303, 40, 'Medium'),
#  (10303, 30, 'Medium'),
#  (10303, 15, 'Small'),
#  (10304, 30, 'Medium'),
#  (10304, 10, 'Small'),
#  (10304, 2, 'Small'),
#  (10305, 25, 'Medium'),
#  (10305, 25, 'Medium'),
#  (10305, 30, 'Medium'),
#  (10306, 10, 'Small'),
#  (10306, 10, 'Small'),
#  (10306, 5, 'Small'),
#  (10307, 10, 'Small'),
#  (10307, 3, 'Small'),
#  (10308, 1, 'Small'),
#  (10308, 5, 'Small'),
#  (10309, 20, 'Medium'),
#  (10309, 30, 'Medium'),
#  (10309, 2, 'Small'),
#  (10309, 20, 'Medium'),
#  (10309, 3, 'Small'),
#  (10310, 10, 'Small'),
#  (10310, 5, 'Small'),
#  (10311, 6, 'Small'),
#  (10311, 7, 'Small'),
#  (10312, 4, 'Small'),
#  (10312, 24, 'Medium'),
#  (10312, 20, 'Medium'),
#  (10312, 10, 'Small'),
#  (10313, 12, 'Small'),
#  (10314, 40, 'Medium'),
#  (10314, 30, 'Medium'),
#  (10314, 25, 'Medium'),
#  (10315, 14, 'Small'),
#  (10315, 30, 'Medium'),
#  (10316, 10, 'Small'),
#  (10316, 70, 'Medium'),
#  (10317, 20, 'Medium'),
#  (10318, 20, 'Medium'),
#  (10318, 6, 'Small'),
#  (10319, 8, 'Small'),
#  (10319, 14, 'Small'),
#  (10319, 30, 'Medium'),
#  (10320, 30, 'Medium'),
#  (10321, 10, 'Small'),
#  (10322, 20, 'Medium'),
#  (10323, 5, 'Small'),
#  (10323, 4, 'Small'),
#  (10323, 4, 'Small'),
#  (10324, 21, 'Medium'),
#  (10324, 70, 'Medium'),
#  (10324, 30, 'Medium'),
#  (10324, 40, 'Medium'),
#  (10324, 80, 'Medium'),
#  (10325, 6, 'Small'),
#  (10325, 12, 'Small'),
#  (10325, 9, 'Small'),
#  (10325, 4, 'Small'),
#  (10325, 40, 'Medium'),
#  (10326, 24, 'Medium'),
#  (10326, 16, 'Small'),
#  (10326, 50, 'Medium'),
#  (10327, 25, 'Medium'),
#  (10327, 50, 'Medium'),
#  (10327, 35, 'Medium'),
#  (10327, 30, 'Medium'),
#  (10328, 9, 'Small'),
#  (10328, 40, 'Medium'),
#  (10328, 10, 'Small'),
#  (10329, 10, 'Small'),
#  (10329, 8, 'Small'),
#  (10329, 20, 'Medium'),
#  (10329, 12, 'Small'),
#  (10330, 50, 'Medium'),
#  (10330, 25, 'Medium'),
#  (10331, 15, 'Small'),
#  (10332, 40, 'Medium'),
#  (10332, 10, 'Small'),
#  (10332, 16, 'Small'),
#  (10333, 10, 'Small'),
#  (10333, 10, 'Small'),
#  (10333, 40, 'Medium'),
#  (10334, 8, 'Small'),
#  (10334, 10, 'Small'),
#  (10335, 7, 'Small'),
#  (10335, 25, 'Medium'),
#  (10335, 6, 'Small'),
#  (10335, 48, 'Medium'),
#  (10336, 18, 'Small'),
#  (10337, 40, 'Medium'),
#  (10337, 24, 'Medium'),
#  (10337, 20, 'Medium'),
#  (10337, 28, 'Medium'),
#  (10337, 25, 'Medium'),
#  (10338, 20, 'Medium'),
#  (10338, 15, 'Small'),
#  (10339, 10, 'Small'),
#  (10339, 70, 'Medium'),
#  (10339, 28, 'Medium'),
#  (10340, 20, 'Medium'),
#  (10340, 12, 'Small'),
#  (10340, 40, 'Medium'),
#  (10341, 8, 'Small'),
#  (10341, 9, 'Small'),
#  (10342, 24, 'Medium'),
#  (10342, 56, 'Medium'),
#  (10342, 40, 'Medium'),
#  (10342, 40, 'Medium'),
#  (10343, 50, 'Medium'),
#  (10343, 4, 'Small'),
#  (10343, 15, 'Small'),
#  (10344, 35, 'Medium'),
#  (10344, 70, 'Medium'),
#  (10345, 70, 'Medium'),
#  (10345, 80, 'Medium'),
#  (10345, 9, 'Small'),
#  (10346, 36, 'Medium'),
#  (10346, 20, 'Medium'),
#  (10347, 10, 'Small'),
#  (10347, 50, 'Medium'),
#  (10347, 4, 'Small'),
#  (10347, 6, 'Small'),
#  (10348, 15, 'Small'),
#  (10348, 25, 'Medium'),
#  (10349, 24, 'Medium'),
#  (10350, 15, 'Small'),
#  (10350, 18, 'Small'),
#  (10351, 20, 'Medium'),
#  (10351, 13, 'Small'),
#  (10351, 77, 'Medium'),
#  (10351, 10, 'Small'),
#  (10352, 10, 'Small'),
#  (10352, 20, 'Medium'),
#  (10353, 12, 'Small'),
#  (10353, 50, 'Medium'),
#  (10354, 12, 'Small'),
#  (10354, 4, 'Small'),
#  (10355, 25, 'Medium'),
#  (10355, 25, 'Medium'),
#  (10356, 30, 'Medium'),
#  (10356, 12, 'Small'),
#  (10356, 20, 'Medium'),
#  (10357, 30, 'Medium'),
#  (10357, 16, 'Small'),
#  (10357, 8, 'Small'),
#  (10358, 10, 'Small'),
#  (10358, 10, 'Small'),
#  (10358, 20, 'Medium'),
#  (10359, 56, 'Medium'),
#  (10359, 70, 'Medium'),
#  (10359, 80, 'Medium'),
#  (10360, 30, 'Medium'),
#  (10360, 35, 'Medium'),
#  (10360, 10, 'Small'),
#  (10360, 35, 'Medium'),
#  (10360, 28, 'Medium'),
#  (10361, 54, 'Medium'),
#  (10361, 55, 'Medium'),
#  (10362, 50, 'Medium'),
#  (10362, 20, 'Medium'),
#  (10362, 24, 'Medium'),
#  (10363, 20, 'Medium'),
#  (10363, 12, 'Small'),
#  (10363, 12, 'Small'),
#  (10364, 30, 'Medium'),
#  (10364, 5, 'Small'),
#  (10365, 24, 'Medium'),
#  (10366, 5, 'Small'),
#  (10366, 5, 'Small'),
#  (10367, 36, 'Medium'),
#  (10367, 18, 'Small'),
#  (10367, 15, 'Small'),
#  (10367, 7, 'Small'),
#  (10368, 5, 'Small'),
#  (10368, 13, 'Small'),
#  (10368, 25, 'Medium'),
#  (10368, 35, 'Medium'),
#  (10369, 20, 'Medium'),
#  (10369, 18, 'Small'),
#  (10370, 15, 'Small'),
#  (10370, 30, 'Medium'),
#  (10370, 20, 'Medium'),
#  (10371, 6, 'Small'),
#  (10372, 12, 'Small'),
#  (10372, 40, 'Medium'),
#  (10372, 70, 'Medium'),
#  (10372, 42, 'Medium'),
#  (10373, 80, 'Medium'),
#  (10373, 50, 'Medium'),
#  (10374, 30, 'Medium'),
#  (10374, 15, 'Small'),
#  (10375, 15, 'Small'),
#  (10375, 10, 'Small'),
#  (10376, 42, 'Medium'),
#  (10377, 20, 'Medium'),
#  (10377, 20, 'Medium'),
#  (10378, 6, 'Small'),
#  (10379, 8, 'Small'),
#  (10379, 16, 'Small'),
#  (10379, 20, 'Medium'),
#  (10380, 18, 'Small'),
#  (10380, 20, 'Medium'),
#  (10380, 6, 'Small'),
#  (10380, 30, 'Medium'),
#  (10381, 14, 'Small'),
#  (10382, 32, 'Medium'),
#  (10382, 9, 'Small'),
#  (10382, 14, 'Small'),
#  (10382, 60, 'Medium'),
#  (10382, 50, 'Medium'),
#  (10383, 20, 'Medium'),
#  (10383, 15, 'Small'),
#  (10383, 20, 'Medium'),
#  (10384, 28, 'Medium'),
#  (10384, 15, 'Small'),
#  (10385, 10, 'Small'),
#  (10385, 20, 'Medium'),
#  (10385, 8, 'Small'),
#  (10386, 15, 'Small'),
#  (10386, 10, 'Small'),
#  (10387, 15, 'Small'),
#  (10387, 6, 'Small'),
#  (10387, 12, 'Small'),
#  (10387, 15, 'Small'),
#  (10388, 15, 'Small'),
#  (10388, 20, 'Medium'),
#  (10388, 40, 'Medium'),
#  (10389, 16, 'Small'),
#  (10389, 15, 'Small'),
#  (10389, 20, 'Medium'),
#  (10389, 30, 'Medium'),
#  (10390, 60, 'Medium'),
#  (10390, 40, 'Medium'),
#  (10390, 45, 'Medium'),
#  (10390, 24, 'Medium'),
#  (10391, 18, 'Small'),
#  (10392, 50, 'Medium'),
#  (10393, 25, 'Medium'),
#  (10393, 42, 'Medium'),
#  (10393, 7, 'Small'),
#  (10393, 70, 'Medium'),
#  (10393, 32, 'Medium'),
#  (10394, 10, 'Small'),
#  (10394, 10, 'Small'),
#  (10395, 28, 'Medium'),
#  (10395, 70, 'Medium'),
#  (10395, 8, 'Small'),
#  (10396, 40, 'Medium'),
#  (10396, 60, 'Medium'),
#  (10396, 21, 'Medium'),
#  (10397, 10, 'Small'),
#  (10397, 18, 'Small'),
#  (10398, 30, 'Medium'),
#  (10398, 120, 'Large'),
#  (10399, 60, 'Medium'),
#  (10399, 30, 'Medium'),
#  (10399, 35, 'Medium'),
#  (10399, 14, 'Small'),
#  (10400, 21, 'Medium'),
#  (10400, 35, 'Medium'),
#  (10400, 30, 'Medium'),
#  (10401, 18, 'Small'),
#  (10401, 70, 'Medium'),
#  (10401, 20, 'Medium'),
#  (10401, 60, 'Medium'),
#  (10402, 60, 'Medium'),
#  (10402, 65, 'Medium'),
#  (10403, 21, 'Medium'),
#  (10403, 70, 'Medium'),
#  (10404, 30, 'Medium'),
#  (10404, 40, 'Medium'),
#  (10404, 30, 'Medium'),
#  (10405, 50, 'Medium'),
#  (10406, 10, 'Small'),
#  (10406, 30, 'Medium'),
#  (10406, 42, 'Medium'),
#  (10406, 5, 'Small'),
#  (10406, 2, 'Small'),
#  (10407, 30, 'Medium'),
#  (10407, 15, 'Small'),
#  (10407, 15, 'Small'),
#  (10408, 10, 'Small'),
#  (10408, 6, 'Small'),
#  (10408, 35, 'Medium'),
#  (10409, 12, 'Small'),
#  (10409, 12, 'Small'),
#  (10410, 49, 'Medium'),
#  (10410, 16, 'Small'),
#  (10411, 25, 'Medium'),
#  (10411, 40, 'Medium'),
#  (10411, 9, 'Small'),
#  (10412, 20, 'Medium'),
#  (10413, 24, 'Medium'),
#  (10413, 40, 'Medium'),
#  (10413, 14, 'Small'),
#  (10414, 18, 'Small'),
#  (10414, 50, 'Medium'),
#  (10415, 2, 'Small'),
#  (10415, 20, 'Medium'),
#  (10416, 20, 'Medium'),
#  (10416, 10, 'Small'),
#  (10416, 20, 'Medium'),
#  (10417, 50, 'Medium'),
#  (10417, 2, 'Small'),
#  (10417, 36, 'Medium'),
#  (10417, 35, 'Medium'),
#  (10418, 60, 'Medium'),
#  (10418, 55, 'Medium'),
#  (10418, 16, 'Small'),
#  (10418, 15, 'Small'),
#  (10419, 60, 'Medium'),
#  (10419, 20, 'Medium'),
#  (10420, 20, 'Medium'),
#  (10420, 2, 'Small'),
#  (10420, 8, 'Small'),
#  (10420, 20, 'Medium'),
#  (10421, 4, 'Small'),
#  (10421, 30, 'Medium'),
#  (10421, 15, 'Small'),
#  (10421, 10, 'Small'),
#  (10422, 2, 'Small'),
#  (10423, 14, 'Small'),
#  (10423, 20, 'Medium'),
#  (10424, 60, 'Medium'),
#  (10424, 49, 'Medium'),
#  (10424, 30, 'Medium'),
#  (10425, 10, 'Small'),
#  (10425, 20, 'Medium'),
#  (10426, 5, 'Small'),
#  (10426, 7, 'Small'),
#  (10427, 35, 'Medium'),
#  (10428, 20, 'Medium'),
#  (10429, 40, 'Medium'),
#  (10429, 35, 'Medium'),
#  (10430, 45, 'Medium'),
#  (10430, 50, 'Medium'),
#  (10430, 30, 'Medium'),
#  (10430, 70, 'Medium'),
#  (10431, 50, 'Medium'),
#  (10431, 50, 'Medium'),
#  (10431, 30, 'Medium'),
#  (10432, 10, 'Small'),
#  (10432, 40, 'Medium'),
#  (10433, 28, 'Medium'),
#  (10434, 6, 'Small'),
#  (10434, 18, 'Small'),
#  (10435, 10, 'Small'),
#  (10435, 12, 'Small'),
#  (10435, 10, 'Small'),
#  (10436, 5, 'Small'),
#  (10436, 40, 'Medium'),
#  (10436, 30, 'Medium'),
#  (10436, 24, 'Medium'),
#  (10437, 15, 'Small'),
#  (10438, 15, 'Small'),
#  (10438, 20, 'Medium'),
#  (10438, 15, 'Small'),
#  (10439, 15, 'Small'),
#  (10439, 16, 'Small'),
#  (10439, 6, 'Small'),
#  (10439, 30, 'Medium'),
#  (10440, 45, 'Medium'),
#  (10440, 49, 'Medium'),
#  (10440, 24, 'Medium'),
#  (10440, 90, 'Medium'),
#  (10441, 50, 'Medium'),
#  (10442, 30, 'Medium'),
#  (10442, 80, 'Medium'),
#  (10442, 60, 'Medium'),
#  (10443, 6, 'Small'),
#  (10443, 12, 'Small'),
#  (10444, 10, 'Small'),
#  (10444, 15, 'Small'),
#  (10444, 8, 'Small'),
#  (10444, 30, 'Medium'),
#  (10445, 6, 'Small'),
#  (10445, 15, 'Small'),
#  (10446, 12, 'Small'),
#  (10446, 20, 'Medium'),
#  (10446, 3, 'Small'),
#  (10446, 15, 'Small'),
#  (10447, 40, 'Medium'),
#  (10447, 35, 'Medium'),
#  (10447, 2, 'Small'),
#  (10448, 6, 'Small'),
#  (10448, 20, 'Medium'),
#  (10449, 14, 'Small'),
#  (10449, 20, 'Medium'),
#  (10449, 35, 'Medium'),
#  (10450, 20, 'Medium'),
#  (10450, 6, 'Small'),
#  (10451, 120, 'Large'),
#  (10451, 35, 'Medium'),
#  (10451, 28, 'Medium'),
#  (10451, 55, 'Medium'),
#  (10452, 15, 'Small'),
#  (10452, 100, 'Medium'),
#  (10453, 15, 'Small'),
#  (10453, 25, 'Medium'),
#  (10454, 20, 'Medium'),
#  (10454, 20, 'Medium'),
#  (10454, 10, 'Small'),
#  (10455, 20, 'Medium'),
#  (10455, 50, 'Medium'),
#  (10455, 25, 'Medium'),
#  (10455, 30, 'Medium'),
#  (10456, 40, 'Medium'),
#  (10456, 21, 'Medium'),
#  (10457, 36, 'Medium'),
#  (10458, 30, 'Medium'),
#  (10458, 30, 'Medium'),
#  (10458, 20, 'Medium'),
#  (10458, 15, 'Small'),
#  (10458, 50, 'Medium'),
#  (10459, 16, 'Small'),
#  (10459, 20, 'Medium'),
#  (10459, 40, 'Medium'),
#  (10460, 21, 'Medium'),
#  (10460, 4, 'Small'),
#  (10461, 40, 'Medium'),
#  (10461, 28, 'Medium'),
#  (10461, 60, 'Medium'),
#  (10462, 1, 'Small'),
#  (10462, 21, 'Medium'),
#  (10463, 21, 'Medium'),
#  (10463, 50, 'Medium'),
#  (10464, 16, 'Small'),
#  (10464, 3, 'Small'),
#  (10464, 30, 'Medium'),
#  (10464, 20, 'Medium'),
#  (10465, 25, 'Medium'),
#  (10465, 18, 'Small'),
#  (10465, 20, 'Medium'),
#  (10465, 30, 'Medium'),
#  (10465, 25, 'Medium'),
#  (10466, 10, 'Small'),
#  (10466, 5, 'Small'),
#  (10467, 28, 'Medium'),
#  (10467, 12, 'Small'),
#  (10468, 8, 'Small'),
#  (10468, 15, 'Small'),
#  (10469, 40, 'Medium'),
#  (10469, 35, 'Medium'),
#  (10469, 2, 'Small'),
#  (10470, 30, 'Medium'),
#  (10470, 15, 'Small'),
#  (10470, 8, 'Small'),
#  (10471, 30, 'Medium'),
#  (10471, 20, 'Medium'),
#  (10472, 80, 'Medium'),
#  (10472, 18, 'Small'),
#  (10473, 12, 'Small'),
#  (10473, 12, 'Small'),
#  (10474, 12, 'Small'),
#  (10474, 18, 'Small'),
#  (10474, 21, 'Medium'),
#  (10474, 10, 'Small'),
#  (10475, 35, 'Medium'),
#  (10475, 60, 'Medium'),
#  (10475, 42, 'Medium'),
#  (10476, 2, 'Small'),
#  (10476, 12, 'Small'),
#  (10477, 15, 'Small'),
#  (10477, 21, 'Medium'),
#  (10477, 20, 'Medium'),
#  (10478, 20, 'Medium'),
#  (10479, 30, 'Medium'),
#  (10479, 28, 'Medium'),
#  (10479, 60, 'Medium'),
#  (10479, 30, 'Medium'),
#  (10480, 30, 'Medium'),
#  (10480, 12, 'Small'),
#  (10481, 24, 'Medium'),
#  (10481, 40, 'Medium'),
#  (10482, 10, 'Small'),
#  (10483, 35, 'Medium'),
#  (10483, 30, 'Medium'),
#  (10484, 14, 'Small'),
#  (10484, 10, 'Small'),
#  (10484, 3, 'Small'),
#  (10485, 20, 'Medium'),
#  (10485, 20, 'Medium'),
#  (10485, 30, 'Medium'),
#  (10485, 60, 'Medium'),
#  (10486, 5, 'Small'),
#  (10486, 25, 'Medium'),
#  (10486, 16, 'Small'),
#  (10487, 5, 'Small'),
#  (10487, 30, 'Medium'),
#  (10487, 24, 'Medium'),
#  (10488, 30, 'Medium'),
#  (10488, 20, 'Medium'),
#  (10489, 15, 'Small'),
#  (10489, 18, 'Small'),
#  (10490, 60, 'Medium'),
#  (10490, 30, 'Medium'),
#  (10490, 36, 'Medium'),
#  (10491, 15, 'Small'),
#  (10491, 7, 'Small'),
#  (10492, 60, 'Medium'),
#  (10492, 20, 'Medium'),
#  (10493, 15, 'Small'),
#  (10493, 10, 'Small'),
#  (10493, 10, 'Small'),
#  (10494, 30, 'Medium'),
#  (10495, 10, 'Small'),
#  (10495, 20, 'Medium'),
#  (10495, 5, 'Small'),
#  (10496, 20, 'Medium'),
#  (10497, 14, 'Small'),
#  (10497, 25, 'Medium'),
#  (10497, 25, 'Medium'),
#  (10498, 14, 'Small'),
#  (10498, 5, 'Small'),
#  (10498, 30, 'Medium'),
#  (10499, 20, 'Medium'),
#  (10499, 25, 'Medium'),
#  (10500, 12, 'Small'),
#  (10500, 8, 'Small'),
#  (10501, 20, 'Medium'),
#  (10502, 21, 'Medium'),
#  (10502, 6, 'Small'),
#  (10502, 30, 'Medium'),
#  (10503, 70, 'Medium'),
#  (10503, 20, 'Medium'),
#  (10504, 12, 'Small'),
#  (10504, 12, 'Small'),
#  (10504, 10, 'Small'),
#  (10504, 25, 'Medium'),
#  (10505, 3, 'Small'),
#  (10506, 18, 'Small'),
#  (10506, 14, 'Small'),
#  (10507, 15, 'Small'),
#  (10507, 15, 'Small'),
#  (10508, 10, 'Small'),
#  (10508, 10, 'Small'),
#  (10509, 3, 'Small'),
#  (10510, 36, 'Medium'),
#  (10510, 36, 'Medium'),
#  (10511, 50, 'Medium'),
#  (10511, 50, 'Medium'),
#  (10511, 10, 'Small'),
#  (10512, 10, 'Small'),
#  (10512, 9, 'Small'),
#  (10512, 6, 'Small'),
#  (10512, 12, 'Small'),
#  (10513, 40, 'Medium'),
#  (10513, 50, 'Medium'),
#  (10513, 15, 'Small'),
#  (10514, 39, 'Medium'),
#  (10514, 35, 'Medium'),
#  (10514, 70, 'Medium'),
#  (10514, 39, 'Medium'),
#  (10514, 50, 'Medium'),
#  (10515, 16, 'Small'),
#  (10515, 50, 'Medium'),
#  (10515, 120, 'Large'),
#  (10515, 16, 'Small'),
#  (10515, 84, 'Medium'),
#  (10516, 25, 'Medium'),
#  (10516, 80, 'Medium'),
#  (10516, 20, 'Medium'),
#  (10517, 6, 'Small'),
#  (10517, 4, 'Small'),
#  (10517, 6, 'Small'),
#  (10518, 5, 'Small'),
#  (10518, 15, 'Small'),
#  (10518, 9, 'Small'),
#  (10519, 16, 'Small'),
#  (10519, 40, 'Medium'),
#  (10519, 10, 'Small'),
#  (10520, 8, 'Small'),
#  (10520, 5, 'Small'),
#  (10521, 3, 'Small'),
#  (10521, 10, 'Small'),
#  (10521, 6, 'Small'),
#  (10522, 40, 'Medium'),
#  (10522, 24, 'Medium'),
#  (10522, 20, 'Medium'),
#  (10522, 25, 'Medium'),
#  (10523, 25, 'Medium'),
#  (10523, 15, 'Small'),
#  (10523, 18, 'Small'),
#  (10523, 6, 'Small'),
#  (10524, 2, 'Small'),
#  (10524, 10, 'Small'),
#  (10524, 60, 'Medium'),
#  (10524, 15, 'Small'),
#  (10525, 30, 'Medium'),
#  (10525, 15, 'Small'),
#  (10526, 8, 'Small'),
#  (10526, 10, 'Small'),
#  (10526, 30, 'Medium'),
#  (10527, 50, 'Medium'),
#  (10527, 30, 'Medium'),
#  (10528, 3, 'Small'),
#  (10528, 8, 'Small'),
#  (10528, 9, 'Small'),
#  (10529, 14, 'Small'),
#  (10529, 20, 'Medium'),
#  (10529, 10, 'Small'),
#  (10530, 40, 'Medium'),
#  (10530, 25, 'Medium'),
#  (10530, 20, 'Medium'),
#  (10530, 50, 'Medium'),
#  (10531, 2, 'Small'),
#  (10532, 15, 'Small'),
#  (10532, 24, 'Medium'),
#  (10533, 50, 'Medium'),
#  (10533, 24, 'Medium'),
#  (10533, 24, 'Medium'),
#  (10534, 10, 'Small'),
#  (10534, 10, 'Small'),
#  (10534, 10, 'Small'),
#  (10535, 50, 'Medium'),
#  (10535, 10, 'Small'),
#  (10535, 5, 'Small'),
#  (10535, 15, 'Small'),
#  (10536, 15, 'Small'),
#  (10536, 20, 'Medium'),
#  (10536, 30, 'Medium'),
#  (10536, 35, 'Medium'),
#  (10537, 30, 'Medium'),
#  (10537, 6, 'Small'),
#  (10537, 20, 'Medium'),
#  (10537, 21, 'Medium'),
#  (10537, 9, 'Small'),
#  (10538, 7, 'Small'),
#  (10538, 1, 'Small'),
#  (10539, 8, 'Small'),
#  (10539, 15, 'Small'),
#  (10539, 15, 'Small'),
#  (10539, 6, 'Small'),
#  (10540, 60, 'Medium'),
#  (10540, 40, 'Medium'),
#  (10540, 30, 'Medium'),
#  (10540, 35, 'Medium'),
#  (10541, 35, 'Medium'),
#  (10541, 4, 'Small'),
#  (10541, 36, 'Medium'),
#  (10541, 9, 'Small'),
#  (10542, 15, 'Small'),
#  (10542, 24, 'Medium'),
#  (10543, 30, 'Medium'),
#  (10543, 70, 'Medium'),
#  (10544, 7, 'Small'),
#  (10544, 7, 'Small'),
#  (10545, 10, 'Small'),
#  (10546, 10, 'Small'),
#  (10546, 30, 'Medium'),
#  (10546, 40, 'Medium'),
#  (10547, 24, 'Medium'),
#  (10547, 60, 'Medium'),
#  (10548, 10, 'Small'),
#  (10548, 14, 'Small'),
#  (10549, 55, 'Medium'),
#  (10549, 100, 'Medium'),
#  (10549, 48, 'Medium'),
#  (10550, 8, 'Small'),
#  (10550, 10, 'Small'),
#  (10550, 6, 'Small'),
#  (10550, 10, 'Small'),
#  (10551, 40, 'Medium'),
#  (10551, 20, 'Medium'),
#  (10551, 40, 'Medium'),
#  (10552, 18, 'Small'),
#  (10552, 30, 'Medium'),
#  (10553, 15, 'Small'),
#  (10553, 14, 'Small'),
#  (10553, 24, 'Medium'),
#  (10553, 30, 'Medium'),
#  (10553, 6, 'Small'),
#  (10554, 30, 'Medium'),
#  (10554, 20, 'Medium'),
#  (10554, 20, 'Medium'),
#  (10554, 10, 'Small'),
#  (10555, 30, 'Medium'),
#  (10555, 35, 'Medium'),
#  (10555, 18, 'Small'),
#  (10555, 20, 'Medium'),
#  (10555, 40, 'Medium'),
#  (10556, 24, 'Medium'),
#  (10557, 30, 'Medium'),
#  (10557, 20, 'Medium'),
#  (10558, 25, 'Medium'),
#  (10558, 20, 'Medium'),
#  (10558, 30, 'Medium'),
#  (10558, 18, 'Small'),
#  (10558, 3, 'Small'),
#  (10559, 12, 'Small'),
#  (10559, 18, 'Small'),
#  (10560, 20, 'Medium'),
#  (10560, 15, 'Small'),
#  (10561, 10, 'Small'),
#  (10561, 50, 'Medium'),
#  (10562, 20, 'Medium'),
#  (10562, 10, 'Small'),
#  (10563, 25, 'Medium'),
#  (10563, 70, 'Medium'),
#  (10564, 16, 'Small'),
#  (10564, 6, 'Small'),
#  (10564, 25, 'Medium'),
#  (10565, 25, 'Medium'),
#  (10565, 18, 'Small'),
#  (10566, 35, 'Medium'),
#  (10566, 18, 'Small'),
#  (10566, 10, 'Small'),
#  (10567, 60, 'Medium'),
#  (10567, 3, 'Small'),
#  (10567, 40, 'Medium'),
#  (10568, 5, 'Small'),
#  (10569, 35, 'Medium'),
#  (10569, 30, 'Medium'),
#  (10570, 15, 'Small'),
#  (10570, 60, 'Medium'),
#  (10571, 11, 'Small'),
#  (10571, 28, 'Medium'),
#  (10572, 12, 'Small'),
#  (10572, 10, 'Small'),
#  (10572, 50, 'Medium'),
#  (10572, 15, 'Small'),
#  (10573, 18, 'Small'),
#  (10573, 40, 'Medium'),
#  (10573, 25, 'Medium'),
#  (10574, 14, 'Small'),
#  (10574, 2, 'Small'),
#  (10574, 10, 'Small'),
#  (10574, 6, 'Small'),
#  (10575, 12, 'Small'),
#  (10575, 6, 'Small'),
#  (10575, 30, 'Medium'),
#  (10575, 10, 'Small'),
#  (10576, 10, 'Small'),
#  (10576, 20, 'Medium'),
#  (10576, 21, 'Medium'),
#  (10577, 10, 'Small'),
#  (10577, 20, 'Medium'),
#  (10577, 18, 'Small'),
#  (10578, 20, 'Medium'),
#  (10578, 6, 'Small'),
#  (10579, 10, 'Small'),
#  (10579, 21, 'Medium'),
#  (10580, 15, 'Small'),
#  (10580, 9, 'Small'),
#  (10580, 30, 'Medium'),
#  (10581, 50, 'Medium'),
#  (10582, 4, 'Small'),
#  (10582, 14, 'Small'),
#  (10583, 10, 'Small'),
#  (10583, 24, 'Medium'),
#  (10583, 10, 'Small'),
#  (10584, 50, 'Medium'),
#  (10585, 15, 'Small'),
#  (10586, 4, 'Small'),
#  (10587, 6, 'Small'),
#  (10587, 20, 'Medium'),
#  (10587, 20, 'Medium'),
#  (10588, 40, 'Medium'),
#  (10588, 100, 'Medium'),
#  (10589, 4, 'Small'),
#  (10590, 20, 'Medium'),
#  (10590, 60, 'Medium'),
#  (10591, 14, 'Small'),
#  (10591, 10, 'Small'),
#  (10591, 50, 'Medium'),
#  (10592, 25, 'Medium'),
#  (10592, 5, 'Small'),
#  (10593, 21, 'Medium'),
#  (10593, 20, 'Medium'),
#  (10593, 4, 'Small'),
#  (10594, 24, 'Medium'),
#  (10594, 30, 'Medium'),
#  (10595, 30, 'Medium'),
#  (10595, 120, 'Large'),
#  (10595, 65, 'Medium'),
#  (10596, 5, 'Small'),
#  (10596, 24, 'Medium'),
#  (10596, 30, 'Medium'),
#  (10597, 35, 'Medium'),
#  (10597, 20, 'Medium'),
#  (10597, 12, 'Small'),
#  (10598, 50, 'Medium'),
#  (10598, 9, 'Small'),
#  (10599, 10, 'Small'),
#  (10600, 4, 'Small'),
#  (10600, 30, 'Medium'),
#  (10601, 60, 'Medium'),
#  (10601, 35, 'Medium'),
#  (10602, 5, 'Small'),
#  (10603, 48, 'Medium'),
#  (10603, 25, 'Medium'),
#  (10604, 6, 'Small'),
#  (10604, 10, 'Small'),
#  (10605, 30, 'Medium'),
#  (10605, 20, 'Medium'),
#  (10605, 70, 'Medium'),
#  (10605, 15, 'Small'),
#  (10606, 20, 'Medium'),
#  (10606, 20, 'Medium'),
#  (10606, 10, 'Small'),
#  (10607, 45, 'Medium'),
#  (10607, 100, 'Medium'),
#  (10607, 14, 'Small'),
#  (10607, 42, 'Medium'),
#  (10607, 12, 'Small'),
#  (10608, 28, 'Medium'),
#  (10609, 3, 'Small'),
#  (10609, 10, 'Small'),
#  (10609, 6, 'Small'),
#  (10610, 21, 'Medium'),
#  (10611, 6, 'Small'),
#  (10611, 10, 'Small'),
#  (10611, 15, 'Small'),
#  (10612, 70, 'Medium'),
#  (10612, 55, 'Medium'),
#  (10612, 18, 'Small'),
#  (10612, 40, 'Medium'),
#  (10612, 80, 'Medium'),
#  (10613, 8, 'Small'),
#  (10613, 40, 'Medium'),
#  (10614, 14, 'Small'),
#  (10614, 8, 'Small'),
#  (10614, 5, 'Small'),
#  (10615, 5, 'Small'),
#  (10616, 15, 'Small'),
#  (10616, 14, 'Small'),
#  (10616, 15, 'Small'),
#  (10616, 15, 'Small'),
#  (10617, 30, 'Medium'),
#  (10618, 70, 'Medium'),
#  (10618, 20, 'Medium'),
#  (10618, 15, 'Small'),
#  (10619, 42, 'Medium'),
#  (10619, 40, 'Medium'),
#  (10620, 5, 'Small'),
#  (10620, 5, 'Small'),
#  (10621, 5, 'Small'),
#  (10621, 10, 'Small'),
#  (10621, 20, 'Medium'),
#  (10621, 15, 'Small'),
#  (10622, 20, 'Medium'),
#  (10622, 18, 'Small'),
#  (10623, 21, 'Medium'),
#  (10623, 15, 'Small'),
#  (10623, 25, 'Medium'),
#  (10623, 3, 'Small'),
#  (10623, 30, 'Medium'),
#  (10624, 10, 'Small'),
#  (10624, 6, 'Small'),
#  (10624, 10, 'Small'),
#  (10625, 3, 'Small'),
#  (10625, 5, 'Small'),
#  (10625, 10, 'Small'),
#  ...]

# %% [markdown]
# ###  Exercise 3: Replace Country if NULL
# For customers with a missing country, replace the `Country` value with `'Not Provided'`.

# %%
# %%sql
#
# SELECT
#     CustomerID,
#     CompanyName,
#     IF(Country IS NULL, 'Not Provided', Country) AS Country
# FROM Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Germany'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Mexico'),
#  ('ANTON', 'Antonio Moreno Taquera', 'Mexico'),
#  ('AROUT', 'Around the Horn', 'UK'),
#  ('BERGS', 'Berglunds snabbkp', 'Sweden'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Germany'),
#  ('BLONP', 'Blondesddsl pre et fils', 'France'),
#  ('BOLID', 'Blido Comidas preparadas', 'Spain'),
#  ('BONAP', "Bon app'", 'France'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Canada'),
#  ('BSBEV', "B's Beverages", 'UK'),
#  ('CACTU', 'Cactus Comidas para llevar', 'Argentina'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Mexico'),
#  ('CHOPS', 'Chop-suey Chinese', 'Switzerland'),
#  ('COMMI', 'Comrcio Mineiro', 'Brazil'),
#  ('CONSH', 'Consolidated Holdings', 'UK'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Germany'),
#  ('DUMON', 'Du monde entier', 'France'),
#  ('EASTC', 'Eastern Connection', 'UK'),
#  ('ERNSH', 'Ernst Handel', 'Austria'),
#  ('FAMIA', 'Familia Arquibaldo', 'Brazil'),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Spain'),
#  ('FOLIG', 'Folies gourmandes', 'France'),
#  ('FOLKO', 'Folk och f HB', 'Sweden'),
#  ('FRANK', 'Frankenversand', 'Germany'),
#  ('FRANR', 'France restauration', 'France'),
#  ('FRANS', 'Franchi S.p.A.', 'Italy'),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Portugal'),
#  ('GALED', 'Galera del gastrnomo', 'Spain'),
#  ('GODOS', 'Godos Cocina Tpica', 'Spain'),
#  ('GOURL', 'Gourmet Lanchonetes', 'Brazil'),
#  ('GREAL', 'Great Lakes Food Market', 'USA'),
#  ('GROSR', 'GROSELLA-Restaurante', 'Venezuela'),
#  ('HANAR', 'Hanari Carnes', 'Brazil'),
#  ('HILAA', 'HILARION-Abastos', 'Venezuela'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'USA'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Ireland'),
#  ('ISLAT', 'Island Trading', 'UK'),
#  ('KOENE', 'Kniglich Essen', 'Germany'),
#  ('LACOR', "La corne d'abondance", 'France'),
#  ('LAMAI', "La maison d'Asie", 'France'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Canada'),
#  ('LAZYK', 'Lazy K Kountry Store', 'USA'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Germany'),
#  ('LETSS', "Let's Stop N Shop", 'USA'),
#  ('LILAS', 'LILA-Supermercado', 'Venezuela'),
#  ('LINOD', 'LINO-Delicateses', 'Venezuela'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'USA'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Italy'),
#  ('MAISD', 'Maison Dewey', 'Belgium'),
#  ('MEREP', 'Mre Paillarde', 'Canada'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Germany'),
#  ('NORTS', 'North/South', 'UK'),
#  ('OCEAN', 'Ocano Atlntico Ltda.', 'Argentina'),
#  ('OLDWO', 'Old World Delicatessen', 'USA'),
#  ('OTTIK', 'Ottilies Kseladen', 'Germany'),
#  ('PARIS', 'Paris spcialits', 'France'),
#  ('PERIC', 'Pericles Comidas clsicas', 'Mexico'),
#  ('PICCO', 'Piccolo und mehr', 'Austria'),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Portugal'),
#  ('QUEDE', 'Que Delcia', 'Brazil'),
#  ('QUEEN', 'Queen Cozinha', 'Brazil'),
#  ('QUICK', 'QUICK-Stop', 'Germany'),
#  ('RANCH', 'Rancho grande', 'Argentina'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'USA'),
#  ('REGGC', 'Reggiani Caseifici', 'Italy'),
#  ('RICAR', 'Ricardo Adocicados', 'Brazil'),
#  ('RICSU', 'Richter Supermarkt', 'Switzerland'),
#  ('ROMEY', 'Romero y tomillo', 'Spain'),
#  ('SANTG', 'Sant Gourmet', 'Norway'),
#  ('SAVEA', 'Save-a-lot Markets', 'USA'),
#  ('SEVES', 'Seven Seas Imports', 'UK'),
#  ('SIMOB', 'Simons bistro', 'Denmark'),
#  ('SPECD', 'Spcialits du monde', 'France'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'USA'),
#  ('SUPRD', 'Suprmes dlices', 'Belgium'),
#  ('THEBI', 'The Big Cheese', 'USA'),
#  ('THECR', 'The Cracker Box', 'USA'),
#  ('TOMSP', 'Toms Spezialitten', 'Germany'),
#  ('TORTU', 'Tortuga Restaurante', 'Mexico'),
#  ('TRADH', 'Tradio Hipermercados', 'Brazil'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'USA'),
#  ('VAFFE', 'Vaffeljernet', 'Denmark'),
#  ('Val2 ', 'IT', 'Not Provided'),
#  ('VALON', 'IT', 'Not Provided'),
#  ('VICTE', 'Victuailles en stock', 'France'),
#  ('VINET', 'Vins et alcools Chevalier', 'France'),
#  ('WANDK', 'Die Wandernde Kuh', 'Germany'),
#  ('WARTH', 'Wartian Herkku', 'Finland'),
#  ('WELLI', 'Wellington Importadora', 'Brazil'),
#  ('WHITC', 'White Clover Markets', 'USA'),
#  ('WILMK', 'Wilman Kala', 'Finland'),
#  ('WOLZA', 'Wolski  Zajazd', 'Poland')]

# %% [markdown]
# ###  Exercise 4: Calculate Average Price of Products
# We’ll calculate the **average unit price** of all products, then compare each product’s price to that average:
# - `'Below Average'` if the price is lower than average
# - `'Average'` if equal to the average
# - `'Above Average'` if higher than average

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitPrice,
#     CASE
#         WHEN UnitPrice < (SELECT AVG(UnitPrice) FROM Products) THEN 'Below Average'
#         WHEN UnitPrice = (SELECT AVG(UnitPrice) FROM Products) THEN 'Average'
#         ELSE 'Above Average'
#     END as PriceComparison
# FROM
#     Products;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Chai', 18, 'Below Average'),
#  ('Chang', 19, 'Below Average'),
#  ('Aniseed Syrup', 10, 'Below Average'),
#  ("Chef Anton's Cajun Seasoning", 22, 'Below Average'),
#  ("Chef Anton's Gumbo Mix", 21.35, 'Below Average'),
#  ("Grandma's Boysenberry Spread", 25, 'Below Average'),
#  ("Uncle Bob's Organic Dried Pears", 30, 'Above Average'),
#  ('Northwoods Cranberry Sauce', 40, 'Above Average'),
#  ('Mishi Kobe Niku', 97, 'Above Average'),
#  ('Ikura', 31, 'Above Average'),
#  ('Queso Cabrales', 21, 'Below Average'),
#  ('Queso Manchego La Pastora', 38, 'Above Average'),
#  ('Konbu', 6, 'Below Average'),
#  ('Tofu', 23.25, 'Below Average'),
#  ('Genen Shouyu', 15.5, 'Below Average'),
#  ('Pavlova', 17.45, 'Below Average'),
#  ('Alice Mutton', 39, 'Above Average'),
#  ('Carnarvon Tigers', 62.5, 'Above Average'),
#  ('Teatime Chocolate Biscuits', 9.2, 'Below Average'),
#  ("Sir Rodney's Marmalade", 81, 'Above Average'),
#  ("Sir Rodney's Scones", 10, 'Below Average'),
#  ("Gustaf's Knckebrd", 21, 'Below Average'),
#  ('Tunnbrd', 9, 'Below Average'),
#  ('Guaran Fantstica', 4.5, 'Below Average'),
#  ('NuNuCa Nu-Nougat-Creme', 14, 'Below Average'),
#  ('Gumbr Gummibrchen', 31.23, 'Above Average'),
#  ('Schoggi Schokolade', 43.9, 'Above Average'),
#  ('Rssle Sauerkraut', 45.6, 'Above Average'),
#  ('Thringer Rostbratwurst', 123.79, 'Above Average'),
#  ('Nord-Ost Matjeshering', 25.89, 'Below Average'),
#  ('Gorgonzola Telino', 12.5, 'Below Average'),
#  ('Mascarpone Fabioli', 32, 'Above Average'),
#  ('Geitost', 2.5, 'Below Average'),
#  ('Sasquatch Ale', 14, 'Below Average'),
#  ('Steeleye Stout', 18, 'Below Average'),
#  ('Inlagd Sill', 19, 'Below Average'),
#  ('Gravad lax', 26, 'Below Average'),
#  ('Cte de Blaye', 263.5, 'Above Average'),
#  ('Chartreuse verte', 18, 'Below Average'),
#  ('Boston Crab Meat', 18.4, 'Below Average'),
#  ("Jack's New England Clam Chowder", 9.65, 'Below Average'),
#  ('Singaporean Hokkien Fried Mee', 14, 'Below Average'),
#  ('Ipoh Coffee', 46, 'Above Average'),
#  ('Gula Malacca', 19.45, 'Below Average'),
#  ('Rogede sild', 9.5, 'Below Average'),
#  ('Spegesild', 12, 'Below Average'),
#  ('Zaanse koeken', 9.5, 'Below Average'),
#  ('Chocolade', 12.75, 'Below Average'),
#  ('Maxilaku', 20, 'Below Average'),
#  ('Valkoinen suklaa', 16.25, 'Below Average'),
#  ('Manjimup Dried Apples', 53, 'Above Average'),
#  ('Filo Mix', 7, 'Below Average'),
#  ('Perth Pasties', 32.8, 'Above Average'),
#  ('Tourtire', 7.45, 'Below Average'),
#  ('Pt chinois', 24, 'Below Average'),
#  ('Gnocchi di nonna Alice', 38, 'Above Average'),
#  ('Ravioli Angelo', 19.5, 'Below Average'),
#  ('Escargots de Bourgogne', 13.25, 'Below Average'),
#  ('Raclette Courdavault', 55, 'Above Average'),
#  ('Camembert Pierrot', 34, 'Above Average'),
#  ("Sirop d'rable", 28.5, 'Below Average'),
#  ('Tarte au sucre', 49.3, 'Above Average'),
#  ('Vegie-spread', 43.9, 'Above Average'),
#  ('Wimmers gute Semmelkndel', 33.25, 'Above Average'),
#  ('Louisiana Fiery Hot Pepper Sauce', 21.05, 'Below Average'),
#  ('Louisiana Hot Spiced Okra', 17, 'Below Average'),
#  ('Laughing Lumberjack Lager', 14, 'Below Average'),
#  ('Scottish Longbreads', 12.5, 'Below Average'),
#  ('Gudbrandsdalsost', 36, 'Above Average'),
#  ('Outback Lager', 15, 'Below Average'),
#  ('Flotemysost', 21.5, 'Below Average'),
#  ('Mozzarella di Giovanni', 34.8, 'Above Average'),
#  ('Rd Kaviar', 15, 'Below Average'),
#  ('Longlife Tofu', 10, 'Below Average'),
#  ('Rhnbru Klosterbier', 7.75, 'Below Average'),
#  ('Lakkalikri', 18, 'Below Average'),
#  ('Original Frankfurter grne Soe', 13, 'Below Average')]

# %% [markdown]
# ###  Exercise 5: Identify Top Management Employees
# In the **Employees** table, if `ReportsTo` is NULL, the employee is part of `'Top Management'`.
# Otherwise, they are `'Staff'`.

# %%
# %%sql
#
# SELECT
#     FirstName,
#     LastName,
#     IF(ReportsTo IS NULL, 'Top Management', 'Staff') as Position
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'Staff'),
#  ('Andrew', 'Fuller', 'Top Management'),
#  ('Janet', 'Leverling', 'Staff'),
#  ('Margaret', 'Peacock', 'Staff'),
#  ('Steven', 'Buchanan', 'Staff'),
#  ('Michael', 'Suyama', 'Staff'),
#  ('Robert', 'King', 'Staff'),
#  ('Laura', 'Callahan', 'Staff'),
#  ('Anne', 'Dodsworth', 'Staff')]

# %% [markdown]
# ###  Challenge Question
# Using the **Products** table, retrieve the following:
#
# - ProductName
# - UnitPrice
# - UnitsInStock
# - StockStatus (Low, Medium, or High based on UnitsInStock)
# - PriceLevel (Cheap, Affordable, or Expensive based on UnitPrice)
#
# Use CASE statements to categorize products based on stock and price.

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitPrice,
#     UnitsInStock,
#     CASE
#         WHEN UnitsInStock < 20 THEN 'Low'
#         WHEN UnitsInStock BETWEEN 20 AND 50 THEN 'Medium'
#         ELSE 'High'
#     END AS StockStatus,
#     CASE
#         WHEN UnitPrice < 10 THEN 'Cheap'
#         WHEN UnitPrice BETWEEN 10 AND 50 THEN 'Affordable'
#         ELSE 'Expensive'
#     END AS PriceLevel
# FROM Products;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Chai', 18, 39, 'Medium', 'Affordable'),
#  ('Chang', 19, 17, 'Low', 'Affordable'),
#  ('Aniseed Syrup', 10, 13, 'Low', 'Affordable'),
#  ("Chef Anton's Cajun Seasoning", 22, 53, 'High', 'Affordable'),
#  ("Chef Anton's Gumbo Mix", 21.35, 0, 'Low', 'Affordable'),
#  ("Grandma's Boysenberry Spread", 25, 120, 'High', 'Affordable'),
#  ("Uncle Bob's Organic Dried Pears", 30, 15, 'Low', 'Affordable'),
#  ('Northwoods Cranberry Sauce', 40, 6, 'Low', 'Affordable'),
#  ('Mishi Kobe Niku', 97, 29, 'Medium', 'Expensive'),
#  ('Ikura', 31, 31, 'Medium', 'Affordable'),
#  ('Queso Cabrales', 21, 22, 'Medium', 'Affordable'),
#  ('Queso Manchego La Pastora', 38, 86, 'High', 'Affordable'),
#  ('Konbu', 6, 24, 'Medium', 'Cheap'),
#  ('Tofu', 23.25, 35, 'Medium', 'Affordable'),
#  ('Genen Shouyu', 15.5, 39, 'Medium', 'Affordable'),
#  ('Pavlova', 17.45, 29, 'Medium', 'Affordable'),
#  ('Alice Mutton', 39, 0, 'Low', 'Affordable'),
#  ('Carnarvon Tigers', 62.5, 42, 'Medium', 'Expensive'),
#  ('Teatime Chocolate Biscuits', 9.2, 25, 'Medium', 'Cheap'),
#  ("Sir Rodney's Marmalade", 81, 40, 'Medium', 'Expensive'),
#  ("Sir Rodney's Scones", 10, 3, 'Low', 'Affordable'),
#  ("Gustaf's Knckebrd", 21, 104, 'High', 'Affordable'),
#  ('Tunnbrd', 9, 61, 'High', 'Cheap'),
#  ('Guaran Fantstica', 4.5, 20, 'Medium', 'Cheap'),
#  ('NuNuCa Nu-Nougat-Creme', 14, 76, 'High', 'Affordable'),
#  ('Gumbr Gummibrchen', 31.23, 15, 'Low', 'Affordable'),
#  ('Schoggi Schokolade', 43.9, 49, 'Medium', 'Affordable'),
#  ('Rssle Sauerkraut', 45.6, 26, 'Medium', 'Affordable'),
#  ('Thringer Rostbratwurst', 123.79, 0, 'Low', 'Expensive'),
#  ('Nord-Ost Matjeshering', 25.89, 10, 'Low', 'Affordable'),
#  ('Gorgonzola Telino', 12.5, 0, 'Low', 'Affordable'),
#  ('Mascarpone Fabioli', 32, 9, 'Low', 'Affordable'),
#  ('Geitost', 2.5, 112, 'High', 'Cheap'),
#  ('Sasquatch Ale', 14, 111, 'High', 'Affordable'),
#  ('Steeleye Stout', 18, 20, 'Medium', 'Affordable'),
#  ('Inlagd Sill', 19, 112, 'High', 'Affordable'),
#  ('Gravad lax', 26, 11, 'Low', 'Affordable'),
#  ('Cte de Blaye', 263.5, 17, 'Low', 'Expensive'),
#  ('Chartreuse verte', 18, 69, 'High', 'Affordable'),
#  ('Boston Crab Meat', 18.4, 123, 'High', 'Affordable'),
#  ("Jack's New England Clam Chowder", 9.65, 85, 'High', 'Cheap'),
#  ('Singaporean Hokkien Fried Mee', 14, 26, 'Medium', 'Affordable'),
#  ('Ipoh Coffee', 46, 17, 'Low', 'Affordable'),
#  ('Gula Malacca', 19.45, 27, 'Medium', 'Affordable'),
#  ('Rogede sild', 9.5, 5, 'Low', 'Cheap'),
#  ('Spegesild', 12, 95, 'High', 'Affordable'),
#  ('Zaanse koeken', 9.5, 36, 'Medium', 'Cheap'),
#  ('Chocolade', 12.75, 15, 'Low', 'Affordable'),
#  ('Maxilaku', 20, 10, 'Low', 'Affordable'),
#  ('Valkoinen suklaa', 16.25, 65, 'High', 'Affordable'),
#  ('Manjimup Dried Apples', 53, 20, 'Medium', 'Expensive'),
#  ('Filo Mix', 7, 38, 'Medium', 'Cheap'),
#  ('Perth Pasties', 32.8, 0, 'Low', 'Affordable'),
#  ('Tourtire', 7.45, 21, 'Medium', 'Cheap'),
#  ('Pt chinois', 24, 115, 'High', 'Affordable'),
#  ('Gnocchi di nonna Alice', 38, 21, 'Medium', 'Affordable'),
#  ('Ravioli Angelo', 19.5, 36, 'Medium', 'Affordable'),
#  ('Escargots de Bourgogne', 13.25, 62, 'High', 'Affordable'),
#  ('Raclette Courdavault', 55, 79, 'High', 'Expensive'),
#  ('Camembert Pierrot', 34, 19, 'Low', 'Affordable'),
#  ("Sirop d'rable", 28.5, 113, 'High', 'Affordable'),
#  ('Tarte au sucre', 49.3, 17, 'Low', 'Affordable'),
#  ('Vegie-spread', 43.9, 24, 'Medium', 'Affordable'),
#  ('Wimmers gute Semmelkndel', 33.25, 22, 'Medium', 'Affordable'),
#  ('Louisiana Fiery Hot Pepper Sauce', 21.05, 76, 'High', 'Affordable'),
#  ('Louisiana Hot Spiced Okra', 17, 4, 'Low', 'Affordable'),
#  ('Laughing Lumberjack Lager', 14, 52, 'High', 'Affordable'),
#  ('Scottish Longbreads', 12.5, 6, 'Low', 'Affordable'),
#  ('Gudbrandsdalsost', 36, 26, 'Medium', 'Affordable'),
#  ('Outback Lager', 15, 15, 'Low', 'Affordable'),
#  ('Flotemysost', 21.5, 26, 'Medium', 'Affordable'),
#  ('Mozzarella di Giovanni', 34.8, 14, 'Low', 'Affordable'),
#  ('Rd Kaviar', 15, 101, 'High', 'Affordable'),
#  ('Longlife Tofu', 10, 4, 'Low', 'Affordable'),
#  ('Rhnbru Klosterbier', 7.75, 125, 'High', 'Cheap'),
#  ('Lakkalikri', 18, 57, 'High', 'Affordable'),
#  ('Original Frankfurter grne Soe', 13, 32, 'Medium', 'Affordable')]
