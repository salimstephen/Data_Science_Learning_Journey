# %% [markdown]
# ###  **Learning Objectives**
# By the end of this training, you should be able to:
# - Use the `GROUP BY` clause to analyze datasets at different levels of granularity.
# - Connect to a MySQL database and query data using SQL within Jupyter Notebook.
#
#
#
# ###  **Connecting to the MySQL Database**
#
# We’ll connect to the `united_nations` MySQL database that contains the `access_to_basic_services` table.
# Once connected, we can run SQL queries directly from Jupyter Notebook using the `%sql` magic command.

# %%
# %load_ext sql

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ###  Exercise 1 — Access to Managed Drinking Water Services (Region / Sub_region)
#
# **Goal:**
# Calculate the **minimum**, **maximum**, and **average** percentage of people who have access to managed drinking water services, grouped by `Region` and `Sub_region`.
#
# **What we will use:**
# SQL aggregate functions `MIN()`, `MAX()`, and `AVG()`, combined with a `GROUP BY` clause.
#
# **Notes:**
# - We’ll use the column `Pct_managed_drinking_water_services` to represent the percentage of people with access to managed drinking water services.
# - Results will include clear aliases for readability (e.g., `Min_Access`, `Max_Access`, `Avg_Access`).
# - `AVG()` returns a numeric average; you may use rounding or casting in SQL if you want to limit decimal places.
# - Rows are grouped first by `Region`, then by `Sub_region` for analysis at two levels of geographic granularity.
#
# **Expected output columns:**
# - `Region` — top-level geographic region
# - `Sub_region` — more specific geographic area within the region
# - `Min_Access` — minimum percentage of people with managed drinking water access in that group
# - `Max_Access` — maximum percentage of people with managed drinking water access in that group
# - `Avg_Access` — average percentage of people with managed drinking water access in that group
#
# **Example:**
# This query helps identify which regions and sub-regions have the highest, lowest, and typical levels of access to managed drinking water services.

# %%
# %%sql
# SELECT
#     Region,
#     Sub_region,
#     MIN(Pct_managed_drinking_water_services) AS Min_Access,
#     MAX(Pct_managed_drinking_water_services) AS Max_Access,
#     AVG(Pct_managed_drinking_water_services) AS Avg_Access
# FROM access_to_basic_services
# GROUP BY Region, Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost/united_nations
# 18 rows affected.
# [('Central and Southern Asia', 'Central Asia', Decimal('80.33'), Decimal('100.00'), Decimal('93.144667')),
#  ('Central and Southern Asia', 'Southern Asia', Decimal('67.00'), Decimal('99.67'), Decimal('91.894074')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', Decimal('75.67'), Decimal('100.00'), Decimal('92.699667')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', Decimal('73.33'), Decimal('100.00'), Decimal('90.626061')),
#  ('Europe and Northern America', 'Northern America', Decimal('91.00'), Decimal('100.00'), Decimal('97.911333')),
#  ('Latin America and the Caribbean', 'Caribbean', Decimal('64.00'), Decimal('100.00'), Decimal('96.005000')),
#  ('Latin America and the Caribbean', 'Central America', Decimal('79.00'), Decimal('100.00'), Decimal('93.798125')),
#  ('Latin America and the Caribbean', 'South America', Decimal('86.00'), Decimal('100.00'), Decimal('94.880952')),
#  ('Northern Africa and Western Asia', 'Northern Africa', Decimal('61.33'), Decimal('100.00'), Decimal('88.906111')),
#  ('Northern Africa and Western Asia', 'Western Asia', Decimal('59.00'), Decimal('100.00'), Decimal('95.031204')),
#  ('Oceania', 'Australia and New Zealand', Decimal('100.00'), Decimal('100.00'), Decimal('100.000000')),
#  ('Oceania', 'Melanesia', Decimal('53.67'), Decimal('99.00'), Decimal('82.700333')),
#  ('Oceania', 'Micronesia', Decimal('73.67'), Decimal('100.00'), Decimal('93.414634')),
#  ('Oceania', 'Polynesia', Decimal('91.00'), Decimal('100.00'), Decimal('98.506481')),
#  ('Sub-Saharan Africa', 'Eastern Africa', Decimal('46.33'), Decimal('100.00'), Decimal('70.128421')),
#  ('Sub-Saharan Africa', 'Middle Africa', Decimal('38.33'), Decimal('77.33'), Decimal('58.967059')),
#  ('Sub-Saharan Africa', 'Southern Africa', Decimal('73.33'), Decimal('92.00'), Decimal('82.645000')),
#  ('Sub-Saharan Africa', 'Western Africa', Decimal('53.33'), Decimal('99.00'), Decimal('72.365686'))]

# %% [markdown]
# ### Exercise 2 — Number of Countries per Region and Sub_region
#
# **Goal:**
# Determine the **number of countries** within each `Region` and `Sub_region`.
#
# **What we will use:**
# The SQL aggregate function `COUNT()` in combination with the `GROUP BY` clause.
#
# **Notes:**
# - We’ll use the `Country_name` column to count how many countries belong to each region and sub-region.
# - The result will include an alias `Country_Count` for clarity.
# - Grouping by both `Region` and `Sub_region` allows us to analyze the data at two geographic levels.
#
# **Expected output columns:**
# - `Region` — top-level geographic region
# - `Sub_region` — more specific geographic area within the region
# - `Country_Count` — number of countries in that region and sub-region
#
# **Example:**
# This query helps us understand how countries are distributed across different regions and sub-regions.

# %%
# %%sql
#
# SELECT
#     Region,
#     Sub_region,
#     COUNT(Country_name) AS Country_Count
# FROM access_to_basic_services
# GROUP BY Region, Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost/united_nations
# 18 rows affected.
# [('Central and Southern Asia', 'Central Asia', 30),
#  ('Central and Southern Asia', 'Southern Asia', 54),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 30),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 66),
#  ('Europe and Northern America', 'Northern America', 30),
#  ('Latin America and the Caribbean', 'Caribbean', 128),
#  ('Latin America and the Caribbean', 'Central America', 48),
#  ('Latin America and the Caribbean', 'South America', 84),
#  ('Northern Africa and Western Asia', 'Northern Africa', 36),
#  ('Northern Africa and Western Asia', 'Western Asia', 108),
#  ('Oceania', 'Australia and New Zealand', 12),
#  ('Oceania', 'Melanesia', 30),
#  ('Oceania', 'Micronesia', 41),
#  ('Oceania', 'Polynesia', 54),
#  ('Sub-Saharan Africa', 'Eastern Africa', 114),
#  ('Sub-Saharan Africa', 'Middle Africa', 51),
#  ('Sub-Saharan Africa', 'Southern Africa', 30),
#  ('Sub-Saharan Africa', 'Western Africa', 102)]

# %% [markdown]
# ### Exercise 3 — Total GDP per Region and Sub_region
#
# **Goal:**
# Determine the **total GDP** for each `Region` and `Sub_region` by summing all GDP values.
#
# **What we will use:**
# The SQL aggregate function `SUM()` together with the `GROUP BY` clause.
#
# **Notes:**
# - We’ll use the column `Est_gdp_in_billions`, which contains the estimated GDP values (in billions).
# - The result will include an alias `Total_GDP` for better readability.
# - Grouping by both `Region` and `Sub_region` provides insight into the economic scale of different geographic areas.
#
# **Expected output columns:**
# - `Region` — top-level geographic region
# - `Sub_region` — more specific area within the region
# - `Total_GDP` — total estimated GDP (in billions) for that region and sub-region
#
# **Example:**
# This query helps us compare economic output across different regions and sub-regions to identify which areas have the largest or smallest total GDP.

# %%
# %%sql
#
# SELECT
#     Region,
#     Sub_region,
#     SUM(Est_gdp_in_billions) AS Total_GDP
# FROM access_to_basic_services
# GROUP BY Region, Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost/united_nations
# 18 rows affected.
# [('Central and Southern Asia', 'Central Asia', Decimal('1670.32')),
#  ('Central and Southern Asia', 'Southern Asia', Decimal('19824.66')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', Decimal('107123.37')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', Decimal('15563.18')),
#  ('Europe and Northern America', 'Northern America', Decimal('9905.96')),
#  ('Latin America and the Caribbean', 'Caribbean', Decimal('2070.17')),
#  ('Latin America and the Caribbean', 'Central America', Decimal('8524.66')),
#  ('Latin America and the Caribbean', 'South America', Decimal('19959.58')),
#  ('Northern Africa and Western Asia', 'Northern Africa', Decimal('2736.80')),
#  ('Northern Africa and Western Asia', 'Western Asia', Decimal('13605.83')),
#  ('Oceania', 'Australia and New Zealand', Decimal('9241.73')),
#  ('Oceania', 'Melanesia', Decimal('237.87')),
#  ('Oceania', 'Micronesia', Decimal('46.92')),
#  ('Oceania', 'Polynesia', Decimal('46.76')),
#  ('Sub-Saharan Africa', 'Eastern Africa', Decimal('1944.61')),
#  ('Sub-Saharan Africa', 'Middle Africa', Decimal('837.34')),
#  ('Sub-Saharan Africa', 'Southern Africa', Decimal('2386.64')),
#  ('Sub-Saharan Africa', 'Western Africa', Decimal('3621.31'))]

# %% [markdown]
# ### Summary
#
# We can also combine all of our previous queries into a **single query** to get one consolidated result that includes:
# - The **minimum**, **maximum**, and **average** access to managed drinking water services,
# - The **number of countries**, and
# - The **total GDP**
#
# for each `Region` and `Sub_region`.
#
# By combining these aggregations, we can analyze multiple dimensions of our dataset at once — providing a clearer overview of development indicators across different regions.

# %%
# %%sql
#
# SELECT
#     Region,
#     Sub_region,
#     MIN(Pct_managed_drinking_water_services) AS Min_Access,
#     MAX(Pct_managed_drinking_water_services) AS Max_Access,
#     AVG(Pct_managed_drinking_water_services) AS Avg_Access,
#     COUNT(Country_name) AS Country_Count,
#     SUM(Est_gdp_in_billions) AS Total_GDP
# FROM access_to_basic_services
# GROUP BY Region, Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost/united_nations
# 18 rows affected.
# [('Central and Southern Asia', 'Central Asia', Decimal('80.33'), Decimal('100.00'), Decimal('93.144667'), 30, Decimal('1670.32')),
#  ('Central and Southern Asia', 'Southern Asia', Decimal('67.00'), Decimal('99.67'), Decimal('91.894074'), 54, Decimal('19824.66')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', Decimal('75.67'), Decimal('100.00'), Decimal('92.699667'), 30, Decimal('107123.37')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', Decimal('73.33'), Decimal('100.00'), Decimal('90.626061'), 66, Decimal('15563.18')),
#  ('Europe and Northern America', 'Northern America', Decimal('91.00'), Decimal('100.00'), Decimal('97.911333'), 30, Decimal('9905.96')),
#  ('Latin America and the Caribbean', 'Caribbean', Decimal('64.00'), Decimal('100.00'), Decimal('96.005000'), 128, Decimal('2070.17')),
#  ('Latin America and the Caribbean', 'Central America', Decimal('79.00'), Decimal('100.00'), Decimal('93.798125'), 48, Decimal('8524.66')),
#  ('Latin America and the Caribbean', 'South America', Decimal('86.00'), Decimal('100.00'), Decimal('94.880952'), 84, Decimal('19959.58')),
#  ('Northern Africa and Western Asia', 'Northern Africa', Decimal('61.33'), Decimal('100.00'), Decimal('88.906111'), 36, Decimal('2736.80')),
#  ('Northern Africa and Western Asia', 'Western Asia', Decimal('59.00'), Decimal('100.00'), Decimal('95.031204'), 108, Decimal('13605.83')),
#  ('Oceania', 'Australia and New Zealand', Decimal('100.00'), Decimal('100.00'), Decimal('100.000000'), 12, Decimal('9241.73')),
#  ('Oceania', 'Melanesia', Decimal('53.67'), Decimal('99.00'), Decimal('82.700333'), 30, Decimal('237.87')),
#  ('Oceania', 'Micronesia', Decimal('73.67'), Decimal('100.00'), Decimal('93.414634'), 41, Decimal('46.92')),
#  ('Oceania', 'Polynesia', Decimal('91.00'), Decimal('100.00'), Decimal('98.506481'), 54, Decimal('46.76')),
#  ('Sub-Saharan Africa', 'Eastern Africa', Decimal('46.33'), Decimal('100.00'), Decimal('70.128421'), 114, Decimal('1944.61')),
#  ('Sub-Saharan Africa', 'Middle Africa', Decimal('38.33'), Decimal('77.33'), Decimal('58.967059'), 51, Decimal('837.34')),
#  ('Sub-Saharan Africa', 'Southern Africa', Decimal('73.33'), Decimal('92.00'), Decimal('82.645000'), 30, Decimal('2386.64')),
#  ('Sub-Saharan Africa', 'Western Africa', Decimal('53.33'), Decimal('99.00'), Decimal('72.365686'), 102, Decimal('3621.31'))]
