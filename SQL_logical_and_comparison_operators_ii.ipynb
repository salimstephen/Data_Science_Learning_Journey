# %% [markdown]
# ##  Learning Objectives
#
# In this training session, we will focus on expanding our SQL filtering and conditional logic skills.
#
# By the end of this section, we will be able to:
#
# - **Use `IS NULL` and `IS NOT NULL`** to identify records with missing or non-missing values.
# - **Use `IN` and `NOT IN`** to efficiently include or exclude specific categories or countries in a query.
# - **Explore potential correlations** between a country's **GDP** and the **availability of managed drinking water and sanitation services**, with a focus on **Sub-Saharan Africa**.
#
# ---
#
# These skills are essential for understanding **data completeness**, **pattern recognition**, and performing **data-driven analysis** in real-world datasets.

# %%
# %load_ext sql

# %% [markdown]
# To make a query, we add the %%sql command to the start of a cell, create one open line and then the query like below and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise: Exploring Correlation Between GDP and Access to Basic Services
#
# In this exercise, we will continue working with the **`united_nations.access_to_basic_services`** table.
# This dataset provides valuable insights into different countries’ access to **managed drinking water**, **sanitation services**, and their **estimated GDP**.
#
# ###  Objective
# We aim to determine whether there is a **correlation between a country's GDP** and its **access to basic services** — focusing on countries within the **Sub-Saharan Africa** region.
#
# ---
#
# ###  Task 1: Filter Data for Sub-Saharan Africa (2020)
# We’ll begin by selecting all relevant data for:
# - **Region:** Sub-Saharan Africa
# - **Year (Time_period):** 2020
#
# This will give us a focused dataset to analyze the relationship between economic output (GDP) and access to essential services.

# %%
# %%sql
# -- Task 1: Select data for Sub-Saharan Africa in the year 2020
# -- Filtering the dataset to focus only on Sub-Saharan African countries for analysis
#
# SELECT
#     Region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM access_to_basic_services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
# ORDER BY Country_name ASC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 47 rows affected.
# [('Sub-Saharan Africa', 'Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), Decimal('33.428486')),
#  ('Sub-Saharan Africa', 'Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), Decimal('12.643123')),
#  ('Sub-Saharan Africa', 'Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('14.93'), Decimal('2.546402')),
#  ('Sub-Saharan Africa', 'Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('21.522626')),
#  ('Sub-Saharan Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), Decimal('12.220227')),
#  ('Sub-Saharan Africa', 'Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), Decimal('0.582640')),
#  ('Sub-Saharan Africa', 'Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), Decimal('26.491087')),
#  ('Sub-Saharan Africa', 'Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('5.343020')),
#  ('Sub-Saharan Africa', 'Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('16.644701')),
#  ('Sub-Saharan Africa', 'Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None, None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None, None),
#  ('Sub-Saharan Africa', 'Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), Decimal('1.090156')),
#  ('Sub-Saharan Africa', 'Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('3.98'), Decimal('1.180655')),
#  ('Sub-Saharan Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), Decimal('117.190911')),
#  ('Sub-Saharan Africa', 'Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), Decimal('2.292573')),
#  ('Sub-Saharan Africa', 'Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None, None),
#  ('Sub-Saharan Africa', 'Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), Decimal('32.180401')),
#  ('Sub-Saharan Africa', 'Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), Decimal('13.205153')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), Decimal('2.015828')),
#  ('Sub-Saharan Africa', 'Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), Decimal('51.985780')),
#  ('Sub-Saharan Africa', 'Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.23'), Decimal('2.254100')),
#  ('Sub-Saharan Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), Decimal('5.087584')),
#  ('Sub-Saharan Africa', 'Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('28.225177')),
#  ('Sub-Saharan Africa', 'Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('12.18'), Decimal('19.377061')),
#  ('Sub-Saharan Africa', 'Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('17.47'), Decimal('21.224040')),
#  ('Sub-Saharan Africa', 'Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('8.41'), Decimal('4.498604')),
#  ('Sub-Saharan Africa', 'Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('11.40'), Decimal('1.265740')),
#  ('Sub-Saharan Africa', 'Mayotte', 2020, Decimal('96.00'), Decimal('100.00'), None, None),
#  ('Sub-Saharan Africa', 'Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('14.03'), Decimal('31.178239')),
#  ('Sub-Saharan Africa', 'Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('10.58'), Decimal('2.489098')),
#  ('Sub-Saharan Africa', 'Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('24.333639')),
#  ('Sub-Saharan Africa', 'Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), Decimal('208.327405')),
#  ('Sub-Saharan Africa', 'Réunion', 2020, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Sub-Saharan Africa', 'Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('10.18'), Decimal('13.146362')),
#  ('Sub-Saharan Africa', 'Saint Helena', 2020, Decimal('99.00'), Decimal('100.00'), None, None),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), Decimal('0.218641')),
#  ('Sub-Saharan Africa', 'Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), Decimal('16.436120')),
#  ('Sub-Saharan Africa', 'Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('4.06'), Decimal('8.233970')),
#  ('Sub-Saharan Africa', 'Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('16.537016')),
#  ('Sub-Saharan Africa', 'South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), Decimal('58.801927')),
#  ('Sub-Saharan Africa', 'South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), None, Decimal('10.606227')),
#  ('Sub-Saharan Africa', 'Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('7.57'), Decimal('8.442580')),
#  ('Sub-Saharan Africa', 'Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), Decimal('44.404611')),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None, None),
#  ('Sub-Saharan Africa', 'Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), Decimal('18.927715')),
#  ('Sub-Saharan Africa', 'Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), Decimal('15.669666'))]

# %% [markdown]
# ###  Task 2: Identifying NULL Values in GDP
#
# Before analyzing correlations, it’s important to ensure our data is complete and reliable.
#
# Some entries in the dataset may have **NULL (missing)** values in the **`Est_gdp_in_billions`** column.
# Countries with missing GDP data cannot contribute meaningfully to our analysis, as we need both GDP and service access values for comparison.
#
# In this task, we will:
# - Check if there are any **NULL values** in the GDP column.
# - Identify which countries have missing GDP data within the **Sub-Saharan Africa (2020)** subset.

# %%
# %%sql
# -- Task 2: Checking for NULL values in GDP data
# -- Identifying Sub-Saharan African countries with missing GDP values in 2020
#
# SELECT
#     Region,
#     Country_name,
#     Time_period,
#     Est_gdp_in_billions
# FROM access_to_basic_services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Est_gdp_in_billions IS NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Sub-Saharan Africa', 'Mayotte', 2020, None),
#  ('Sub-Saharan Africa', 'Réunion', 2020, None),
#  ('Sub-Saharan Africa', 'South Sudan', 2020, None),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', 2020, None),
#  ('Sub-Saharan Africa', 'Congo', 2020, None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', 2020, None),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", 2020, None),
#  ('Sub-Saharan Africa', 'Gambia', 2020, None),
#  ('Sub-Saharan Africa', 'Saint Helena', 2020, None)]

# %% [markdown]
# ###  Task 3: Excluding NULL GDP Values
#
# Now that we’ve checked for missing GDP values, we’ll refine our dataset to include **only countries with valid GDP data**.
#
# By using the **`IS NOT NULL`** condition, we ensure that all selected rows have complete GDP information.
# This step helps us prepare a clean dataset for accurate correlation analysis between GDP and access to basic services.

# %%
# %%sql
# -- Task 3: Excluding countries with NULL GDP values
# -- Creating a clean dataset for Sub-Saharan Africa (2020) with complete GDP records
#
# SELECT
#     Region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM access_to_basic_services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Est_gdp_in_billions IS NOT NULL
# ORDER BY Country_name ASC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 38 rows affected.
# [('Sub-Saharan Africa', 'Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), Decimal('33.428486')),
#  ('Sub-Saharan Africa', 'Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), Decimal('12.643123')),
#  ('Sub-Saharan Africa', 'Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('14.93'), Decimal('2.546402')),
#  ('Sub-Saharan Africa', 'Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('21.522626')),
#  ('Sub-Saharan Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), Decimal('12.220227')),
#  ('Sub-Saharan Africa', 'Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), Decimal('0.582640')),
#  ('Sub-Saharan Africa', 'Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), Decimal('26.491087')),
#  ('Sub-Saharan Africa', 'Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('5.343020')),
#  ('Sub-Saharan Africa', 'Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('16.644701')),
#  ('Sub-Saharan Africa', 'Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), Decimal('1.090156')),
#  ('Sub-Saharan Africa', 'Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('3.98'), Decimal('1.180655')),
#  ('Sub-Saharan Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), Decimal('117.190911')),
#  ('Sub-Saharan Africa', 'Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), Decimal('2.292573')),
#  ('Sub-Saharan Africa', 'Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), Decimal('32.180401')),
#  ('Sub-Saharan Africa', 'Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), Decimal('13.205153')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), Decimal('2.015828')),
#  ('Sub-Saharan Africa', 'Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), Decimal('51.985780')),
#  ('Sub-Saharan Africa', 'Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.23'), Decimal('2.254100')),
#  ('Sub-Saharan Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), Decimal('5.087584')),
#  ('Sub-Saharan Africa', 'Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('28.225177')),
#  ('Sub-Saharan Africa', 'Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('12.18'), Decimal('19.377061')),
#  ('Sub-Saharan Africa', 'Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('17.47'), Decimal('21.224040')),
#  ('Sub-Saharan Africa', 'Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('8.41'), Decimal('4.498604')),
#  ('Sub-Saharan Africa', 'Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('11.40'), Decimal('1.265740')),
#  ('Sub-Saharan Africa', 'Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('14.03'), Decimal('31.178239')),
#  ('Sub-Saharan Africa', 'Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('10.58'), Decimal('2.489098')),
#  ('Sub-Saharan Africa', 'Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('24.333639')),
#  ('Sub-Saharan Africa', 'Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), Decimal('208.327405')),
#  ('Sub-Saharan Africa', 'Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('10.18'), Decimal('13.146362')),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), Decimal('0.218641')),
#  ('Sub-Saharan Africa', 'Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), Decimal('16.436120')),
#  ('Sub-Saharan Africa', 'Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('4.06'), Decimal('8.233970')),
#  ('Sub-Saharan Africa', 'Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('16.537016')),
#  ('Sub-Saharan Africa', 'South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), Decimal('58.801927')),
#  ('Sub-Saharan Africa', 'Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('7.57'), Decimal('8.442580')),
#  ('Sub-Saharan Africa', 'Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), Decimal('44.404611')),
#  ('Sub-Saharan Africa', 'Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), Decimal('18.927715')),
#  ('Sub-Saharan Africa', 'Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), Decimal('15.669666'))]

# %% [markdown]
# ###  Task 4: Analyzing GDP and Access to Basic Services in the Top 5 Economies
#
# To better understand potential correlations between **GDP** and **access to basic services**,
# we will focus on the **top 5 economies in Sub-Saharan Africa**:
#
# -  Nigeria
# -  South Africa
# -  Ethiopia
# -  Kenya
# -  Ghana
#
# ###  Objective
# Retrieve data for these five countries in the **year 2020**, ensuring only records with **non-null GDP values** are included.
#
# This filtered dataset will help us compare how economic strength may influence access to managed drinking water and sanitation services.

# %%
# %%sql
# -- Task 4: Retrieve data for the top 5 economies in Sub-Saharan Africa (2020)
# -- Filtering by specific countries and ensuring GDP values are not null
#
# SELECT
#     Region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM access_to_basic_services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Country_name IN ('Nigeria', 'South Africa', 'Ethiopia', 'Kenya', 'Ghana')
#     AND Est_gdp_in_billions IS NOT NULL
# ORDER BY Est_gdp_in_billions DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Sub-Saharan Africa', 'Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), Decimal('208.327405')),
#  ('Sub-Saharan Africa', 'South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), Decimal('58.801927')),
#  ('Sub-Saharan Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), Decimal('117.190911')),
#  ('Sub-Saharan Africa', 'Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), Decimal('51.985780')),
#  ('Sub-Saharan Africa', 'Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), Decimal('32.180401'))]

# %% [markdown]
# ###  Task 5: Exploring the Rest of Sub-Saharan Africa
#
# In the previous task, we focused on the **top 5 economies** in Sub-Saharan Africa
# (`Nigeria`, `South Africa`, `Ethiopia`, `Kenya`, and `Ghana`).
#
# Now, we’ll expand our view to include **the rest of Sub-Saharan Africa** —
# excluding those five major economies.
#
# ###  Objective
# To analyze GDP and access to basic services for all other Sub-Saharan African countries in **2020**,
# excluding the top 5 economies identified earlier.
#
# This comparison allows us to explore how smaller or developing economies perform in providing essential services like drinking water and sanitation.

# %%
# %%sql
# -- Task 5: Retrieve data for Sub-Saharan African countries excluding the top 5 economies
# -- Focus: Countries other than Nigeria, South Africa, Ethiopia, Kenya, and Ghana (Year 2020)
#
# SELECT
#     Region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM access_to_basic_services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Country_name NOT IN ('Nigeria', 'South Africa', 'Ethiopia', 'Kenya', 'Ghana')
#     AND Est_gdp_in_billions IS NOT NULL
# ORDER BY Est_gdp_in_billions DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 33 rows affected.
# [('Sub-Saharan Africa', 'Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), Decimal('33.428486')),
#  ('Sub-Saharan Africa', 'Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), Decimal('26.491087')),
#  ('Sub-Saharan Africa', 'Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), Decimal('44.404611')),
#  ('Sub-Saharan Africa', 'Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), Decimal('16.436120')),
#  ('Sub-Saharan Africa', 'Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), Decimal('15.669666')),
#  ('Sub-Saharan Africa', 'Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), Decimal('18.927715')),
#  ('Sub-Saharan Africa', 'Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('17.93'), Decimal('21.522626')),
#  ('Sub-Saharan Africa', 'Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('17.47'), Decimal('21.224040')),
#  ('Sub-Saharan Africa', 'Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('15.65'), Decimal('12.643123')),
#  ('Sub-Saharan Africa', 'Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), Decimal('2.292573')),
#  ('Sub-Saharan Africa', 'Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('14.93'), Decimal('2.546402')),
#  ('Sub-Saharan Africa', 'Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('14.18'), Decimal('13.205153')),
#  ('Sub-Saharan Africa', 'Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('14.03'), Decimal('31.178239')),
#  ('Sub-Saharan Africa', 'Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('13.74'), Decimal('24.333639')),
#  ('Sub-Saharan Africa', 'Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), Decimal('28.225177')),
#  ('Sub-Saharan Africa', 'Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('12.18'), Decimal('19.377061')),
#  ('Sub-Saharan Africa', 'Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('11.40'), Decimal('1.265740')),
#  ('Sub-Saharan Africa', 'Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), Decimal('16.644701')),
#  ('Sub-Saharan Africa', 'Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('10.58'), Decimal('2.489098')),
#  ('Sub-Saharan Africa', 'Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('10.18'), Decimal('13.146362')),
#  ('Sub-Saharan Africa', 'Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('8.41'), Decimal('4.498604')),
#  ('Sub-Saharan Africa', 'Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('7.57'), Decimal('8.442580')),
#  ('Sub-Saharan Africa', 'Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), Decimal('16.537016')),
#  ('Sub-Saharan Africa', 'Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('4.06'), Decimal('8.233970')),
#  ('Sub-Saharan Africa', 'Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('3.98'), Decimal('1.180655')),
#  ('Sub-Saharan Africa', 'Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), Decimal('1.090156')),
#  ('Sub-Saharan Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('3.04'), Decimal('5.087584')),
#  ('Sub-Saharan Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), Decimal('12.220227')),
#  ('Sub-Saharan Africa', 'Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), Decimal('5.343020')),
#  ('Sub-Saharan Africa', 'Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.23'), Decimal('2.254100')),
#  ('Sub-Saharan Africa', 'Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('1.70'), Decimal('0.582640')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('1.43'), Decimal('2.015828')),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), Decimal('0.218641'))]

# %% [markdown]
# ###  Summary
#
# In this exercise, we explored how to handle missing and filtered data using SQL conditional statements.
#
# We:
# - Used the **`IS NULL`** statement to identify countries with missing GDP values.
# - Applied the **`IS NOT NULL`** statement to exclude those countries from our analysis.
# - Used the **`IN`** statement to focus on the **top 5 GDP economies** in Sub-Saharan Africa (`Nigeria`, `South Africa`, `Ethiopia`, `Kenya`, and `Ghana`).
# - Used the **`NOT IN`** statement to examine the **remaining countries** in the region.
#
# After analyzing the data, we found that **there isn’t a clear or noticeable correlation** between a country’s GDP and its **access to drinking water and sanitation services** in Sub-Saharan Africa.
# This suggests that **economic size alone may not determine service accessibility**, and other factors such as governance, infrastructure investment, and policy priorities likely play a role.
