# %% [markdown]
# #  Subquery in the FROM Clause — Using the `Economic_Indicators` Table
#
# ###  Description
# In this lesson, we’ll use a **subquery as a temporary table** — also known as a *derived table*.
# This allows us to:
# - Perform calculations within one query.
# - Then use the results inside another query.
#
#
#
# ###  Learning Objectives
# By the end of this exercise, you’ll be able to:
# - Use **subqueries in the FROM clause**.
# - Treat a subquery result like a temporary dataset.
# - Combine subqueries with filters and aggregates for richer insights.
#
#
#
# ###  Connect to the MySQL Database
# We’ll use the **`Economic_Indicators`** table from the **`united_nations`** database.

# %%
# %load_ext sql

# %% [markdown]
# ###  Preview the Table
# Let’s view a few records from the `Economic_Indicators` table to confirm its structure.

# %%
# %%sql
# SELECT
#     *
# FROM
#     Economic_Indicators
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Kazakhstan', 2015, Decimal('184.39'), Decimal('17.542806'), Decimal('4.93'), Decimal('2699700.00')),
#  ('Kazakhstan', 2016, Decimal('137.28'), Decimal('17.794055'), Decimal('4.96'), Decimal('2699700.00')),
#  ('Kazakhstan', 2017, Decimal('166.81'), Decimal('18.037776'), Decimal('4.90'), Decimal('2699700.00')),
#  ('Kazakhstan', 2018, Decimal('179.34'), Decimal('18.276452'), Decimal('4.85'), Decimal('2699700.00')),
#  ('Kazakhstan', 2019, Decimal('181.67'), Decimal('18.513673'), Decimal('4.80'), Decimal('2699700.00'))]

# %% [markdown]
# ##  Exercise
#
# **Question:**
# What is the **average GDP** and **average population** for countries with **unemployment rates above 5%**?
#
# We’ll solve this step-by-step:
# 1. Create a subquery to calculate the average GDP and population for each country.
# 2. Filter countries with unemployment rates greater than 5%.
# 3. Combine the queries using a **subquery in the FROM clause**.

# %% [markdown]
# ### Step 1️ — Create the Subquery
# This subquery calculates each country’s **average GDP** and **average population** for the year 2020.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# WHERE
#     Time_period = 2020
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 165 rows affected.
# [('Kazakhstan', Decimal('171.080000'), Decimal('18.7556660000')),
#  ('Kyrgyzstan', None, None),
#  ('Tajikistan', Decimal('8.130000'), Decimal('9.5432070000')),
#  ('Turkmenistan', None, Decimal('6.2504380000')),
#  ('Uzbekistan', Decimal('59.890000'), Decimal('34.2320500000')),
#  ('Afghanistan', Decimal('20.140000'), Decimal('38.9722300000')),
#  ('Bangladesh', Decimal('373.900000'), Decimal('167.4209510000')),
#  ('Bhutan', Decimal('2.330000'), Decimal('0.7725060000')),
#  ('India', Decimal('2667.690000'), Decimal('1396.3871270000')),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Maldives', Decimal('3.750000'), Decimal('0.5144380000')),
#  ('Nepal', Decimal('33.430000'), Decimal('29.3486270000')),
#  ('Pakistan', Decimal('300.430000'), Decimal('227.1967410000')),
#  ('Sri Lanka', Decimal('85.350000'), Decimal('21.9190000000')),
#  ('China', Decimal('14687.670000'), Decimal('1411.1000000000')),
#  ("Democratic People's Republic of Korea", None, None),
#  ('Japan', Decimal('5040.110000'), Decimal('126.2610000000')),
#  ('Mongolia', Decimal('13.310000'), Decimal('3.2943350000')),
#  ('Republic of Korea', None, None),
#  ('Brunei Darussalam', Decimal('12.010000'), Decimal('0.4417250000')),
#  ('Cambodia', Decimal('25.870000'), Decimal('16.3968600000')),
#  ('Indonesia', Decimal('1058.690000'), Decimal('271.8579700000')),
#  ("Lao People's Democratic Republic", None, None),
#  ('Malaysia', Decimal('337.340000'), Decimal('33.1999930000')),
#  ('Myanmar', Decimal('78.930000'), Decimal('53.4231980000')),
#  ('Philippines', Decimal('361.750000'), Decimal('112.1909770000')),
#  ('Singapore', Decimal('345.300000'), Decimal('5.6858070000')),
#  ('Thailand', Decimal('499.680000'), Decimal('71.4756640000')),
#  ('Timor-Leste', Decimal('2.160000'), Decimal('1.2999950000')),
#  ('Viet Nam', None, None),
#  ('Bermuda', Decimal('6.890000'), Decimal('0.0638930000')),
#  ('Canada', Decimal('1645.420000'), Decimal('38.0372040000')),
#  ('Greenland', Decimal('3.080000'), Decimal('0.0563670000')),
#  ('Saint Pierre and Miquelon', None, None),
#  ('United States of America', None, None),
#  ('Barbados', Decimal('4.670000'), Decimal('0.2806930000')),
#  ('British Virgin Islands', None, Decimal('0.0309100000')),
#  ('Cuba', Decimal('107.350000'), Decimal('11.3006980000')),
#  ('Dominican Republic', Decimal('78.840000'), Decimal('10.9996640000')),
#  ('Guadeloupe', None, None),
#  ('Haiti', Decimal('14.510000'), Decimal('11.3068010000')),
#  ('Jamaica', Decimal('13.810000'), Decimal('2.8204360000')),
#  ('Martinique', None, None),
#  ('Montserrat', None, None),
#  ('Puerto Rico', Decimal('103.020000'), Decimal('3.2815380000')),
#  ('Saint Barthélemy', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Trinidad and Tobago', Decimal('21.060000'), Decimal('1.5181470000')),
#  ('United States Virgin Islands', None, None),
#  ('Belize', Decimal('2.080000'), Decimal('0.3949210000')),
#  ('Costa Rica', Decimal('62.160000'), Decimal('5.1231050000')),
#  ('El Salvador', Decimal('24.560000'), Decimal('6.2927310000')),
#  ('Guatemala', Decimal('77.630000'), Decimal('16.8583330000')),
#  ('Honduras', Decimal('23.830000'), Decimal('10.1217630000')),
#  ('Mexico', Decimal('1090.520000'), Decimal('125.9983020000')),
#  ('Nicaragua', Decimal('12.590000'), Decimal('6.7558950000')),
#  ('Panama', Decimal('53.980000'), Decimal('4.2943960000')),
#  ('Argentina', Decimal('385.540000'), Decimal('45.3767630000')),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Brazil', Decimal('1448.560000'), Decimal('213.1963040000')),
#  ('Chile', Decimal('252.730000'), Decimal('19.3003150000')),
#  ('Colombia', Decimal('270.300000'), Decimal('50.9306620000')),
#  ('Ecuador', Decimal('99.290000'), Decimal('17.5885950000')),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('French Guiana', None, None),
#  ('Guyana', Decimal('5.470000'), Decimal('0.7972020000')),
#  ('Paraguay', Decimal('35.430000'), Decimal('6.6186950000')),
#  ('Peru', Decimal('201.710000'), Decimal('33.3047560000')),
#  ('Suriname', Decimal('2.910000'), Decimal('0.6070650000')),
#  ('Uruguay', Decimal('53.560000'), Decimal('3.4290860000')),
#  ('Venezuela (Bolivarian Republic of)', None, None),
#  ('Algeria', Decimal('145.010000'), Decimal('43.4516660000')),
#  ('Egypt', None, None),
#  ('Libya', Decimal('50.360000'), Decimal('6.6539420000')),
#  ('Morocco', Decimal('121.350000'), Decimal('36.6887720000')),
#  ('Sudan', Decimal('27.030000'), Decimal('44.4404860000')),
#  ('Tunisia', Decimal('42.540000'), Decimal('12.1617230000')),
#  ('Armenia', Decimal('12.640000'), Decimal('2.8056080000')),
#  ('Azerbaijan', Decimal('42.690000'), Decimal('10.0931210000')),
#  ('Bahrain', Decimal('34.720000'), Decimal('1.4774690000')),
#  ('Cyprus', Decimal('25.010000'), Decimal('1.2375370000')),
#  ('Georgia', Decimal('15.840000'), Decimal('3.7227160000')),
#  ('Iraq', Decimal('184.370000'), Decimal('42.5569840000')),
#  ('Israel', Decimal('413.270000'), Decimal('9.2151000000')),
#  ('Jordan', Decimal('44.180000'), Decimal('10.9287210000')),
#  ('Kuwait', Decimal('105.960000'), Decimal('4.3604440000')),
#  ('Lebanon', Decimal('31.710000'), Decimal('5.6629230000')),
#  ('Oman', Decimal('75.910000'), Decimal('4.5433990000')),
#  ('Qatar', Decimal('144.410000'), Decimal('2.7603850000')),
#  ('Saudi Arabia', Decimal('703.370000'), Decimal('35.9971070000')),
#  ('State of Palestine', None, None),
#  ('Syrian Arab Republic', Decimal('11.080000'), Decimal('20.7725950000')),
#  ('Türkiye', None, None),
#  ('United Arab Emirates', Decimal('349.470000'), Decimal('9.2872890000')),
#  ('Yemen', None, None),
#  ('Australia', Decimal('1326.900000'), Decimal('25.6552890000')),
#  ('New Zealand', Decimal('211.730000'), Decimal('5.0902000000')),
#  ('Fiji', Decimal('4.480000'), Decimal('0.9204220000')),
#  ('New Caledonia', Decimal('9.440000'), Decimal('0.2711300000')),
#  ('Papua New Guinea', Decimal('23.850000'), Decimal('9.7496400000')),
#  ('Solomon Islands', Decimal('1.540000'), Decimal('0.6911910000')),
#  ('Vanuatu', Decimal('0.900000'), Decimal('0.3116850000')),
#  ('Guam', Decimal('5.890000'), Decimal('0.1692310000')),
#  ('Kiribati', Decimal('0.180000'), Decimal('0.1264630000')),
#  ('Marshall Islands', Decimal('0.240000'), Decimal('0.0434130000')),
#  ('Nauru', Decimal('0.110000'), Decimal('0.0123150000')),
#  ('Northern Mariana Islands', None, Decimal('0.0495870000')),
#  ('Palau', Decimal('0.250000'), Decimal('0.0179720000')),
#  ('American Samoa', Decimal('0.720000'), Decimal('0.0461890000')),
#  ('Cook Islands', None, None),
#  ('French Polynesia', Decimal('5.710000'), Decimal('0.3019200000')),
#  ('Niue', None, None),
#  ('Samoa', Decimal('0.870000'), Decimal('0.2149290000')),
#  ('Tokelau', None, None),
#  ('Tonga', Decimal('0.480000'), Decimal('0.1052540000')),
#  ('Tuvalu', Decimal('0.060000'), Decimal('0.0110690000')),
#  ('Wallis and Futuna Islands', None, None),
#  ('Burundi', Decimal('2.650000'), Decimal('12.2202270000')),
#  ('Djibouti', Decimal('3.180000'), Decimal('1.0901560000')),
#  ('Ethiopia', Decimal('107.660000'), Decimal('117.1909110000')),
#  ('Kenya', Decimal('100.670000'), Decimal('51.9857800000')),
#  ('Madagascar', Decimal('13.050000'), Decimal('28.2251770000')),
#  ('Malawi', Decimal('12.180000'), Decimal('19.3770610000')),
#  ('Mauritius', Decimal('11.400000'), Decimal('1.2657400000')),
#  ('Mayotte', None, None),
#  ('Mozambique', Decimal('14.030000'), Decimal('31.1782390000')),
#  ('Rwanda', Decimal('10.180000'), Decimal('13.1463620000')),
#  ('Réunion', None, None),
#  ('Somalia', Decimal('6.880000'), Decimal('16.5370160000')),
#  ('South Sudan', None, Decimal('10.6062270000')),
#  ('Uganda', Decimal('37.600000'), Decimal('44.4046110000')),
#  ('United Republic of Tanzania', None, None),
#  ('Zambia', Decimal('18.110000'), Decimal('18.9277150000')),
#  ('Zimbabwe', Decimal('21.510000'), Decimal('15.6696660000')),
#  ('Angola', Decimal('53.620000'), Decimal('33.4284860000')),
#  ('Cameroon', Decimal('40.770000'), Decimal('26.4910870000')),
#  ('Central African Republic', Decimal('2.330000'), Decimal('5.3430200000')),
#  ('Chad', Decimal('10.720000'), Decimal('16.6447010000')),
#  ('Congo', None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Gabon', Decimal('15.310000'), Decimal('2.2925730000')),
#  ('Sao Tome and Principe', Decimal('0.470000'), Decimal('0.2186410000')),
#  ('Botswana', Decimal('14.930000'), Decimal('2.5464020000')),
#  ('Eswatini', Decimal('3.980000'), Decimal('1.1806550000')),
#  ('Lesotho', Decimal('2.230000'), Decimal('2.2541000000')),
#  ('Namibia', Decimal('10.580000'), Decimal('2.4890980000')),
#  ('South Africa', Decimal('337.620000'), Decimal('58.8019270000')),
#  ('Benin', Decimal('15.650000'), Decimal('12.6431230000')),
#  ('Burkina Faso', Decimal('17.930000'), Decimal('21.5226260000')),
#  ('Cabo Verde', Decimal('1.700000'), Decimal('0.5826400000')),
#  ("Côte d'Ivoire", None, None),
#  ('Gambia', None, None),
#  ('Ghana', Decimal('70.040000'), Decimal('32.1804010000')),
#  ('Guinea', Decimal('14.180000'), Decimal('13.2051530000')),
#  ('Guinea-Bissau', Decimal('1.430000'), Decimal('2.0158280000')),
#  ('Liberia', Decimal('3.040000'), Decimal('5.0875840000')),
#  ('Mali', Decimal('17.470000'), Decimal('21.2240400000')),
#  ('Mauritania', Decimal('8.410000'), Decimal('4.4986040000')),
#  ('Niger', Decimal('13.740000'), Decimal('24.3336390000')),
#  ('Nigeria', Decimal('432.200000'), Decimal('208.3274050000')),
#  ('Saint Helena', None, None),
#  ('Senegal', Decimal('24.490000'), Decimal('16.4361200000')),
#  ('Sierra Leone', Decimal('4.060000'), Decimal('8.2339700000')),
#  ('Togo', Decimal('7.570000'), Decimal('8.4425800000'))]

# %% [markdown]
# ### Step 2️ — Filter Countries with Unemployment Rates Above 5%
# This main query lists all countries whose unemployment rate exceeds 5%, along with their GDP and population.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions,
#     Pct_unemployment
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 37 rows affected.
# [('Uzbekistan', Decimal('59.89'), Decimal('34.232050'), Decimal('5.29')),
#  ('Afghanistan', Decimal('20.14'), Decimal('38.972230'), Decimal('11.71')),
#  ('Bhutan', Decimal('2.33'), Decimal('0.772506'), Decimal('5.03')),
#  ('India', Decimal('2667.69'), Decimal('1396.387127'), Decimal('7.86')),
#  ('Sri Lanka', Decimal('85.35'), Decimal('21.919000'), Decimal('5.36')),
#  ('China', Decimal('14687.67'), Decimal('1411.100000'), Decimal('5.61')),
#  ('Mongolia', Decimal('13.31'), Decimal('3.294335'), Decimal('6.59')),
#  ('Brunei Darussalam', Decimal('12.01'), Decimal('0.441725'), Decimal('7.41')),
#  ('Canada', Decimal('1645.42'), Decimal('38.037204'), Decimal('9.46')),
#  ('Dominican Republic', Decimal('78.84'), Decimal('10.999664'), Decimal('6.13')),
#  ('Jamaica', Decimal('13.81'), Decimal('2.820436'), Decimal('6.50')),
#  ('Costa Rica', Decimal('62.16'), Decimal('5.123105'), Decimal('16.43')),
#  ('El Salvador', Decimal('24.56'), Decimal('6.292731'), Decimal('5.01')),
#  ('Honduras', Decimal('23.83'), Decimal('10.121763'), Decimal('10.68')),
#  ('Panama', Decimal('53.98'), Decimal('4.294396'), Decimal('18.55')),
#  ('Argentina', Decimal('385.54'), Decimal('45.376763'), Decimal('11.46')),
#  ('Brazil', Decimal('1448.56'), Decimal('213.196304'), Decimal('13.70')),
#  ('Chile', Decimal('252.73'), Decimal('19.300315'), Decimal('10.94')),
#  ('Colombia', Decimal('270.30'), Decimal('50.930662'), Decimal('15.98')),
#  ('Ecuador', Decimal('99.29'), Decimal('17.588595'), Decimal('6.11')),
#  ('Paraguay', Decimal('35.43'), Decimal('6.618695'), Decimal('7.55')),
#  ('Peru', Decimal('201.71'), Decimal('33.304756'), Decimal('7.18')),
#  ('Uruguay', Decimal('53.56'), Decimal('3.429086'), Decimal('10.33')),
#  ('Armenia', Decimal('12.64'), Decimal('2.805608'), Decimal('12.18')),
#  ('Azerbaijan', Decimal('42.69'), Decimal('10.093121'), Decimal('7.16')),
#  ('Cyprus', Decimal('25.01'), Decimal('1.237537'), Decimal('7.76')),
#  ('Georgia', Decimal('15.84'), Decimal('3.722716'), Decimal('11.73')),
#  ('Jordan', Decimal('44.18'), Decimal('10.928721'), Decimal('19.21')),
#  ('Saudi Arabia', Decimal('703.37'), Decimal('35.997107'), Decimal('7.66')),
#  ('Australia', Decimal('1326.90'), Decimal('25.655289'), Decimal('6.46')),
#  ('New Caledonia', Decimal('9.44'), Decimal('0.271130'), Decimal('13.56')),
#  ('Kiribati', Decimal('0.18'), Decimal('0.126463'), Decimal('10.97')),
#  ('Mauritius', Decimal('11.40'), Decimal('1.265740'), Decimal('8.63')),
#  ('Rwanda', Decimal('10.18'), Decimal('13.146362'), Decimal('11.83')),
#  ('Zambia', Decimal('18.11'), Decimal('18.927715'), Decimal('6.03')),
#  ('Botswana', Decimal('14.93'), Decimal('2.546402'), Decimal('21.02')),
#  ('South Africa', Decimal('337.62'), Decimal('58.801927'), Decimal('24.34'))]

# %% [markdown]
# ### Step 3️ — Combine Both Queries (Subquery in the FROM Clause)
# We’ll now use a subquery inside the **FROM** clause to calculate the average GDP and population
# **for countries with unemployment rates above 5%**.
#
# This subquery acts like a temporary table called `High_Unemployment`.

# %%
# %%sql
#
# SELECT
#     AVG(High_Unemployment.Est_gdp_in_billions) AS Avg_GDP_Above5,
#     AVG(High_Unemployment.Est_population_in_millions) AS Avg_Pop_Above5
# FROM
#     (
#         SELECT
#             Country_name,
#             Est_gdp_in_billions,
#             Est_population_in_millions,
#             Pct_unemployment
#         FROM
#             Economic_Indicators
#         WHERE
#             Pct_unemployment > 5
#             AND Time_period = 2020
#     ) AS High_Unemployment;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [(Decimal('669.475676'), Decimal('96.2183590811'))]

# %% [markdown]
# ##  Summary
# In this exercise, we learned how to:
# - Use a **subquery in the FROM clause** to treat a temporary result set as a table.
# - Filter data using conditions like `Pct_unemployment > 5`.
# - Compute averages efficiently using the results of a subquery.
#
# This skill allows you to write more modular and professional SQL queries — useful for analytics, reporting, and dashboards.
