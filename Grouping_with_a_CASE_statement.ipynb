# %% [markdown]
# # Grouping with a CASE Statement
#
# In this section, we’re learning how to categorize and summarize data using the `CASE` statement in SQL.
#
# By the end of this section, we will:
# - Know how to categorize data using CASE statements.
# - Combine CASE statements with aggregate functions for advanced summarization.
# - Use the `GROUP BY` clause effectively with CASE statements.
#
# We’ll be using our **Access_to_Basic_Services** table from the **united_nations** MySQL database to analyze how access to managed drinking water services varies across Africa’s Regional Economic Communities (RECs).

# %% [markdown]
# ## Connecting to our MySQL Database
#
# Let’s connect to our MySQL server using `pymysql` and the `%sql` magic command to run SQL queries directly in this notebook.

# %%
# %load_ext sql

# %% [markdown]
# ## 1. Identify Regions in Africa
#
# We’ll start by selecting only the regions that contain the word “Africa” in their name.
# This helps us isolate the African countries for our regional classification task.

# %%
# %%sql
#
# SELECT DISTINCT Region
# FROM united_nations.Access_to_Basic_Services
# WHERE Region LIKE '%Africa%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 2 rows affected.
# [('Northern Africa and Western Asia',), ('Sub-Saharan Africa',)]

# %% [markdown]
# ## 2. Classify SADC Countries
#
# Next, we’ll classify whether a country belongs to the **SADC** (Southern African Development Community).
# If the country is part of SADC, we’ll label it as `SADC`; otherwise, it will be `Not Classified`.

# %%
# %%sql
#
# SELECT
#   CASE
#     WHEN Country_name IN (
#       'Angola', 'Botswana', 'Comoros', 'Democratic Republic of Congo', 'Eswatini',
#       'Lesotho', 'Madagascar', 'Malawi', 'Mauritius', 'Mozambique',
#       'Namibia', 'Seychelles', 'South Africa', 'United Republic Tanzania', 'Zambia', 'Zimbabwe'
#     ) THEN 'SADC'
#     ELSE 'Not Classified'
#   END AS Regional_economic_community,
#   Country_name,
#   Pct_managed_drinking_water_services
# FROM united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Not Classified', 'Kazakhstan', Decimal('94.67')),
#  ('Not Classified', 'Kazakhstan', Decimal('94.67')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('89.67')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('90.33')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('91.00')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('91.33')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('91.67')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('92.67')),
#  ('Not Classified', 'Tajikistan', Decimal('80.33')),
#  ('Not Classified', 'Tajikistan', Decimal('81.33')),
#  ('Not Classified', 'Tajikistan', Decimal('82.33')),
#  ('Not Classified', 'Tajikistan', Decimal('83.33')),
#  ('Not Classified', 'Tajikistan', Decimal('85.00')),
#  ('Not Classified', 'Tajikistan', Decimal('85.00')),
#  ('Not Classified', 'Turkmenistan', Decimal('97.67')),
#  ('Not Classified', 'Turkmenistan', Decimal('98.00')),
#  ('Not Classified', 'Turkmenistan', Decimal('98.67')),
#  ('Not Classified', 'Turkmenistan', Decimal('99.33')),
#  ('Not Classified', 'Turkmenistan', Decimal('100.00')),
#  ('Not Classified', 'Turkmenistan', Decimal('100.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('97.67')),
#  ('Not Classified', 'Uzbekistan', Decimal('97.67')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Afghanistan', Decimal('67.00')),
#  ('Not Classified', 'Afghanistan', Decimal('69.67')),
#  ('Not Classified', 'Afghanistan', Decimal('72.33')),
#  ('Not Classified', 'Afghanistan', Decimal('75.33')),
#  ('Not Classified', 'Afghanistan', Decimal('78.00')),
#  ('Not Classified', 'Afghanistan', Decimal('80.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.67')),
#  ('Not Classified', 'Bangladesh', Decimal('97.67')),
#  ('Not Classified', 'Bhutan', Decimal('96.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.00')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'India', Decimal('89.00')),
#  ('Not Classified', 'India', Decimal('89.33')),
#  ('Not Classified', 'India', Decimal('90.00')),
#  ('Not Classified', 'India', Decimal('90.33')),
#  ('Not Classified', 'India', Decimal('90.67')),
#  ('Not Classified', 'India', Decimal('91.00')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('95.67')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.00')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.33')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.33')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.33')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.67')),
#  ('Not Classified', 'Maldives', Decimal('99.00')),
#  ('Not Classified', 'Maldives', Decimal('99.00')),
#  ('Not Classified', 'Maldives', Decimal('99.33')),
#  ('Not Classified', 'Maldives', Decimal('99.33')),
#  ('Not Classified', 'Maldives', Decimal('99.67')),
#  ('Not Classified', 'Maldives', Decimal('99.67')),
#  ('Not Classified', 'Nepal', Decimal('88.33')),
#  ('Not Classified', 'Nepal', Decimal('88.67')),
#  ('Not Classified', 'Nepal', Decimal('89.00')),
#  ('Not Classified', 'Nepal', Decimal('89.33')),
#  ('Not Classified', 'Nepal', Decimal('90.00')),
#  ('Not Classified', 'Nepal', Decimal('90.00')),
#  ('Not Classified', 'Pakistan', Decimal('90.00')),
#  ('Not Classified', 'Pakistan', Decimal('90.00')),
#  ('Not Classified', 'Pakistan', Decimal('90.33')),
#  ('Not Classified', 'Pakistan', Decimal('90.33')),
#  ('Not Classified', 'Pakistan', Decimal('90.33')),
#  ('Not Classified', 'Pakistan', Decimal('90.67')),
#  ('Not Classified', 'Sri Lanka', Decimal('92.00')),
#  ('Not Classified', 'Sri Lanka', Decimal('93.00')),
#  ('Not Classified', 'Sri Lanka', Decimal('93.67')),
#  ('Not Classified', 'Sri Lanka', Decimal('94.33')),
#  ('Not Classified', 'Sri Lanka', Decimal('94.33')),
#  ('Not Classified', 'Sri Lanka', Decimal('94.33')),
#  ('Not Classified', 'China', Decimal('91.33')),
#  ('Not Classified', 'China', Decimal('91.33')),
#  ('Not Classified', 'China', Decimal('92.00')),
#  ('Not Classified', 'China', Decimal('92.67')),
#  ('Not Classified', 'China', Decimal('93.33')),
#  ('Not Classified', 'China', Decimal('93.67')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('94.67')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('94.33')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('94.00')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('93.33')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('93.33')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('93.33')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Mongolia', Decimal('75.67')),
#  ('Not Classified', 'Mongolia', Decimal('77.00')),
#  ('Not Classified', 'Mongolia', Decimal('78.00')),
#  ('Not Classified', 'Mongolia', Decimal('79.00')),
#  ('Not Classified', 'Mongolia', Decimal('80.00')),
#  ('Not Classified', 'Mongolia', Decimal('81.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('99.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('99.67')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Cambodia', Decimal('73.33')),
#  ('Not Classified', 'Cambodia', Decimal('73.67')),
#  ('Not Classified', 'Cambodia', Decimal('74.33')),
#  ('Not Classified', 'Cambodia', Decimal('74.67')),
#  ('Not Classified', 'Cambodia', Decimal('75.33')),
#  ('Not Classified', 'Cambodia', Decimal('75.33')),
#  ('Not Classified', 'Indonesia', Decimal('88.33')),
#  ('Not Classified', 'Indonesia', Decimal('89.00')),
#  ('Not Classified', 'Indonesia', Decimal('89.67')),
#  ('Not Classified', 'Indonesia', Decimal('90.67')),
#  ('Not Classified', 'Indonesia', Decimal('91.33')),
#  ('Not Classified', 'Indonesia', Decimal('92.00')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('79.67')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('82.00')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('83.33')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('85.00')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('86.67')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('86.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.33')),
#  ('Not Classified', 'Malaysia', Decimal('95.33')),
#  ('Not Classified', 'Malaysia', Decimal('95.33')),
#  ('Not Classified', 'Myanmar', Decimal('76.33')),
#  ('Not Classified', 'Myanmar', Decimal('78.33')),
#  ('Not Classified', 'Myanmar', Decimal('80.33')),
#  ('Not Classified', 'Myanmar', Decimal('82.33')),
#  ('Not Classified', 'Myanmar', Decimal('84.00')),
#  ('Not Classified', 'Myanmar', Decimal('85.67')),
#  ('Not Classified', 'Philippines', Decimal('92.00')),
#  ('Not Classified', 'Philippines', Decimal('92.67')),
#  ('Not Classified', 'Philippines', Decimal('93.00')),
#  ('Not Classified', 'Philippines', Decimal('93.33')),
#  ('Not Classified', 'Philippines', Decimal('93.67')),
#  ('Not Classified', 'Philippines', Decimal('94.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('99.33')),
#  ('Not Classified', 'Thailand', Decimal('99.33')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Timor-Leste', Decimal('78.00')),
#  ('Not Classified', 'Timor-Leste', Decimal('80.67')),
#  ('Not Classified', 'Timor-Leste', Decimal('82.33')),
#  ('Not Classified', 'Timor-Leste', Decimal('84.33')),
#  ('Not Classified', 'Timor-Leste', Decimal('86.00')),
#  ('Not Classified', 'Timor-Leste', Decimal('87.00')),
#  ('Not Classified', 'Viet Nam', Decimal('94.00')),
#  ('Not Classified', 'Viet Nam', Decimal('95.00')),
#  ('Not Classified', 'Viet Nam', Decimal('95.67')),
#  ('Not Classified', 'Viet Nam', Decimal('96.33')),
#  ('Not Classified', 'Viet Nam', Decimal('96.67')),
#  ('Not Classified', 'Viet Nam', Decimal('97.33')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'United States of America', Decimal('99.00')),
#  ('Not Classified', 'United States of America', Decimal('99.33')),
#  ('Not Classified', 'United States of America', Decimal('99.67')),
#  ('Not Classified', 'United States of America', Decimal('99.67')),
#  ('Not Classified', 'United States of America', Decimal('99.67')),
#  ('Not Classified', 'United States of America', Decimal('100.00')),
#  ('Not Classified', 'Anguilla', Decimal('97.00')),
#  ('Not Classified', 'Anguilla', Decimal('97.00')),
#  ('Not Classified', 'Anguilla', Decimal('97.00')),
#  ('Not Classified', 'Antigua and Barbuda', Decimal('97.00')),
#  ('Not Classified', 'Antigua and Barbuda', Decimal('97.00')),
#  ('Not Classified', 'Antigua and Barbuda', Decimal('97.00')),
#  ('Not Classified', 'Aruba', Decimal('98.00')),
#  ('Not Classified', 'Aruba', Decimal('98.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Barbados', Decimal('98.00')),
#  ('Not Classified', 'Barbados', Decimal('98.00')),
#  ('Not Classified', 'Barbados', Decimal('98.00')),
#  ('Not Classified', 'Barbados', Decimal('99.00')),
#  ('Not Classified', 'Barbados', Decimal('99.00')),
#  ('Not Classified', 'Barbados', Decimal('99.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'Cayman Islands', Decimal('96.00')),
#  ('Not Classified', 'Cayman Islands', Decimal('96.00')),
#  ('Not Classified', 'Cuba', Decimal('94.67')),
#  ('Not Classified', 'Cuba', Decimal('95.00')),
#  ('Not Classified', 'Cuba', Decimal('95.33')),
#  ('Not Classified', 'Cuba', Decimal('96.00')),
#  ('Not Classified', 'Cuba', Decimal('96.33')),
#  ('Not Classified', 'Cuba', Decimal('96.33')),
#  ('Not Classified', 'Curaçao', Decimal('99.00')),
#  ('Not Classified', 'Curaçao', Decimal('99.00')),
#  ('Not Classified', 'Curaçao', Decimal('99.00')),
#  ('Not Classified', 'Dominica', Decimal('95.00')),
#  ('Not Classified', 'Dominica', Decimal('95.00')),
#  ('Not Classified', 'Dominica', Decimal('95.00')),
#  ('Not Classified', 'Dominican Republic', Decimal('94.33')),
#  ('Not Classified', 'Dominican Republic', Decimal('94.67')),
#  ('Not Classified', 'Dominican Republic', Decimal('94.67')),
#  ('Not Classified', 'Dominican Republic', Decimal('95.00')),
#  ('Not Classified', 'Dominican Republic', Decimal('95.00')),
#  ('Not Classified', 'Dominican Republic', Decimal('95.00')),
#  ('Not Classified', 'Grenada', Decimal('96.00')),
#  ('Not Classified', 'Grenada', Decimal('96.00')),
#  ('Not Classified', 'Grenada', Decimal('96.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Haiti', Decimal('64.00')),
#  ('Not Classified', 'Haiti', Decimal('64.33')),
#  ('Not Classified', 'Haiti', Decimal('64.33')),
#  ('Not Classified', 'Haiti', Decimal('64.67')),
#  ('Not Classified', 'Haiti', Decimal('64.67')),
#  ('Not Classified', 'Haiti', Decimal('65.00')),
#  ('Not Classified', 'Jamaica', Decimal('90.00')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('99.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Kitts and Nevis', Decimal('99.00')),
#  ('Not Classified', 'Saint Kitts and Nevis', Decimal('99.00')),
#  ('Not Classified', 'Saint Kitts and Nevis', Decimal('99.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('96.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('96.33')),
#  ('Not Classified', 'Saint Lucia', Decimal('96.33')),
#  ('Not Classified', 'Saint Lucia', Decimal('97.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('97.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('97.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Sint Maarten (Dutch part)', Decimal('95.00')),
#  ('Not Classified', 'Sint Maarten (Dutch part)', Decimal('95.00')),
#  ('Not Classified', 'Sint Maarten (Dutch part)', Decimal('95.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('98.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'Belize', Decimal('97.33')),
#  ('Not Classified', 'Belize', Decimal('97.67')),
#  ('Not Classified', 'Belize', Decimal('98.00')),
#  ('Not Classified', 'Belize', Decimal('98.33')),
#  ('Not Classified', 'Belize', Decimal('98.33')),
#  ('Not Classified', 'Belize', Decimal('98.33')),
#  ('Not Classified', 'Costa Rica', Decimal('99.00')),
#  ('Not Classified', 'Costa Rica', Decimal('99.67')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'El Salvador', Decimal('94.33')),
#  ('Not Classified', 'El Salvador', Decimal('95.33')),
#  ('Not Classified', 'El Salvador', Decimal('96.00')),
#  ('Not Classified', 'El Salvador', Decimal('97.00')),
#  ('Not Classified', 'El Salvador', Decimal('97.00')),
#  ('Not Classified', 'El Salvador', Decimal('97.00')),
#  ('Not Classified', 'Guatemala', Decimal('92.00')),
#  ('Not Classified', 'Guatemala', Decimal('92.33')),
#  ('Not Classified', 'Guatemala', Decimal('92.67')),
#  ('Not Classified', 'Guatemala', Decimal('93.00')),
#  ('Not Classified', 'Guatemala', Decimal('94.00')),
#  ('Not Classified', 'Guatemala', Decimal('94.00')),
#  ('Not Classified', 'Honduras', Decimal('92.67')),
#  ('Not Classified', 'Honduras', Decimal('93.33')),
#  ('Not Classified', 'Honduras', Decimal('93.67')),
#  ('Not Classified', 'Honduras', Decimal('94.33')),
#  ('Not Classified', 'Honduras', Decimal('94.67')),
#  ('Not Classified', 'Honduras', Decimal('95.33')),
#  ('Not Classified', 'Mexico', Decimal('96.67')),
#  ('Not Classified', 'Mexico', Decimal('97.33')),
#  ('Not Classified', 'Mexico', Decimal('98.00')),
#  ('Not Classified', 'Mexico', Decimal('98.33')),
#  ('Not Classified', 'Mexico', Decimal('98.67')),
#  ('Not Classified', 'Mexico', Decimal('99.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.00')),
#  ('Not Classified', 'Nicaragua', Decimal('79.00')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Panama', Decimal('91.67')),
#  ('Not Classified', 'Panama', Decimal('91.67')),
#  ('Not Classified', 'Panama', Decimal('92.33')),
#  ('Not Classified', 'Panama', Decimal('92.33')),
#  ('Not Classified', 'Panama', Decimal('92.67')),
#  ('Not Classified', 'Panama', Decimal('92.67')),
#  ('Not Classified', 'Argentina', Decimal('97.33')),
#  ('Not Classified', 'Argentina', Decimal('97.33')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('87.33')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('88.00')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('89.00')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('89.67')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('90.33')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('90.67')),
#  ('Not Classified', 'Brazil', Decimal('95.33')),
#  ('Not Classified', 'Brazil', Decimal('95.33')),
#  ('Not Classified', 'Brazil', Decimal('96.33')),
#  ('Not Classified', 'Brazil', Decimal('97.00')),
#  ('Not Classified', 'Brazil', Decimal('97.33')),
#  ('Not Classified', 'Brazil', Decimal('98.33')),
#  ('Not Classified', 'Chile', Decimal('99.00')),
#  ('Not Classified', 'Chile', Decimal('99.67')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Colombia', Decimal('93.00')),
#  ('Not Classified', 'Colombia', Decimal('93.67')),
#  ('Not Classified', 'Colombia', Decimal('94.00')),
#  ('Not Classified', 'Colombia', Decimal('94.00')),
#  ('Not Classified', 'Colombia', Decimal('94.33')),
#  ('Not Classified', 'Colombia', Decimal('94.67')),
#  ('Not Classified', 'Ecuador', Decimal('91.67')),
#  ('Not Classified', 'Ecuador', Decimal('92.33')),
#  ('Not Classified', 'Ecuador', Decimal('92.67')),
#  ('Not Classified', 'Ecuador', Decimal('93.33')),
#  ('Not Classified', 'Ecuador', Decimal('93.67')),
#  ('Not Classified', 'Ecuador', Decimal('94.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'Guyana', Decimal('96.00')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Paraguay', Decimal('96.33')),
#  ('Not Classified', 'Paraguay', Decimal('97.67')),
#  ('Not Classified', 'Paraguay', Decimal('99.33')),
#  ('Not Classified', 'Paraguay', Decimal('99.67')),
#  ('Not Classified', 'Paraguay', Decimal('99.67')),
#  ('Not Classified', 'Paraguay', Decimal('99.67')),
#  ('Not Classified', 'Peru', Decimal('86.00')),
#  ('Not Classified', 'Peru', Decimal('87.33')),
#  ('Not Classified', 'Peru', Decimal('87.67')),
#  ('Not Classified', 'Peru', Decimal('88.67')),
#  ('Not Classified', 'Peru', Decimal('89.33')),
#  ('Not Classified', 'Peru', Decimal('90.33')),
#  ('Not Classified', 'Suriname', Decimal('95.00')),
#  ('Not Classified', 'Suriname', Decimal('95.33')),
#  ('Not Classified', 'Suriname', Decimal('96.33')),
#  ('Not Classified', 'Suriname', Decimal('96.67')),
#  ('Not Classified', 'Suriname', Decimal('97.33')),
#  ('Not Classified', 'Suriname', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('96.67')),
#  ('Not Classified', 'Uruguay', Decimal('97.33')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('95.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Algeria', Decimal('92.00')),
#  ('Not Classified', 'Algeria', Decimal('93.00')),
#  ('Not Classified', 'Algeria', Decimal('93.00')),
#  ('Not Classified', 'Algeria', Decimal('93.00')),
#  ('Not Classified', 'Algeria', Decimal('93.33')),
#  ('Not Classified', 'Algeria', Decimal('93.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Libya', Decimal('97.00')),
#  ('Not Classified', 'Libya', Decimal('98.00')),
#  ('Not Classified', 'Libya', Decimal('99.00')),
#  ('Not Classified', 'Libya', Decimal('100.00')),
#  ('Not Classified', 'Libya', Decimal('100.00')),
#  ('Not Classified', 'Libya', Decimal('100.00')),
#  ('Not Classified', 'Morocco', Decimal('81.33')),
#  ('Not Classified', 'Morocco', Decimal('83.00')),
#  ('Not Classified', 'Morocco', Decimal('84.00')),
#  ('Not Classified', 'Morocco', Decimal('85.67')),
#  ('Not Classified', 'Morocco', Decimal('87.33')),
#  ('Not Classified', 'Morocco', Decimal('88.33')),
#  ('Not Classified', 'Sudan', Decimal('61.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Tunisia', Decimal('93.33')),
#  ('Not Classified', 'Tunisia', Decimal('93.67')),
#  ('Not Classified', 'Tunisia', Decimal('94.67')),
#  ('Not Classified', 'Tunisia', Decimal('95.67')),
#  ('Not Classified', 'Tunisia', Decimal('96.00')),
#  ('Not Classified', 'Tunisia', Decimal('97.00')),
#  ('Not Classified', 'Armenia', Decimal('99.67')),
#  ('Not Classified', 'Armenia', Decimal('99.67')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Azerbaijan', Decimal('91.67')),
#  ('Not Classified', 'Azerbaijan', Decimal('92.33')),
#  ('Not Classified', 'Azerbaijan', Decimal('93.67')),
#  ('Not Classified', 'Azerbaijan', Decimal('94.33')),
#  ('Not Classified', 'Azerbaijan', Decimal('95.00')),
#  ('Not Classified', 'Azerbaijan', Decimal('95.67')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Georgia', Decimal('95.33')),
#  ('Not Classified', 'Georgia', Decimal('96.00')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Iraq', Decimal('92.33')),
#  ('Not Classified', 'Iraq', Decimal('93.67')),
#  ('Not Classified', 'Iraq', Decimal('94.67')),
#  ('Not Classified', 'Iraq', Decimal('95.67')),
#  ('Not Classified', 'Iraq', Decimal('97.00')),
#  ('Not Classified', 'Iraq', Decimal('97.67')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Lebanon', Decimal('91.00')),
#  ('Not Classified', 'Lebanon', Decimal('92.00')),
#  ('Not Classified', 'Lebanon', Decimal('92.00')),
#  ('Not Classified', 'Lebanon', Decimal('92.00')),
#  ('Not Classified', 'Lebanon', Decimal('93.00')),
#  ('Not Classified', 'Lebanon', Decimal('93.00')),
#  ('Not Classified', 'Oman', Decimal('86.00')),
#  ('Not Classified', 'Oman', Decimal('86.67')),
#  ('Not Classified', 'Oman', Decimal('86.67')),
#  ('Not Classified', 'Oman', Decimal('87.00')),
#  ('Not Classified', 'Oman', Decimal('87.67')),
#  ('Not Classified', 'Oman', Decimal('87.67')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'State of Palestine', Decimal('96.00')),
#  ('Not Classified', 'State of Palestine', Decimal('96.67')),
#  ('Not Classified', 'State of Palestine', Decimal('97.00')),
#  ('Not Classified', 'State of Palestine', Decimal('97.00')),
#  ('Not Classified', 'State of Palestine', Decimal('97.67')),
#  ('Not Classified', 'State of Palestine', Decimal('98.33')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.33')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Türkiye', Decimal('95.67')),
#  ('Not Classified', 'Türkiye', Decimal('96.00')),
#  ('Not Classified', 'Türkiye', Decimal('96.33')),
#  ('Not Classified', 'Türkiye', Decimal('96.33')),
#  ('Not Classified', 'Türkiye', Decimal('96.67')),
#  ('Not Classified', 'Türkiye', Decimal('96.67')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'Yemen', Decimal('59.00')),
#  ('Not Classified', 'Yemen', Decimal('59.67')),
#  ('Not Classified', 'Yemen', Decimal('60.33')),
#  ('Not Classified', 'Yemen', Decimal('61.33')),
#  ('Not Classified', 'Yemen', Decimal('62.33')),
#  ('Not Classified', 'Yemen', Decimal('63.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'New Caledonia', Decimal('98.00')),
#  ('Not Classified', 'New Caledonia', Decimal('98.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'Papua New Guinea', Decimal('53.67')),
#  ('Not Classified', 'Papua New Guinea', Decimal('54.33')),
#  ('Not Classified', 'Papua New Guinea', Decimal('55.00')),
#  ('Not Classified', 'Papua New Guinea', Decimal('55.67')),
#  ('Not Classified', 'Papua New Guinea', Decimal('56.33')),
#  ('Not Classified', 'Papua New Guinea', Decimal('56.67')),
#  ('Not Classified', 'Solomon Islands', Decimal('74.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('74.00')),
#  ('Not Classified', 'Solomon Islands', Decimal('73.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('72.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('72.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('72.33')),
#  ('Not Classified', 'Vanuatu', Decimal('92.00')),
#  ('Not Classified', 'Vanuatu', Decimal('92.67')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Kiribati', Decimal('73.67')),
#  ('Not Classified', 'Kiribati', Decimal('74.33')),
#  ('Not Classified', 'Kiribati', Decimal('75.00')),
#  ('Not Classified', 'Kiribati', Decimal('75.33')),
#  ('Not Classified', 'Kiribati', Decimal('76.00')),
#  ('Not Classified', 'Kiribati', Decimal('77.00')),
#  ('Not Classified', 'Marshall Islands', Decimal('89.33')),
#  ('Not Classified', 'Marshall Islands', Decimal('89.67')),
#  ('Not Classified', 'Marshall Islands', Decimal('89.67')),
#  ('Not Classified', 'Marshall Islands', Decimal('90.00')),
#  ('Not Classified', 'Marshall Islands', Decimal('90.00')),
#  ('Not Classified', 'Marshall Islands', Decimal('90.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'Niue', Decimal('98.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Samoa', Decimal('91.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Tokelau', Decimal('99.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('99.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Burundi', Decimal('68.33')),
#  ('Not Classified', 'Burundi', Decimal('68.33')),
#  ('Not Classified', 'Burundi', Decimal('69.33')),
#  ('Not Classified', 'Burundi', Decimal('69.33')),
#  ('Not Classified', 'Burundi', Decimal('70.33')),
#  ('Not Classified', 'Burundi', Decimal('70.33')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('Not Classified', 'Djibouti', Decimal('69.67')),
#  ('Not Classified', 'Djibouti', Decimal('69.33')),
#  ('Not Classified', 'Djibouti', Decimal('69.33')),
#  ('Not Classified', 'Djibouti', Decimal('69.33')),
#  ('Not Classified', 'Djibouti', Decimal('69.00')),
#  ('Not Classified', 'Djibouti', Decimal('69.00')),
#  ('Not Classified', 'Eritrea', Decimal('56.33')),
#  ('Not Classified', 'Eritrea', Decimal('56.67')),
#  ('Not Classified', 'Ethiopia', Decimal('52.00')),
#  ('Not Classified', 'Ethiopia', Decimal('53.33')),
#  ('Not Classified', 'Ethiopia', Decimal('54.67')),
#  ('Not Classified', 'Ethiopia', Decimal('55.67')),
#  ('Not Classified', 'Ethiopia', Decimal('57.00')),
#  ('Not Classified', 'Ethiopia', Decimal('58.00')),
#  ('Not Classified', 'Kenya', Decimal('64.33')),
#  ('Not Classified', 'Kenya', Decimal('65.00')),
#  ('Not Classified', 'Kenya', Decimal('65.67')),
#  ('Not Classified', 'Kenya', Decimal('65.67')),
#  ('Not Classified', 'Kenya', Decimal('66.33')),
#  ('Not Classified', 'Kenya', Decimal('67.00')),
#  ('SADC', 'Madagascar', Decimal('53.33')),
#  ('SADC', 'Madagascar', Decimal('54.00')),
#  ('SADC', 'Madagascar', Decimal('54.67')),
#  ('SADC', 'Madagascar', Decimal('55.33')),
#  ('SADC', 'Madagascar', Decimal('56.00')),
#  ('SADC', 'Madagascar', Decimal('56.33')),
#  ('SADC', 'Malawi', Decimal('71.33')),
#  ('SADC', 'Malawi', Decimal('72.00')),
#  ('SADC', 'Malawi', Decimal('72.67')),
#  ('SADC', 'Malawi', Decimal('73.33')),
#  ('SADC', 'Malawi', Decimal('73.67')),
#  ('SADC', 'Malawi', Decimal('74.33')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('Not Classified', 'Mayotte', Decimal('97.00')),
#  ('Not Classified', 'Mayotte', Decimal('97.00')),
#  ('Not Classified', 'Mayotte', Decimal('97.00')),
#  ('Not Classified', 'Mayotte', Decimal('96.00')),
#  ('Not Classified', 'Mayotte', Decimal('96.00')),
#  ('Not Classified', 'Mayotte', Decimal('96.00')),
#  ('SADC', 'Mozambique', Decimal('55.67')),
#  ('SADC', 'Mozambique', Decimal('58.00')),
#  ('SADC', 'Mozambique', Decimal('60.00')),
#  ('SADC', 'Mozambique', Decimal('62.33')),
#  ('SADC', 'Mozambique', Decimal('64.33')),
#  ('SADC', 'Mozambique', Decimal('66.67')),
#  ('Not Classified', 'Rwanda', Decimal('63.00')),
#  ('Not Classified', 'Rwanda', Decimal('64.00')),
#  ('Not Classified', 'Rwanda', Decimal('65.00')),
#  ('Not Classified', 'Rwanda', Decimal('65.67')),
#  ('Not Classified', 'Rwanda', Decimal('66.33')),
#  ('Not Classified', 'Rwanda', Decimal('66.33')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('97.00')),
#  ('Not Classified', 'Somalia', Decimal('50.67')),
#  ('Not Classified', 'Somalia', Decimal('52.00')),
#  ('Not Classified', 'Somalia', Decimal('53.33')),
#  ('Not Classified', 'Somalia', Decimal('54.67')),
#  ('Not Classified', 'Somalia', Decimal('56.33')),
#  ('Not Classified', 'Somalia', Decimal('57.33')),
#  ('Not Classified', 'South Sudan', Decimal('46.33')),
#  ('Not Classified', 'South Sudan', Decimal('46.67')),
#  ('Not Classified', 'South Sudan', Decimal('47.00')),
#  ('Not Classified', 'South Sudan', Decimal('47.67')),
#  ('Not Classified', 'South Sudan', Decimal('48.33')),
#  ('Not Classified', 'South Sudan', Decimal('48.33')),
#  ('Not Classified', 'Uganda', Decimal('55.00')),
#  ('Not Classified', 'Uganda', Decimal('55.67')),
#  ('Not Classified', 'Uganda', Decimal('57.00')),
#  ('Not Classified', 'Uganda', Decimal('58.67')),
#  ('Not Classified', 'Uganda', Decimal('59.33')),
#  ('Not Classified', 'Uganda', Decimal('61.00')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('58.33')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('60.00')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('61.67')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('63.33')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('64.67')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('65.00')),
#  ('SADC', 'Zambia', Decimal('63.67')),
#  ('SADC', 'Zambia', Decimal('64.33')),
#  ('SADC', 'Zambia', Decimal('64.67')),
#  ('SADC', 'Zambia', Decimal('65.33')),
#  ('SADC', 'Zambia', Decimal('66.33')),
#  ('SADC', 'Zambia', Decimal('66.67')),
#  ('SADC', 'Zimbabwe', Decimal('70.00')),
#  ('SADC', 'Zimbabwe', Decimal('69.33')),
#  ('SADC', 'Zimbabwe', Decimal('69.00')),
#  ('SADC', 'Zimbabwe', Decimal('68.67')),
#  ('SADC', 'Zimbabwe', Decimal('68.33')),
#  ('SADC', 'Zimbabwe', Decimal('68.00')),
#  ('SADC', 'Angola', Decimal('50.33')),
#  ('SADC', 'Angola', Decimal('51.00')),
#  ('SADC', 'Angola', Decimal('51.33')),
#  ('SADC', 'Angola', Decimal('52.33')),
#  ('SADC', 'Angola', Decimal('52.33')),
#  ('SADC', 'Angola', Decimal('52.33')),
#  ('Not Classified', 'Cameroon', Decimal('62.67')),
#  ('Not Classified', 'Cameroon', Decimal('62.67')),
#  ('Not Classified', 'Cameroon', Decimal('63.33')),
#  ('Not Classified', 'Cameroon', Decimal('63.33')),
#  ('Not Classified', 'Cameroon', Decimal('63.33')),
#  ('Not Classified', 'Cameroon', Decimal('64.00')),
#  ('Not Classified', 'Central African Republic', Decimal('44.00')),
#  ('Not Classified', 'Central African Republic', Decimal('42.67')),
#  ('Not Classified', 'Central African Republic', Decimal('41.33')),
#  ('Not Classified', 'Central African Republic', Decimal('40.67')),
#  ('Not Classified', 'Central African Republic', Decimal('39.33')),
#  ('Not Classified', 'Central African Republic', Decimal('38.33')),
#  ('Not Classified', 'Chad', Decimal('51.67')),
#  ('Not Classified', 'Chad', Decimal('52.00')),
#  ('Not Classified', 'Chad', Decimal('52.00')),
#  ('Not Classified', 'Chad', Decimal('52.00')),
#  ('Not Classified', 'Chad', Decimal('52.33')),
#  ('Not Classified', 'Chad', Decimal('52.67')),
#  ('Not Classified', 'Congo', Decimal('66.33')),
#  ('Not Classified', 'Congo', Decimal('67.67')),
#  ('Not Classified', 'Congo', Decimal('68.67')),
#  ('Not Classified', 'Congo', Decimal('68.67')),
#  ('Not Classified', 'Congo', Decimal('69.00')),
#  ('Not Classified', 'Congo', Decimal('69.00')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('45.33')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('45.67')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('46.00')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('46.67')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('47.00')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('47.67')),
#  ('Not Classified', 'Equatorial Guinea', Decimal('57.67')),
#  ('Not Classified', 'Equatorial Guinea', Decimal('57.67')),
#  ('Not Classified', 'Equatorial Guinea', Decimal('58.00')),
#  ('Not Classified', 'Gabon', Decimal('72.00')),
#  ('Not Classified', 'Gabon', Decimal('72.33')),
#  ('Not Classified', 'Gabon', Decimal('73.00')),
#  ('Not Classified', 'Gabon', Decimal('73.00')),
#  ('Not Classified', 'Gabon', Decimal('73.33')),
#  ('Not Classified', 'Gabon', Decimal('73.33')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('76.00')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('76.67')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.00')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.00')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.33')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.33')),
#  ('SADC', 'Botswana', Decimal('85.67')),
#  ('SADC', 'Botswana', Decimal('86.67')),
#  ('SADC', 'Botswana', Decimal('87.67')),
#  ('SADC', 'Botswana', Decimal('88.33')),
#  ('SADC', 'Botswana', Decimal('89.67')),
#  ('SADC', 'Botswana', Decimal('89.67')),
#  ('SADC', 'Eswatini', Decimal('73.33')),
#  ('SADC', 'Eswatini', Decimal('74.00')),
#  ('SADC', 'Eswatini', Decimal('75.00')),
#  ('SADC', 'Eswatini', Decimal('75.67')),
#  ('SADC', 'Eswatini', Decimal('76.67')),
#  ('SADC', 'Eswatini', Decimal('76.67')),
#  ('SADC', 'Lesotho', Decimal('74.67')),
#  ('SADC', 'Lesotho', Decimal('75.00')),
#  ('SADC', 'Lesotho', Decimal('75.33')),
#  ('SADC', 'Lesotho', Decimal('76.00')),
#  ('SADC', 'Lesotho', Decimal('76.00')),
#  ('SADC', 'Lesotho', Decimal('76.33')),
#  ('SADC', 'Namibia', Decimal('83.33')),
#  ('SADC', 'Namibia', Decimal('83.00')),
#  ('SADC', 'Namibia', Decimal('83.33')),
#  ('SADC', 'Namibia', Decimal('83.67')),
#  ('SADC', 'Namibia', Decimal('83.67')),
#  ('SADC', 'Namibia', Decimal('83.67')),
#  ('SADC', 'South Africa', Decimal('90.00')),
#  ('SADC', 'South Africa', Decimal('90.33')),
#  ('SADC', 'South Africa', Decimal('91.00')),
#  ('SADC', 'South Africa', Decimal('91.33')),
#  ('SADC', 'South Africa', Decimal('91.67')),
#  ('SADC', 'South Africa', Decimal('92.00')),
#  ('Not Classified', 'Benin', Decimal('65.33')),
#  ('Not Classified', 'Benin', Decimal('65.33')),
#  ('Not Classified', 'Benin', Decimal('65.33')),
#  ('Not Classified', 'Benin', Decimal('65.67')),
#  ('Not Classified', 'Benin', Decimal('65.33')),
#  ('Not Classified', 'Benin', Decimal('65.33')),
#  ('Not Classified', 'Burkina Faso', Decimal('56.33')),
#  ('Not Classified', 'Burkina Faso', Decimal('56.00')),
#  ('Not Classified', 'Burkina Faso', Decimal('55.00')),
#  ('Not Classified', 'Burkina Faso', Decimal('54.33')),
#  ('Not Classified', 'Burkina Faso', Decimal('54.00')),
#  ('Not Classified', 'Burkina Faso', Decimal('53.33')),
#  ('Not Classified', 'Cabo Verde', Decimal('83.33')),
#  ('Not Classified', 'Cabo Verde', Decimal('84.33')),
#  ('Not Classified', 'Cabo Verde', Decimal('85.33')),
#  ('Not Classified', 'Cabo Verde', Decimal('86.00')),
#  ('Not Classified', 'Cabo Verde', Decimal('86.67')),
#  ('Not Classified', 'Cabo Verde', Decimal('87.33')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.33')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.00')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.00')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.00')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('70.67')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('70.67')),
#  ('Not Classified', 'Gambia', Decimal('78.00')),
#  ('Not Classified', 'Gambia', Decimal('78.33')),
#  ('Not Classified', 'Gambia', Decimal('78.67')),
#  ('Not Classified', 'Gambia', Decimal('78.67')),
#  ('Not Classified', 'Gambia', Decimal('79.33')),
#  ('Not Classified', 'Gambia', Decimal('79.33')),
#  ('Not Classified', 'Ghana', Decimal('79.33')),
#  ('Not Classified', 'Ghana', Decimal('80.33')),
#  ('Not Classified', 'Ghana', Decimal('81.33')),
#  ('Not Classified', 'Ghana', Decimal('82.67')),
#  ('Not Classified', 'Ghana', Decimal('83.67')),
#  ('Not Classified', 'Ghana', Decimal('84.67')),
#  ('Not Classified', 'Guinea', Decimal('67.00')),
#  ('Not Classified', 'Guinea', Decimal('67.00')),
#  ('Not Classified', 'Guinea', Decimal('67.33')),
#  ('Not Classified', 'Guinea', Decimal('67.00')),
#  ('Not Classified', 'Guinea', Decimal('67.00')),
#  ('Not Classified', 'Guinea', Decimal('67.33')),
#  ('Not Classified', 'Guinea-Bissau', Decimal('60.00')),
#  ('Not Classified', 'Guinea-Bissau', Decimal('60.33')),
#  ('Not Classified', 'Guinea-Bissau', Decimal('60.00')),
#  ('Not Classified', 'Guinea-Bissau', Decimal('60.00')),
#  ('Not Classified', 'Guinea-Bissau', Decimal('60.00')),
#  ('Not Classified', 'Guinea-Bissau', Decimal('60.00')),
#  ('Not Classified', 'Liberia', Decimal('72.67')),
#  ('Not Classified', 'Liberia', Decimal('73.00')),
#  ('Not Classified', 'Liberia', Decimal('74.00')),
#  ('Not Classified', 'Liberia', Decimal('74.00')),
#  ('Not Classified', 'Liberia', Decimal('75.00')),
#  ('Not Classified', 'Liberia', Decimal('75.00')),
#  ...]

# %% [markdown]
# ## 3. Classify UMA and ECOWAS Countries
#
# We’ll expand the CASE statement to include **UMA** (Union du Maghreb Arabe) and **ECOWAS** (Economic Community of West African States) members as well.

# %%
# %%sql
#
# SELECT
#   CASE
#     WHEN Country_name IN (
#       'Angola', 'Botswana', 'Comoros', 'Democratic Republic of Congo', 'Eswatini',
#       'Lesotho', 'Madagascar', 'Malawi', 'Mauritius', 'Mozambique',
#       'Namibia', 'Seychelles', 'South Africa', 'United Republic Tanzania', 'Zambia', 'Zimbabwe'
#     ) THEN 'SADC'
#     WHEN Country_name IN (
#       'Algeria', 'Libya', 'Mauritania', 'Morocco', 'Tunisia'
#     ) THEN 'UMA'
#     WHEN Country_name IN (
#       'Benin', 'Burkina Faso', 'Cabo Verde', 'Cote d’Ivoire', 'Gambia', 'Ghana', 'Guinea',
#       'Guinea-Bissau', 'Liberia', 'Mali', 'Niger', 'Nigeria', 'Senegal', 'Sierra Leone', 'Togo'
#     ) THEN 'ECOWAS'
#     ELSE 'Not Classified'
#   END AS Regional_economic_community,
#   Country_name,
#   Pct_managed_drinking_water_services
# FROM united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Not Classified', 'Kazakhstan', Decimal('94.67')),
#  ('Not Classified', 'Kazakhstan', Decimal('94.67')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kazakhstan', Decimal('95.00')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('89.67')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('90.33')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('91.00')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('91.33')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('91.67')),
#  ('Not Classified', 'Kyrgyzstan', Decimal('92.67')),
#  ('Not Classified', 'Tajikistan', Decimal('80.33')),
#  ('Not Classified', 'Tajikistan', Decimal('81.33')),
#  ('Not Classified', 'Tajikistan', Decimal('82.33')),
#  ('Not Classified', 'Tajikistan', Decimal('83.33')),
#  ('Not Classified', 'Tajikistan', Decimal('85.00')),
#  ('Not Classified', 'Tajikistan', Decimal('85.00')),
#  ('Not Classified', 'Turkmenistan', Decimal('97.67')),
#  ('Not Classified', 'Turkmenistan', Decimal('98.00')),
#  ('Not Classified', 'Turkmenistan', Decimal('98.67')),
#  ('Not Classified', 'Turkmenistan', Decimal('99.33')),
#  ('Not Classified', 'Turkmenistan', Decimal('100.00')),
#  ('Not Classified', 'Turkmenistan', Decimal('100.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('97.67')),
#  ('Not Classified', 'Uzbekistan', Decimal('97.67')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Uzbekistan', Decimal('98.00')),
#  ('Not Classified', 'Afghanistan', Decimal('67.00')),
#  ('Not Classified', 'Afghanistan', Decimal('69.67')),
#  ('Not Classified', 'Afghanistan', Decimal('72.33')),
#  ('Not Classified', 'Afghanistan', Decimal('75.33')),
#  ('Not Classified', 'Afghanistan', Decimal('78.00')),
#  ('Not Classified', 'Afghanistan', Decimal('80.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.33')),
#  ('Not Classified', 'Bangladesh', Decimal('97.67')),
#  ('Not Classified', 'Bangladesh', Decimal('97.67')),
#  ('Not Classified', 'Bhutan', Decimal('96.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.00')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'Bhutan', Decimal('97.33')),
#  ('Not Classified', 'India', Decimal('89.00')),
#  ('Not Classified', 'India', Decimal('89.33')),
#  ('Not Classified', 'India', Decimal('90.00')),
#  ('Not Classified', 'India', Decimal('90.33')),
#  ('Not Classified', 'India', Decimal('90.67')),
#  ('Not Classified', 'India', Decimal('91.00')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('95.67')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.00')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.33')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.33')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.33')),
#  ('Not Classified', 'Iran (Islamic Republic of)', Decimal('96.67')),
#  ('Not Classified', 'Maldives', Decimal('99.00')),
#  ('Not Classified', 'Maldives', Decimal('99.00')),
#  ('Not Classified', 'Maldives', Decimal('99.33')),
#  ('Not Classified', 'Maldives', Decimal('99.33')),
#  ('Not Classified', 'Maldives', Decimal('99.67')),
#  ('Not Classified', 'Maldives', Decimal('99.67')),
#  ('Not Classified', 'Nepal', Decimal('88.33')),
#  ('Not Classified', 'Nepal', Decimal('88.67')),
#  ('Not Classified', 'Nepal', Decimal('89.00')),
#  ('Not Classified', 'Nepal', Decimal('89.33')),
#  ('Not Classified', 'Nepal', Decimal('90.00')),
#  ('Not Classified', 'Nepal', Decimal('90.00')),
#  ('Not Classified', 'Pakistan', Decimal('90.00')),
#  ('Not Classified', 'Pakistan', Decimal('90.00')),
#  ('Not Classified', 'Pakistan', Decimal('90.33')),
#  ('Not Classified', 'Pakistan', Decimal('90.33')),
#  ('Not Classified', 'Pakistan', Decimal('90.33')),
#  ('Not Classified', 'Pakistan', Decimal('90.67')),
#  ('Not Classified', 'Sri Lanka', Decimal('92.00')),
#  ('Not Classified', 'Sri Lanka', Decimal('93.00')),
#  ('Not Classified', 'Sri Lanka', Decimal('93.67')),
#  ('Not Classified', 'Sri Lanka', Decimal('94.33')),
#  ('Not Classified', 'Sri Lanka', Decimal('94.33')),
#  ('Not Classified', 'Sri Lanka', Decimal('94.33')),
#  ('Not Classified', 'China', Decimal('91.33')),
#  ('Not Classified', 'China', Decimal('91.33')),
#  ('Not Classified', 'China', Decimal('92.00')),
#  ('Not Classified', 'China', Decimal('92.67')),
#  ('Not Classified', 'China', Decimal('93.33')),
#  ('Not Classified', 'China', Decimal('93.67')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('94.67')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('94.33')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('94.00')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('93.33')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('93.33')),
#  ('Not Classified', "Democratic People's Republic of Korea", Decimal('93.33')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Japan', Decimal('99.00')),
#  ('Not Classified', 'Mongolia', Decimal('75.67')),
#  ('Not Classified', 'Mongolia', Decimal('77.00')),
#  ('Not Classified', 'Mongolia', Decimal('78.00')),
#  ('Not Classified', 'Mongolia', Decimal('79.00')),
#  ('Not Classified', 'Mongolia', Decimal('80.00')),
#  ('Not Classified', 'Mongolia', Decimal('81.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('99.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Republic of Korea', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('99.67')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Brunei Darussalam', Decimal('100.00')),
#  ('Not Classified', 'Cambodia', Decimal('73.33')),
#  ('Not Classified', 'Cambodia', Decimal('73.67')),
#  ('Not Classified', 'Cambodia', Decimal('74.33')),
#  ('Not Classified', 'Cambodia', Decimal('74.67')),
#  ('Not Classified', 'Cambodia', Decimal('75.33')),
#  ('Not Classified', 'Cambodia', Decimal('75.33')),
#  ('Not Classified', 'Indonesia', Decimal('88.33')),
#  ('Not Classified', 'Indonesia', Decimal('89.00')),
#  ('Not Classified', 'Indonesia', Decimal('89.67')),
#  ('Not Classified', 'Indonesia', Decimal('90.67')),
#  ('Not Classified', 'Indonesia', Decimal('91.33')),
#  ('Not Classified', 'Indonesia', Decimal('92.00')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('79.67')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('82.00')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('83.33')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('85.00')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('86.67')),
#  ('Not Classified', "Lao People's Democratic Republic", Decimal('86.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.67')),
#  ('Not Classified', 'Malaysia', Decimal('95.33')),
#  ('Not Classified', 'Malaysia', Decimal('95.33')),
#  ('Not Classified', 'Malaysia', Decimal('95.33')),
#  ('Not Classified', 'Myanmar', Decimal('76.33')),
#  ('Not Classified', 'Myanmar', Decimal('78.33')),
#  ('Not Classified', 'Myanmar', Decimal('80.33')),
#  ('Not Classified', 'Myanmar', Decimal('82.33')),
#  ('Not Classified', 'Myanmar', Decimal('84.00')),
#  ('Not Classified', 'Myanmar', Decimal('85.67')),
#  ('Not Classified', 'Philippines', Decimal('92.00')),
#  ('Not Classified', 'Philippines', Decimal('92.67')),
#  ('Not Classified', 'Philippines', Decimal('93.00')),
#  ('Not Classified', 'Philippines', Decimal('93.33')),
#  ('Not Classified', 'Philippines', Decimal('93.67')),
#  ('Not Classified', 'Philippines', Decimal('94.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Singapore', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('99.33')),
#  ('Not Classified', 'Thailand', Decimal('99.33')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Thailand', Decimal('100.00')),
#  ('Not Classified', 'Timor-Leste', Decimal('78.00')),
#  ('Not Classified', 'Timor-Leste', Decimal('80.67')),
#  ('Not Classified', 'Timor-Leste', Decimal('82.33')),
#  ('Not Classified', 'Timor-Leste', Decimal('84.33')),
#  ('Not Classified', 'Timor-Leste', Decimal('86.00')),
#  ('Not Classified', 'Timor-Leste', Decimal('87.00')),
#  ('Not Classified', 'Viet Nam', Decimal('94.00')),
#  ('Not Classified', 'Viet Nam', Decimal('95.00')),
#  ('Not Classified', 'Viet Nam', Decimal('95.67')),
#  ('Not Classified', 'Viet Nam', Decimal('96.33')),
#  ('Not Classified', 'Viet Nam', Decimal('96.67')),
#  ('Not Classified', 'Viet Nam', Decimal('97.33')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Bermuda', Decimal('100.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Canada', Decimal('99.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Greenland', Decimal('100.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'Saint Pierre and Miquelon', Decimal('91.00')),
#  ('Not Classified', 'United States of America', Decimal('99.00')),
#  ('Not Classified', 'United States of America', Decimal('99.33')),
#  ('Not Classified', 'United States of America', Decimal('99.67')),
#  ('Not Classified', 'United States of America', Decimal('99.67')),
#  ('Not Classified', 'United States of America', Decimal('99.67')),
#  ('Not Classified', 'United States of America', Decimal('100.00')),
#  ('Not Classified', 'Anguilla', Decimal('97.00')),
#  ('Not Classified', 'Anguilla', Decimal('97.00')),
#  ('Not Classified', 'Anguilla', Decimal('97.00')),
#  ('Not Classified', 'Antigua and Barbuda', Decimal('97.00')),
#  ('Not Classified', 'Antigua and Barbuda', Decimal('97.00')),
#  ('Not Classified', 'Antigua and Barbuda', Decimal('97.00')),
#  ('Not Classified', 'Aruba', Decimal('98.00')),
#  ('Not Classified', 'Aruba', Decimal('98.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Bahamas', Decimal('99.00')),
#  ('Not Classified', 'Barbados', Decimal('98.00')),
#  ('Not Classified', 'Barbados', Decimal('98.00')),
#  ('Not Classified', 'Barbados', Decimal('98.00')),
#  ('Not Classified', 'Barbados', Decimal('99.00')),
#  ('Not Classified', 'Barbados', Decimal('99.00')),
#  ('Not Classified', 'Barbados', Decimal('99.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'British Virgin Islands', Decimal('100.00')),
#  ('Not Classified', 'Cayman Islands', Decimal('96.00')),
#  ('Not Classified', 'Cayman Islands', Decimal('96.00')),
#  ('Not Classified', 'Cuba', Decimal('94.67')),
#  ('Not Classified', 'Cuba', Decimal('95.00')),
#  ('Not Classified', 'Cuba', Decimal('95.33')),
#  ('Not Classified', 'Cuba', Decimal('96.00')),
#  ('Not Classified', 'Cuba', Decimal('96.33')),
#  ('Not Classified', 'Cuba', Decimal('96.33')),
#  ('Not Classified', 'Curaçao', Decimal('99.00')),
#  ('Not Classified', 'Curaçao', Decimal('99.00')),
#  ('Not Classified', 'Curaçao', Decimal('99.00')),
#  ('Not Classified', 'Dominica', Decimal('95.00')),
#  ('Not Classified', 'Dominica', Decimal('95.00')),
#  ('Not Classified', 'Dominica', Decimal('95.00')),
#  ('Not Classified', 'Dominican Republic', Decimal('94.33')),
#  ('Not Classified', 'Dominican Republic', Decimal('94.67')),
#  ('Not Classified', 'Dominican Republic', Decimal('94.67')),
#  ('Not Classified', 'Dominican Republic', Decimal('95.00')),
#  ('Not Classified', 'Dominican Republic', Decimal('95.00')),
#  ('Not Classified', 'Dominican Republic', Decimal('95.00')),
#  ('Not Classified', 'Grenada', Decimal('96.00')),
#  ('Not Classified', 'Grenada', Decimal('96.00')),
#  ('Not Classified', 'Grenada', Decimal('96.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Guadeloupe', Decimal('100.00')),
#  ('Not Classified', 'Haiti', Decimal('64.00')),
#  ('Not Classified', 'Haiti', Decimal('64.33')),
#  ('Not Classified', 'Haiti', Decimal('64.33')),
#  ('Not Classified', 'Haiti', Decimal('64.67')),
#  ('Not Classified', 'Haiti', Decimal('64.67')),
#  ('Not Classified', 'Haiti', Decimal('65.00')),
#  ('Not Classified', 'Jamaica', Decimal('90.00')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Jamaica', Decimal('90.33')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Martinique', Decimal('100.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Montserrat', Decimal('98.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('99.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Puerto Rico', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Barthélemy', Decimal('100.00')),
#  ('Not Classified', 'Saint Kitts and Nevis', Decimal('99.00')),
#  ('Not Classified', 'Saint Kitts and Nevis', Decimal('99.00')),
#  ('Not Classified', 'Saint Kitts and Nevis', Decimal('99.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('96.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('96.33')),
#  ('Not Classified', 'Saint Lucia', Decimal('96.33')),
#  ('Not Classified', 'Saint Lucia', Decimal('97.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('97.00')),
#  ('Not Classified', 'Saint Lucia', Decimal('97.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Martin (French Part)', Decimal('100.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Saint Vincent and the Grenadines', Decimal('95.00')),
#  ('Not Classified', 'Sint Maarten (Dutch part)', Decimal('95.00')),
#  ('Not Classified', 'Sint Maarten (Dutch part)', Decimal('95.00')),
#  ('Not Classified', 'Sint Maarten (Dutch part)', Decimal('95.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('98.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Trinidad and Tobago', Decimal('99.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'Turks and Caicos Islands', Decimal('94.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'United States Virgin Islands', Decimal('99.00')),
#  ('Not Classified', 'Belize', Decimal('97.33')),
#  ('Not Classified', 'Belize', Decimal('97.67')),
#  ('Not Classified', 'Belize', Decimal('98.00')),
#  ('Not Classified', 'Belize', Decimal('98.33')),
#  ('Not Classified', 'Belize', Decimal('98.33')),
#  ('Not Classified', 'Belize', Decimal('98.33')),
#  ('Not Classified', 'Costa Rica', Decimal('99.00')),
#  ('Not Classified', 'Costa Rica', Decimal('99.67')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'Costa Rica', Decimal('100.00')),
#  ('Not Classified', 'El Salvador', Decimal('94.33')),
#  ('Not Classified', 'El Salvador', Decimal('95.33')),
#  ('Not Classified', 'El Salvador', Decimal('96.00')),
#  ('Not Classified', 'El Salvador', Decimal('97.00')),
#  ('Not Classified', 'El Salvador', Decimal('97.00')),
#  ('Not Classified', 'El Salvador', Decimal('97.00')),
#  ('Not Classified', 'Guatemala', Decimal('92.00')),
#  ('Not Classified', 'Guatemala', Decimal('92.33')),
#  ('Not Classified', 'Guatemala', Decimal('92.67')),
#  ('Not Classified', 'Guatemala', Decimal('93.00')),
#  ('Not Classified', 'Guatemala', Decimal('94.00')),
#  ('Not Classified', 'Guatemala', Decimal('94.00')),
#  ('Not Classified', 'Honduras', Decimal('92.67')),
#  ('Not Classified', 'Honduras', Decimal('93.33')),
#  ('Not Classified', 'Honduras', Decimal('93.67')),
#  ('Not Classified', 'Honduras', Decimal('94.33')),
#  ('Not Classified', 'Honduras', Decimal('94.67')),
#  ('Not Classified', 'Honduras', Decimal('95.33')),
#  ('Not Classified', 'Mexico', Decimal('96.67')),
#  ('Not Classified', 'Mexico', Decimal('97.33')),
#  ('Not Classified', 'Mexico', Decimal('98.00')),
#  ('Not Classified', 'Mexico', Decimal('98.33')),
#  ('Not Classified', 'Mexico', Decimal('98.67')),
#  ('Not Classified', 'Mexico', Decimal('99.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.00')),
#  ('Not Classified', 'Nicaragua', Decimal('79.00')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Nicaragua', Decimal('79.33')),
#  ('Not Classified', 'Panama', Decimal('91.67')),
#  ('Not Classified', 'Panama', Decimal('91.67')),
#  ('Not Classified', 'Panama', Decimal('92.33')),
#  ('Not Classified', 'Panama', Decimal('92.33')),
#  ('Not Classified', 'Panama', Decimal('92.67')),
#  ('Not Classified', 'Panama', Decimal('92.67')),
#  ('Not Classified', 'Argentina', Decimal('97.33')),
#  ('Not Classified', 'Argentina', Decimal('97.33')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Argentina', Decimal('100.00')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('87.33')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('88.00')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('89.00')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('89.67')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('90.33')),
#  ('Not Classified', 'Bolivia (Plurinational State of)', Decimal('90.67')),
#  ('Not Classified', 'Brazil', Decimal('95.33')),
#  ('Not Classified', 'Brazil', Decimal('95.33')),
#  ('Not Classified', 'Brazil', Decimal('96.33')),
#  ('Not Classified', 'Brazil', Decimal('97.00')),
#  ('Not Classified', 'Brazil', Decimal('97.33')),
#  ('Not Classified', 'Brazil', Decimal('98.33')),
#  ('Not Classified', 'Chile', Decimal('99.00')),
#  ('Not Classified', 'Chile', Decimal('99.67')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Chile', Decimal('100.00')),
#  ('Not Classified', 'Colombia', Decimal('93.00')),
#  ('Not Classified', 'Colombia', Decimal('93.67')),
#  ('Not Classified', 'Colombia', Decimal('94.00')),
#  ('Not Classified', 'Colombia', Decimal('94.00')),
#  ('Not Classified', 'Colombia', Decimal('94.33')),
#  ('Not Classified', 'Colombia', Decimal('94.67')),
#  ('Not Classified', 'Ecuador', Decimal('91.67')),
#  ('Not Classified', 'Ecuador', Decimal('92.33')),
#  ('Not Classified', 'Ecuador', Decimal('92.67')),
#  ('Not Classified', 'Ecuador', Decimal('93.33')),
#  ('Not Classified', 'Ecuador', Decimal('93.67')),
#  ('Not Classified', 'Ecuador', Decimal('94.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'Falkland Islands (Malvinas)', Decimal('91.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'French Guiana', Decimal('94.00')),
#  ('Not Classified', 'Guyana', Decimal('96.00')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Guyana', Decimal('96.67')),
#  ('Not Classified', 'Paraguay', Decimal('96.33')),
#  ('Not Classified', 'Paraguay', Decimal('97.67')),
#  ('Not Classified', 'Paraguay', Decimal('99.33')),
#  ('Not Classified', 'Paraguay', Decimal('99.67')),
#  ('Not Classified', 'Paraguay', Decimal('99.67')),
#  ('Not Classified', 'Paraguay', Decimal('99.67')),
#  ('Not Classified', 'Peru', Decimal('86.00')),
#  ('Not Classified', 'Peru', Decimal('87.33')),
#  ('Not Classified', 'Peru', Decimal('87.67')),
#  ('Not Classified', 'Peru', Decimal('88.67')),
#  ('Not Classified', 'Peru', Decimal('89.33')),
#  ('Not Classified', 'Peru', Decimal('90.33')),
#  ('Not Classified', 'Suriname', Decimal('95.00')),
#  ('Not Classified', 'Suriname', Decimal('95.33')),
#  ('Not Classified', 'Suriname', Decimal('96.33')),
#  ('Not Classified', 'Suriname', Decimal('96.67')),
#  ('Not Classified', 'Suriname', Decimal('97.33')),
#  ('Not Classified', 'Suriname', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('96.67')),
#  ('Not Classified', 'Uruguay', Decimal('97.33')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Uruguay', Decimal('98.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('95.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('Not Classified', 'Venezuela (Bolivarian Republic of)', Decimal('94.00')),
#  ('UMA', 'Algeria', Decimal('92.00')),
#  ('UMA', 'Algeria', Decimal('93.00')),
#  ('UMA', 'Algeria', Decimal('93.00')),
#  ('UMA', 'Algeria', Decimal('93.00')),
#  ('UMA', 'Algeria', Decimal('93.33')),
#  ('UMA', 'Algeria', Decimal('93.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('Not Classified', 'Egypt', Decimal('99.33')),
#  ('UMA', 'Libya', Decimal('97.00')),
#  ('UMA', 'Libya', Decimal('98.00')),
#  ('UMA', 'Libya', Decimal('99.00')),
#  ('UMA', 'Libya', Decimal('100.00')),
#  ('UMA', 'Libya', Decimal('100.00')),
#  ('UMA', 'Libya', Decimal('100.00')),
#  ('UMA', 'Morocco', Decimal('81.33')),
#  ('UMA', 'Morocco', Decimal('83.00')),
#  ('UMA', 'Morocco', Decimal('84.00')),
#  ('UMA', 'Morocco', Decimal('85.67')),
#  ('UMA', 'Morocco', Decimal('87.33')),
#  ('UMA', 'Morocco', Decimal('88.33')),
#  ('Not Classified', 'Sudan', Decimal('61.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('Not Classified', 'Sudan', Decimal('62.33')),
#  ('UMA', 'Tunisia', Decimal('93.33')),
#  ('UMA', 'Tunisia', Decimal('93.67')),
#  ('UMA', 'Tunisia', Decimal('94.67')),
#  ('UMA', 'Tunisia', Decimal('95.67')),
#  ('UMA', 'Tunisia', Decimal('96.00')),
#  ('UMA', 'Tunisia', Decimal('97.00')),
#  ('Not Classified', 'Armenia', Decimal('99.67')),
#  ('Not Classified', 'Armenia', Decimal('99.67')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Armenia', Decimal('100.00')),
#  ('Not Classified', 'Azerbaijan', Decimal('91.67')),
#  ('Not Classified', 'Azerbaijan', Decimal('92.33')),
#  ('Not Classified', 'Azerbaijan', Decimal('93.67')),
#  ('Not Classified', 'Azerbaijan', Decimal('94.33')),
#  ('Not Classified', 'Azerbaijan', Decimal('95.00')),
#  ('Not Classified', 'Azerbaijan', Decimal('95.67')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Bahrain', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Cyprus', Decimal('100.00')),
#  ('Not Classified', 'Georgia', Decimal('95.33')),
#  ('Not Classified', 'Georgia', Decimal('96.00')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Georgia', Decimal('96.67')),
#  ('Not Classified', 'Iraq', Decimal('92.33')),
#  ('Not Classified', 'Iraq', Decimal('93.67')),
#  ('Not Classified', 'Iraq', Decimal('94.67')),
#  ('Not Classified', 'Iraq', Decimal('95.67')),
#  ('Not Classified', 'Iraq', Decimal('97.00')),
#  ('Not Classified', 'Iraq', Decimal('97.67')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Israel', Decimal('100.00')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Jordan', Decimal('98.33')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Kuwait', Decimal('100.00')),
#  ('Not Classified', 'Lebanon', Decimal('91.00')),
#  ('Not Classified', 'Lebanon', Decimal('92.00')),
#  ('Not Classified', 'Lebanon', Decimal('92.00')),
#  ('Not Classified', 'Lebanon', Decimal('92.00')),
#  ('Not Classified', 'Lebanon', Decimal('93.00')),
#  ('Not Classified', 'Lebanon', Decimal('93.00')),
#  ('Not Classified', 'Oman', Decimal('86.00')),
#  ('Not Classified', 'Oman', Decimal('86.67')),
#  ('Not Classified', 'Oman', Decimal('86.67')),
#  ('Not Classified', 'Oman', Decimal('87.00')),
#  ('Not Classified', 'Oman', Decimal('87.67')),
#  ('Not Classified', 'Oman', Decimal('87.67')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Qatar', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'Saudi Arabia', Decimal('100.00')),
#  ('Not Classified', 'State of Palestine', Decimal('96.00')),
#  ('Not Classified', 'State of Palestine', Decimal('96.67')),
#  ('Not Classified', 'State of Palestine', Decimal('97.00')),
#  ('Not Classified', 'State of Palestine', Decimal('97.00')),
#  ('Not Classified', 'State of Palestine', Decimal('97.67')),
#  ('Not Classified', 'State of Palestine', Decimal('98.33')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.33')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Syrian Arab Republic', Decimal('93.67')),
#  ('Not Classified', 'Türkiye', Decimal('95.67')),
#  ('Not Classified', 'Türkiye', Decimal('96.00')),
#  ('Not Classified', 'Türkiye', Decimal('96.33')),
#  ('Not Classified', 'Türkiye', Decimal('96.33')),
#  ('Not Classified', 'Türkiye', Decimal('96.67')),
#  ('Not Classified', 'Türkiye', Decimal('96.67')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'United Arab Emirates', Decimal('100.00')),
#  ('Not Classified', 'Yemen', Decimal('59.00')),
#  ('Not Classified', 'Yemen', Decimal('59.67')),
#  ('Not Classified', 'Yemen', Decimal('60.33')),
#  ('Not Classified', 'Yemen', Decimal('61.33')),
#  ('Not Classified', 'Yemen', Decimal('62.33')),
#  ('Not Classified', 'Yemen', Decimal('63.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'Australia', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'New Zealand', Decimal('100.00')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'Fiji', Decimal('93.67')),
#  ('Not Classified', 'New Caledonia', Decimal('98.00')),
#  ('Not Classified', 'New Caledonia', Decimal('98.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'New Caledonia', Decimal('99.00')),
#  ('Not Classified', 'Papua New Guinea', Decimal('53.67')),
#  ('Not Classified', 'Papua New Guinea', Decimal('54.33')),
#  ('Not Classified', 'Papua New Guinea', Decimal('55.00')),
#  ('Not Classified', 'Papua New Guinea', Decimal('55.67')),
#  ('Not Classified', 'Papua New Guinea', Decimal('56.33')),
#  ('Not Classified', 'Papua New Guinea', Decimal('56.67')),
#  ('Not Classified', 'Solomon Islands', Decimal('74.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('74.00')),
#  ('Not Classified', 'Solomon Islands', Decimal('73.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('72.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('72.33')),
#  ('Not Classified', 'Solomon Islands', Decimal('72.33')),
#  ('Not Classified', 'Vanuatu', Decimal('92.00')),
#  ('Not Classified', 'Vanuatu', Decimal('92.67')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Vanuatu', Decimal('93.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Guam', Decimal('100.00')),
#  ('Not Classified', 'Kiribati', Decimal('73.67')),
#  ('Not Classified', 'Kiribati', Decimal('74.33')),
#  ('Not Classified', 'Kiribati', Decimal('75.00')),
#  ('Not Classified', 'Kiribati', Decimal('75.33')),
#  ('Not Classified', 'Kiribati', Decimal('76.00')),
#  ('Not Classified', 'Kiribati', Decimal('77.00')),
#  ('Not Classified', 'Marshall Islands', Decimal('89.33')),
#  ('Not Classified', 'Marshall Islands', Decimal('89.67')),
#  ('Not Classified', 'Marshall Islands', Decimal('89.67')),
#  ('Not Classified', 'Marshall Islands', Decimal('90.00')),
#  ('Not Classified', 'Marshall Islands', Decimal('90.00')),
#  ('Not Classified', 'Marshall Islands', Decimal('90.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Micronesia (Federated States of)', Decimal('88.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Nauru', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Northern Mariana Islands', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'Palau', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'American Samoa', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'Cook Islands', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'French Polynesia', Decimal('100.00')),
#  ('Not Classified', 'Niue', Decimal('98.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Niue', Decimal('97.00')),
#  ('Not Classified', 'Samoa', Decimal('91.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Samoa', Decimal('92.00')),
#  ('Not Classified', 'Tokelau', Decimal('99.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tokelau', Decimal('100.00')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('98.67')),
#  ('Not Classified', 'Tonga', Decimal('99.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Tuvalu', Decimal('100.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Wallis and Futuna Islands', Decimal('99.00')),
#  ('Not Classified', 'Burundi', Decimal('68.33')),
#  ('Not Classified', 'Burundi', Decimal('68.33')),
#  ('Not Classified', 'Burundi', Decimal('69.33')),
#  ('Not Classified', 'Burundi', Decimal('69.33')),
#  ('Not Classified', 'Burundi', Decimal('70.33')),
#  ('Not Classified', 'Burundi', Decimal('70.33')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('SADC', 'Comoros', Decimal('81.67')),
#  ('Not Classified', 'Djibouti', Decimal('69.67')),
#  ('Not Classified', 'Djibouti', Decimal('69.33')),
#  ('Not Classified', 'Djibouti', Decimal('69.33')),
#  ('Not Classified', 'Djibouti', Decimal('69.33')),
#  ('Not Classified', 'Djibouti', Decimal('69.00')),
#  ('Not Classified', 'Djibouti', Decimal('69.00')),
#  ('Not Classified', 'Eritrea', Decimal('56.33')),
#  ('Not Classified', 'Eritrea', Decimal('56.67')),
#  ('Not Classified', 'Ethiopia', Decimal('52.00')),
#  ('Not Classified', 'Ethiopia', Decimal('53.33')),
#  ('Not Classified', 'Ethiopia', Decimal('54.67')),
#  ('Not Classified', 'Ethiopia', Decimal('55.67')),
#  ('Not Classified', 'Ethiopia', Decimal('57.00')),
#  ('Not Classified', 'Ethiopia', Decimal('58.00')),
#  ('Not Classified', 'Kenya', Decimal('64.33')),
#  ('Not Classified', 'Kenya', Decimal('65.00')),
#  ('Not Classified', 'Kenya', Decimal('65.67')),
#  ('Not Classified', 'Kenya', Decimal('65.67')),
#  ('Not Classified', 'Kenya', Decimal('66.33')),
#  ('Not Classified', 'Kenya', Decimal('67.00')),
#  ('SADC', 'Madagascar', Decimal('53.33')),
#  ('SADC', 'Madagascar', Decimal('54.00')),
#  ('SADC', 'Madagascar', Decimal('54.67')),
#  ('SADC', 'Madagascar', Decimal('55.33')),
#  ('SADC', 'Madagascar', Decimal('56.00')),
#  ('SADC', 'Madagascar', Decimal('56.33')),
#  ('SADC', 'Malawi', Decimal('71.33')),
#  ('SADC', 'Malawi', Decimal('72.00')),
#  ('SADC', 'Malawi', Decimal('72.67')),
#  ('SADC', 'Malawi', Decimal('73.33')),
#  ('SADC', 'Malawi', Decimal('73.67')),
#  ('SADC', 'Malawi', Decimal('74.33')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('SADC', 'Mauritius', Decimal('100.00')),
#  ('Not Classified', 'Mayotte', Decimal('97.00')),
#  ('Not Classified', 'Mayotte', Decimal('97.00')),
#  ('Not Classified', 'Mayotte', Decimal('97.00')),
#  ('Not Classified', 'Mayotte', Decimal('96.00')),
#  ('Not Classified', 'Mayotte', Decimal('96.00')),
#  ('Not Classified', 'Mayotte', Decimal('96.00')),
#  ('SADC', 'Mozambique', Decimal('55.67')),
#  ('SADC', 'Mozambique', Decimal('58.00')),
#  ('SADC', 'Mozambique', Decimal('60.00')),
#  ('SADC', 'Mozambique', Decimal('62.33')),
#  ('SADC', 'Mozambique', Decimal('64.33')),
#  ('SADC', 'Mozambique', Decimal('66.67')),
#  ('Not Classified', 'Rwanda', Decimal('63.00')),
#  ('Not Classified', 'Rwanda', Decimal('64.00')),
#  ('Not Classified', 'Rwanda', Decimal('65.00')),
#  ('Not Classified', 'Rwanda', Decimal('65.67')),
#  ('Not Classified', 'Rwanda', Decimal('66.33')),
#  ('Not Classified', 'Rwanda', Decimal('66.33')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('Not Classified', 'Réunion', Decimal('100.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('96.00')),
#  ('SADC', 'Seychelles', Decimal('97.00')),
#  ('Not Classified', 'Somalia', Decimal('50.67')),
#  ('Not Classified', 'Somalia', Decimal('52.00')),
#  ('Not Classified', 'Somalia', Decimal('53.33')),
#  ('Not Classified', 'Somalia', Decimal('54.67')),
#  ('Not Classified', 'Somalia', Decimal('56.33')),
#  ('Not Classified', 'Somalia', Decimal('57.33')),
#  ('Not Classified', 'South Sudan', Decimal('46.33')),
#  ('Not Classified', 'South Sudan', Decimal('46.67')),
#  ('Not Classified', 'South Sudan', Decimal('47.00')),
#  ('Not Classified', 'South Sudan', Decimal('47.67')),
#  ('Not Classified', 'South Sudan', Decimal('48.33')),
#  ('Not Classified', 'South Sudan', Decimal('48.33')),
#  ('Not Classified', 'Uganda', Decimal('55.00')),
#  ('Not Classified', 'Uganda', Decimal('55.67')),
#  ('Not Classified', 'Uganda', Decimal('57.00')),
#  ('Not Classified', 'Uganda', Decimal('58.67')),
#  ('Not Classified', 'Uganda', Decimal('59.33')),
#  ('Not Classified', 'Uganda', Decimal('61.00')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('58.33')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('60.00')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('61.67')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('63.33')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('64.67')),
#  ('Not Classified', 'United Republic of Tanzania', Decimal('65.00')),
#  ('SADC', 'Zambia', Decimal('63.67')),
#  ('SADC', 'Zambia', Decimal('64.33')),
#  ('SADC', 'Zambia', Decimal('64.67')),
#  ('SADC', 'Zambia', Decimal('65.33')),
#  ('SADC', 'Zambia', Decimal('66.33')),
#  ('SADC', 'Zambia', Decimal('66.67')),
#  ('SADC', 'Zimbabwe', Decimal('70.00')),
#  ('SADC', 'Zimbabwe', Decimal('69.33')),
#  ('SADC', 'Zimbabwe', Decimal('69.00')),
#  ('SADC', 'Zimbabwe', Decimal('68.67')),
#  ('SADC', 'Zimbabwe', Decimal('68.33')),
#  ('SADC', 'Zimbabwe', Decimal('68.00')),
#  ('SADC', 'Angola', Decimal('50.33')),
#  ('SADC', 'Angola', Decimal('51.00')),
#  ('SADC', 'Angola', Decimal('51.33')),
#  ('SADC', 'Angola', Decimal('52.33')),
#  ('SADC', 'Angola', Decimal('52.33')),
#  ('SADC', 'Angola', Decimal('52.33')),
#  ('Not Classified', 'Cameroon', Decimal('62.67')),
#  ('Not Classified', 'Cameroon', Decimal('62.67')),
#  ('Not Classified', 'Cameroon', Decimal('63.33')),
#  ('Not Classified', 'Cameroon', Decimal('63.33')),
#  ('Not Classified', 'Cameroon', Decimal('63.33')),
#  ('Not Classified', 'Cameroon', Decimal('64.00')),
#  ('Not Classified', 'Central African Republic', Decimal('44.00')),
#  ('Not Classified', 'Central African Republic', Decimal('42.67')),
#  ('Not Classified', 'Central African Republic', Decimal('41.33')),
#  ('Not Classified', 'Central African Republic', Decimal('40.67')),
#  ('Not Classified', 'Central African Republic', Decimal('39.33')),
#  ('Not Classified', 'Central African Republic', Decimal('38.33')),
#  ('Not Classified', 'Chad', Decimal('51.67')),
#  ('Not Classified', 'Chad', Decimal('52.00')),
#  ('Not Classified', 'Chad', Decimal('52.00')),
#  ('Not Classified', 'Chad', Decimal('52.00')),
#  ('Not Classified', 'Chad', Decimal('52.33')),
#  ('Not Classified', 'Chad', Decimal('52.67')),
#  ('Not Classified', 'Congo', Decimal('66.33')),
#  ('Not Classified', 'Congo', Decimal('67.67')),
#  ('Not Classified', 'Congo', Decimal('68.67')),
#  ('Not Classified', 'Congo', Decimal('68.67')),
#  ('Not Classified', 'Congo', Decimal('69.00')),
#  ('Not Classified', 'Congo', Decimal('69.00')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('45.33')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('45.67')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('46.00')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('46.67')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('47.00')),
#  ('Not Classified', 'Democratic Republic of the Congo', Decimal('47.67')),
#  ('Not Classified', 'Equatorial Guinea', Decimal('57.67')),
#  ('Not Classified', 'Equatorial Guinea', Decimal('57.67')),
#  ('Not Classified', 'Equatorial Guinea', Decimal('58.00')),
#  ('Not Classified', 'Gabon', Decimal('72.00')),
#  ('Not Classified', 'Gabon', Decimal('72.33')),
#  ('Not Classified', 'Gabon', Decimal('73.00')),
#  ('Not Classified', 'Gabon', Decimal('73.00')),
#  ('Not Classified', 'Gabon', Decimal('73.33')),
#  ('Not Classified', 'Gabon', Decimal('73.33')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('76.00')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('76.67')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.00')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.00')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.33')),
#  ('Not Classified', 'Sao Tome and Principe', Decimal('77.33')),
#  ('SADC', 'Botswana', Decimal('85.67')),
#  ('SADC', 'Botswana', Decimal('86.67')),
#  ('SADC', 'Botswana', Decimal('87.67')),
#  ('SADC', 'Botswana', Decimal('88.33')),
#  ('SADC', 'Botswana', Decimal('89.67')),
#  ('SADC', 'Botswana', Decimal('89.67')),
#  ('SADC', 'Eswatini', Decimal('73.33')),
#  ('SADC', 'Eswatini', Decimal('74.00')),
#  ('SADC', 'Eswatini', Decimal('75.00')),
#  ('SADC', 'Eswatini', Decimal('75.67')),
#  ('SADC', 'Eswatini', Decimal('76.67')),
#  ('SADC', 'Eswatini', Decimal('76.67')),
#  ('SADC', 'Lesotho', Decimal('74.67')),
#  ('SADC', 'Lesotho', Decimal('75.00')),
#  ('SADC', 'Lesotho', Decimal('75.33')),
#  ('SADC', 'Lesotho', Decimal('76.00')),
#  ('SADC', 'Lesotho', Decimal('76.00')),
#  ('SADC', 'Lesotho', Decimal('76.33')),
#  ('SADC', 'Namibia', Decimal('83.33')),
#  ('SADC', 'Namibia', Decimal('83.00')),
#  ('SADC', 'Namibia', Decimal('83.33')),
#  ('SADC', 'Namibia', Decimal('83.67')),
#  ('SADC', 'Namibia', Decimal('83.67')),
#  ('SADC', 'Namibia', Decimal('83.67')),
#  ('SADC', 'South Africa', Decimal('90.00')),
#  ('SADC', 'South Africa', Decimal('90.33')),
#  ('SADC', 'South Africa', Decimal('91.00')),
#  ('SADC', 'South Africa', Decimal('91.33')),
#  ('SADC', 'South Africa', Decimal('91.67')),
#  ('SADC', 'South Africa', Decimal('92.00')),
#  ('ECOWAS', 'Benin', Decimal('65.33')),
#  ('ECOWAS', 'Benin', Decimal('65.33')),
#  ('ECOWAS', 'Benin', Decimal('65.33')),
#  ('ECOWAS', 'Benin', Decimal('65.67')),
#  ('ECOWAS', 'Benin', Decimal('65.33')),
#  ('ECOWAS', 'Benin', Decimal('65.33')),
#  ('ECOWAS', 'Burkina Faso', Decimal('56.33')),
#  ('ECOWAS', 'Burkina Faso', Decimal('56.00')),
#  ('ECOWAS', 'Burkina Faso', Decimal('55.00')),
#  ('ECOWAS', 'Burkina Faso', Decimal('54.33')),
#  ('ECOWAS', 'Burkina Faso', Decimal('54.00')),
#  ('ECOWAS', 'Burkina Faso', Decimal('53.33')),
#  ('ECOWAS', 'Cabo Verde', Decimal('83.33')),
#  ('ECOWAS', 'Cabo Verde', Decimal('84.33')),
#  ('ECOWAS', 'Cabo Verde', Decimal('85.33')),
#  ('ECOWAS', 'Cabo Verde', Decimal('86.00')),
#  ('ECOWAS', 'Cabo Verde', Decimal('86.67')),
#  ('ECOWAS', 'Cabo Verde', Decimal('87.33')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.33')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.00')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.00')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('71.00')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('70.67')),
#  ('Not Classified', "Côte d'Ivoire", Decimal('70.67')),
#  ('ECOWAS', 'Gambia', Decimal('78.00')),
#  ('ECOWAS', 'Gambia', Decimal('78.33')),
#  ('ECOWAS', 'Gambia', Decimal('78.67')),
#  ('ECOWAS', 'Gambia', Decimal('78.67')),
#  ('ECOWAS', 'Gambia', Decimal('79.33')),
#  ('ECOWAS', 'Gambia', Decimal('79.33')),
#  ('ECOWAS', 'Ghana', Decimal('79.33')),
#  ('ECOWAS', 'Ghana', Decimal('80.33')),
#  ('ECOWAS', 'Ghana', Decimal('81.33')),
#  ('ECOWAS', 'Ghana', Decimal('82.67')),
#  ('ECOWAS', 'Ghana', Decimal('83.67')),
#  ('ECOWAS', 'Ghana', Decimal('84.67')),
#  ('ECOWAS', 'Guinea', Decimal('67.00')),
#  ('ECOWAS', 'Guinea', Decimal('67.00')),
#  ('ECOWAS', 'Guinea', Decimal('67.33')),
#  ('ECOWAS', 'Guinea', Decimal('67.00')),
#  ('ECOWAS', 'Guinea', Decimal('67.00')),
#  ('ECOWAS', 'Guinea', Decimal('67.33')),
#  ('ECOWAS', 'Guinea-Bissau', Decimal('60.00')),
#  ('ECOWAS', 'Guinea-Bissau', Decimal('60.33')),
#  ('ECOWAS', 'Guinea-Bissau', Decimal('60.00')),
#  ('ECOWAS', 'Guinea-Bissau', Decimal('60.00')),
#  ('ECOWAS', 'Guinea-Bissau', Decimal('60.00')),
#  ('ECOWAS', 'Guinea-Bissau', Decimal('60.00')),
#  ('ECOWAS', 'Liberia', Decimal('72.67')),
#  ('ECOWAS', 'Liberia', Decimal('73.00')),
#  ('ECOWAS', 'Liberia', Decimal('74.00')),
#  ('ECOWAS', 'Liberia', Decimal('74.00')),
#  ('ECOWAS', 'Liberia', Decimal('75.00')),
#  ('ECOWAS', 'Liberia', Decimal('75.00')),
#  ...]

# %% [markdown]
# ## 4. Calculate Minimum, Average, and Maximum Drinking Water Access per REC
#
# Finally, let’s summarize the data by REC, calculating the **minimum**, **average**, and **maximum** percentage of managed drinking water services for each group.
#
# This will help us understand disparities in access to basic services across different African regions.

# %%
# %%sql
#
# SELECT
#   CASE
#     WHEN Country_name IN (
#       'Angola', 'Botswana', 'Comoros', 'Democratic Republic of Congo', 'Eswatini',
#       'Lesotho', 'Madagascar', 'Malawi', 'Mauritius', 'Mozambique',
#       'Namibia', 'Seychelles', 'South Africa', 'United Republic Tanzania', 'Zambia', 'Zimbabwe'
#     ) THEN 'SADC'
#     WHEN Country_name IN (
#       'Algeria', 'Libya', 'Mauritania', 'Morocco', 'Tunisia'
#     ) THEN 'UMA'
#     WHEN Country_name IN (
#       'Benin', 'Burkina Faso', 'Cabo Verde', 'Cote d’Ivoire', 'Gambia', 'Ghana', 'Guinea',
#       'Guinea-Bissau', 'Liberia', 'Mali', 'Niger', 'Nigeria', 'Senegal', 'Sierra Leone', 'Togo'
#     ) THEN 'ECOWAS'
#     ELSE 'Not Classified'
#   END AS Regional_economic_community,
#   MIN(Pct_managed_drinking_water_services) AS Min_Water_Access,
#   AVG(Pct_managed_drinking_water_services) AS Avg_Water_Access,
#   MAX(Pct_managed_drinking_water_services) AS Max_Water_Access
# FROM united_nations.Access_to_Basic_Services
# GROUP BY Regional_economic_community;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 4 rows affected.
# [('Not Classified', Decimal('38.33'), Decimal('89.864108'), Decimal('100.00')),
#  ('UMA', Decimal('66.67'), Decimal('88.233000'), Decimal('100.00')),
#  ('SADC', Decimal('50.33'), Decimal('75.813049'), Decimal('100.00')),
#  ('ECOWAS', Decimal('53.33'), Decimal('70.789286'), Decimal('87.33'))]

# %% [markdown]
# ##  Summary
#
# We now have a **summarised report** by the **Regional Economic Community (REC)**, showcasing the **minimum**, **average**, and **maximum** values of *managed drinking water services* for each region.
#
# This analysis highlights how access to clean and safe drinking water varies across Africa’s major economic communities — **SADC**, **UMA**, and **ECOWAS** — as well as countries not yet classified under these groups.
#
# By combining the `CASE` statement with `GROUP BY` and aggregate functions, we’ve learned how to:
# - Categorize data dynamically based on conditions.
# - Compute summary statistics for each category.
# - Generate regional insights that can inform broader development discussions.
#
# This skill is particularly valuable in **data analysis and policymaking**, where grouping and aggregation reveal trends that raw data alone cannot show.
