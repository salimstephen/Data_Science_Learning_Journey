# %% [markdown]
# #  Subquery in the JOIN Clause
#
# In this notebook, we explore **how to use a subquery in the JOIN clause** to make SQL queries more efficient and dynamic.
#
# ### Learning Objectives
# By the end of this exercise, you will be able to:
# - Use the result set of a **subquery** in the main query by joining it to another table.
# - Perform **aggregate calculations** once and use them in another query via a **JOIN**.
# - Understand how subqueries in JOINs improve performance compared to correlated subqueries.
#
#
#
# ### Overview
# Previously, we used a **correlated subquery** to calculate each country’s land area percentage relative to its sub-region.
# However, that approach recalculated totals for every row — not very efficient.
#
# In this exercise, we’ll:
# 1. First calculate the **total land area per sub-region** (using a subquery).
# 2. Then join that result with the **Access_to_Basic_Services** table to calculate each country’s **percentage of regional land** more efficiently.
#
# We’ll be using the `Access_to_Basic_Services` table in the `united_nations` database, which contains columns such as:
# - `Region`
# - `Sub_region`
# - `Country_name`
# - `Land_area`

# %%
# %load_ext sql

# %%
# %%sql
#
# -- Step 2: Calculate the total land area for each sub-region
# -- We aggregate by Sub_region to get the total land area across all countries in that sub-region.
# SELECT
#     Sub_region,
#     SUM(Land_area) AS TotalLandArea
# FROM
#     Access_to_Basic_Services
# GROUP BY
#     Sub_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 18 rows affected.
# [('Central Asia', Decimal('22494091.00')),
#  ('Southern Asia', Decimal('28620812.47')),
#  ('Eastern Asia', Decimal('68078997.40')),
#  ('South-Eastern Asia', Decimal('23191692.00')),
#  ('Northern America', Decimal('56256564.00')),
#  ('Caribbean', Decimal('1240352.00')),
#  ('Central America', Decimal('14712480.00')),
#  ('South America', Decimal('92408352.00')),
#  ('Northern Africa', Decimal('39665646.00')),
#  ('Western Asia', Decimal('20931430.00')),
#  ('Australia and New Zealand', Decimal('47722260.00')),
#  ('Melanesia', Decimal('3177540.00')),
#  ('Micronesia', Decimal('14820.00')),
#  ('Polynesia', Decimal('43306.00')),
#  ('Eastern Africa', Decimal('35208265.46')),
#  ('Middle Africa', Decimal('23245470.00')),
#  ('Southern Africa', Decimal('15904020.00')),
#  ('Western Africa', Decimal('34413293.00'))]

# %% [markdown]
# ## 2️.  Calculate Country Land Area Percentages Using a Subquery in the JOIN Clause
#
# Now that we have the total land area per sub-region,
# we can **join** that summary back to the main table (`Access_to_Basic_Services`) to compute
# each country's percentage share of its sub-region's total land area.
#
# The **JOIN** will match records on the `Sub_region` column.

# %%
# %%sql
#
# SELECT
#     a.Country_name,
#     a.Sub_region,
#     a.Land_area,
#     (a.Land_area / b.TotalLandArea) * 100 AS Pct_of_region_land
# FROM
#     Access_to_Basic_Services AS a
# JOIN
#     (
#         SELECT
#             Sub_region,
#             SUM(Land_area) AS TotalLandArea
#         FROM
#             Access_to_Basic_Services
#         GROUP BY
#             Sub_region
#     ) AS b
# ON
#     a.Sub_region = b.Sub_region
# GROUP BY
#     a.Country_name, a.Sub_region, a.Land_area, b.TotalLandArea
# ORDER BY
#     a.Sub_region, Pct_of_region_land DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 227 rows affected.
# [('Australia', 'Australia and New Zealand', Decimal('7692020.00'), Decimal('16.118306')),
#  ('Australia', 'Australia and New Zealand', Decimal('7682300.00'), Decimal('16.097938')),
#  ('New Zealand', 'Australia and New Zealand', Decimal('263310.00'), Decimal('0.551755')),
#  ('Cuba', 'Caribbean', Decimal('104100.00'), Decimal('8.392779')),
#  ('Cuba', 'Caribbean', Decimal('104040.00'), Decimal('8.387941')),
#  ('Cuba', 'Caribbean', Decimal('103800.00'), Decimal('8.368592')),
#  ('Dominican Republic', 'Caribbean', Decimal('48310.00'), Decimal('3.894862')),
#  ('Haiti', 'Caribbean', Decimal('27560.00'), Decimal('2.221950')),
#  ('Jamaica', 'Caribbean', Decimal('10830.00'), Decimal('0.873139')),
#  ('Puerto Rico', 'Caribbean', Decimal('8870.00'), Decimal('0.715120')),
#  ('Trinidad and Tobago', 'Caribbean', Decimal('5130.00'), Decimal('0.413592')),
#  ('Turks and Caicos Islands', 'Caribbean', Decimal('950.00'), Decimal('0.076591')),
#  ('Dominica', 'Caribbean', Decimal('750.00'), Decimal('0.060467')),
#  ('Antigua and Barbuda', 'Caribbean', Decimal('440.00'), Decimal('0.035474')),
#  ('Barbados', 'Caribbean', Decimal('430.00'), Decimal('0.034668')),
#  ('Grenada', 'Caribbean', Decimal('340.00'), Decimal('0.027412')),
#  ('Cayman Islands', 'Caribbean', Decimal('240.00'), Decimal('0.019349')),
#  ('Aruba', 'Caribbean', Decimal('180.00'), Decimal('0.014512')),
#  ('British Virgin Islands', 'Caribbean', Decimal('150.00'), Decimal('0.012093')),
#  ('Sint Maarten (Dutch part)', 'Caribbean', Decimal('34.00'), Decimal('0.002741')),
#  ('United States Virgin Islands', 'Caribbean', None, None),
#  ('Guadeloupe', 'Caribbean', None, None),
#  ('Bahamas', 'Caribbean', None, None),
#  ('Anguilla', 'Caribbean', None, None),
#  ('Saint Vincent and the Grenadines', 'Caribbean', None, None),
#  ('Saint Martin (French Part)', 'Caribbean', None, None),
#  ('Curaçao', 'Caribbean', None, None),
#  ('Saint Kitts and Nevis', 'Caribbean', None, None),
#  ('Saint Barthélemy', 'Caribbean', None, None),
#  ('Montserrat', 'Caribbean', None, None),
#  ('Martinique', 'Caribbean', None, None),
#  ('Saint Lucia', 'Caribbean', None, None),
#  ('Mexico', 'Central America', Decimal('1943950.00'), Decimal('13.212932')),
#  ('Nicaragua', 'Central America', Decimal('120340.00'), Decimal('0.817945')),
#  ('Honduras', 'Central America', Decimal('111890.00'), Decimal('0.760511')),
#  ('Guatemala', 'Central America', Decimal('107160.00'), Decimal('0.728361')),
#  ('Panama', 'Central America', Decimal('74180.00'), Decimal('0.504198')),
#  ('Panama', 'Central America', Decimal('74120.00'), Decimal('0.503790')),
#  ('Costa Rica', 'Central America', Decimal('51060.00'), Decimal('0.347052')),
#  ('Belize', 'Central America', Decimal('22810.00'), Decimal('0.155038')),
#  ('El Salvador', 'Central America', Decimal('20720.00'), Decimal('0.140833')),
#  ('Kazakhstan', 'Central Asia', Decimal('2699700.00'), Decimal('12.001819')),
#  ('Turkmenistan', 'Central Asia', Decimal('469930.00'), Decimal('2.089126')),
#  ('Uzbekistan', 'Central Asia', Decimal('440650.00'), Decimal('1.958959')),
#  ('Uzbekistan', 'Central Asia', Decimal('440600.00'), Decimal('1.958737')),
#  ('Uzbekistan', 'Central Asia', Decimal('440591.00'), Decimal('1.958697')),
#  ('Uzbekistan', 'Central Asia', Decimal('440588.00'), Decimal('1.958683')),
#  ('Uzbekistan', 'Central Asia', Decimal('440587.00'), Decimal('1.958679')),
#  ('Uzbekistan', 'Central Asia', Decimal('440555.00'), Decimal('1.958537')),
#  ('Tajikistan', 'Central Asia', Decimal('138790.00'), Decimal('0.617006')),
#  ('Kyrgyzstan', 'Central Asia', None, None),
#  ('Ethiopia', 'Eastern Africa', Decimal('1128571.26'), Decimal('3.205416')),
#  ('Ethiopia', 'Eastern Africa', Decimal('1128570.86'), Decimal('3.205415')),
#  ('Ethiopia', 'Eastern Africa', Decimal('1128561.43'), Decimal('3.205388')),
#  ('Ethiopia', 'Eastern Africa', Decimal('1128558.51'), Decimal('3.205379')),
#  ('Ethiopia', 'Eastern Africa', Decimal('1128552.82'), Decimal('3.205363')),
#  ('Ethiopia', 'Eastern Africa', Decimal('1128539.35'), Decimal('3.205325')),
#  ('Mozambique', 'Eastern Africa', Decimal('786380.00'), Decimal('2.233510')),
#  ('Zambia', 'Eastern Africa', Decimal('743390.00'), Decimal('2.111408')),
#  ('South Sudan', 'Eastern Africa', Decimal('631930.00'), Decimal('1.794834')),
#  ('Somalia', 'Eastern Africa', Decimal('627340.00'), Decimal('1.781798')),
#  ('Madagascar', 'Eastern Africa', Decimal('581800.00'), Decimal('1.652453')),
#  ('Kenya', 'Eastern Africa', Decimal('569140.00'), Decimal('1.616495')),
#  ('Zimbabwe', 'Eastern Africa', Decimal('386850.00'), Decimal('1.098748')),
#  ('Uganda', 'Eastern Africa', Decimal('200520.00'), Decimal('0.569525')),
#  ('Eritrea', 'Eastern Africa', Decimal('121088.77'), Decimal('0.343921')),
#  ('Eritrea', 'Eastern Africa', Decimal('121077.46'), Decimal('0.343889')),
#  ('Malawi', 'Eastern Africa', Decimal('94280.00'), Decimal('0.267778')),
#  ('Burundi', 'Eastern Africa', Decimal('25680.00'), Decimal('0.072937')),
#  ('Rwanda', 'Eastern Africa', Decimal('24670.00'), Decimal('0.070069')),
#  ('Djibouti', 'Eastern Africa', Decimal('23180.00'), Decimal('0.065837')),
#  ('Mauritius', 'Eastern Africa', Decimal('2030.00'), Decimal('0.005766')),
#  ('Comoros', 'Eastern Africa', Decimal('1861.00'), Decimal('0.005286')),
#  ('Seychelles', 'Eastern Africa', Decimal('460.00'), Decimal('0.001307')),
#  ('Mayotte', 'Eastern Africa', None, None),
#  ('Réunion', 'Eastern Africa', None, None),
#  ('United Republic of Tanzania', 'Eastern Africa', None, None),
#  ('China', 'Eastern Asia', Decimal('9424702.90'), Decimal('13.843775')),
#  ('China', 'Eastern Asia', Decimal('9424701.40'), Decimal('13.843772')),
#  ('China', 'Eastern Asia', Decimal('9424700.50'), Decimal('13.843771')),
#  ('China', 'Eastern Asia', Decimal('9424700.80'), Decimal('13.843771')),
#  ('Mongolia', 'Eastern Asia', Decimal('1557506.80'), Decimal('2.287793')),
#  ('Mongolia', 'Eastern Asia', Decimal('1557258.00'), Decimal('2.287428')),
#  ('Mongolia', 'Eastern Asia', Decimal('1557255.00'), Decimal('2.287424')),
#  ('Mongolia', 'Eastern Asia', Decimal('1557255.40'), Decimal('2.287424')),
#  ('Japan', 'Eastern Asia', Decimal('364500.00'), Decimal('0.535407')),
#  ('Republic of Korea', 'Eastern Asia', None, None),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', None, None),
#  ('Papua New Guinea', 'Melanesia', Decimal('452860.00'), Decimal('14.251906')),
#  ('Solomon Islands', 'Melanesia', Decimal('27990.00'), Decimal('0.880870')),
#  ('New Caledonia', 'Melanesia', Decimal('18280.00'), Decimal('0.575288')),
#  ('Fiji', 'Melanesia', Decimal('18270.00'), Decimal('0.574973')),
#  ('Vanuatu', 'Melanesia', Decimal('12190.00'), Decimal('0.383630')),
#  ('Kiribati', 'Micronesia', Decimal('810.00'), Decimal('5.465587')),
#  ('Guam', 'Micronesia', Decimal('540.00'), Decimal('3.643725')),
#  ('Northern Mariana Islands', 'Micronesia', Decimal('460.00'), Decimal('3.103914')),
#  ('Palau', 'Micronesia', Decimal('460.00'), Decimal('3.103914')),
#  ('Marshall Islands', 'Micronesia', Decimal('180.00'), Decimal('1.214575')),
#  ('Nauru', 'Micronesia', Decimal('20.00'), Decimal('0.134953')),
#  ('Micronesia (Federated States of)', 'Micronesia', None, None),
#  ('Chad', 'Middle Africa', Decimal('1259200.00'), Decimal('5.416969')),
#  ('Angola', 'Middle Africa', Decimal('1246700.00'), Decimal('5.363195')),
#  ('Central African Republic', 'Middle Africa', Decimal('622980.00'), Decimal('2.680006')),
#  ('Cameroon', 'Middle Africa', Decimal('472710.00'), Decimal('2.033558')),
#  ('Gabon', 'Middle Africa', Decimal('257670.00'), Decimal('1.108474')),
#  ('Equatorial Guinea', 'Middle Africa', Decimal('28050.00'), Decimal('0.120669')),
#  ('Sao Tome and Principe', 'Middle Africa', Decimal('960.00'), Decimal('0.004130')),
#  ('Democratic Republic of the Congo', 'Middle Africa', None, None),
#  ('Congo', 'Middle Africa', None, None),
#  ('Algeria', 'Northern Africa', Decimal('2381741.00'), Decimal('6.004544')),
#  ('Sudan', 'Northern Africa', Decimal('1868000.00'), Decimal('4.709365')),
#  ('Libya', 'Northern Africa', Decimal('1759540.00'), Decimal('4.435929')),
#  ('Morocco', 'Northern Africa', Decimal('446300.00'), Decimal('1.125155')),
#  ('Tunisia', 'Northern Africa', Decimal('155360.00'), Decimal('0.391674')),
#  ('Egypt', 'Northern Africa', None, None),
#  ('Canada', 'Northern America', Decimal('8965590.00'), Decimal('15.936967')),
#  ('Greenland', 'Northern America', Decimal('410450.00'), Decimal('0.729604')),
#  ('Bermuda', 'Northern America', Decimal('54.00'), Decimal('0.000096')),
#  ('United States of America', 'Northern America', None, None),
#  ('Saint Pierre and Miquelon', 'Northern America', None, None),
#  ('French Polynesia', 'Polynesia', Decimal('3471.00'), Decimal('8.015056')),
#  ('Samoa', 'Polynesia', Decimal('2830.00'), Decimal('6.534891')),
#  ('Samoa', 'Polynesia', Decimal('2780.00'), Decimal('6.419434')),
#  ('Tonga', 'Polynesia', Decimal('720.00'), Decimal('1.662587')),
#  ('American Samoa', 'Polynesia', Decimal('200.00'), Decimal('0.461830')),
#  ('Tuvalu', 'Polynesia', Decimal('30.00'), Decimal('0.069274')),
#  ('Niue', 'Polynesia', None, None),
#  ('Tokelau', 'Polynesia', None, None),
#  ('Wallis and Futuna Islands', 'Polynesia', None, None),
#  ('Cook Islands', 'Polynesia', None, None),
#  ('Brazil', 'South America', Decimal('8358140.00'), Decimal('9.044789')),
#  ('Argentina', 'South America', Decimal('2736690.00'), Decimal('2.961518')),
#  ('Peru', 'South America', Decimal('1280000.00'), Decimal('1.385156')),
#  ('Colombia', 'South America', Decimal('1109500.00'), Decimal('1.200649')),
#  ('Chile', 'South America', Decimal('743532.00'), Decimal('0.804616')),
#  ('Paraguay', 'South America', Decimal('397300.00'), Decimal('0.429939')),
#  ('Ecuador', 'South America', Decimal('248360.00'), Decimal('0.268764')),
#  ('Guyana', 'South America', Decimal('196850.00'), Decimal('0.213022')),
#  ('Uruguay', 'South America', Decimal('175020.00'), Decimal('0.189398')),
#  ('Suriname', 'South America', Decimal('156000.00'), Decimal('0.168816')),
#  ('Bolivia (Plurinational State of)', 'South America', None, None),
#  ('Falkland Islands (Malvinas)', 'South America', None, None),
#  ('Venezuela (Bolivarian Republic of)', 'South America', None, None),
#  ('French Guiana', 'South America', None, None),
#  ('Indonesia', 'South-Eastern Asia', Decimal('1877519.00'), Decimal('8.095653')),
#  ('Myanmar', 'South-Eastern Asia', Decimal('653080.00'), Decimal('2.816008')),
#  ('Myanmar', 'South-Eastern Asia', Decimal('652780.00'), Decimal('2.814715')),
#  ('Myanmar', 'South-Eastern Asia', Decimal('652750.00'), Decimal('2.814585')),
#  ('Myanmar', 'South-Eastern Asia', Decimal('652700.00'), Decimal('2.814370')),
#  ('Myanmar', 'South-Eastern Asia', Decimal('652670.00'), Decimal('2.814241')),
#  ('Thailand', 'South-Eastern Asia', Decimal('510890.00'), Decimal('2.202901')),
#  ('Malaysia', 'South-Eastern Asia', Decimal('328550.00'), Decimal('1.416671')),
#  ('Philippines', 'South-Eastern Asia', Decimal('298170.00'), Decimal('1.285676')),
#  ('Cambodia', 'South-Eastern Asia', Decimal('176520.00'), Decimal('0.761135')),
#  ('Timor-Leste', 'South-Eastern Asia', Decimal('14870.00'), Decimal('0.064118')),
#  ('Brunei Darussalam', 'South-Eastern Asia', Decimal('5270.00'), Decimal('0.022724')),
#  ('Singapore', 'South-Eastern Asia', Decimal('718.00'), Decimal('0.003096')),
#  ('Singapore', 'South-Eastern Asia', Decimal('716.00'), Decimal('0.003087')),
#  ('Singapore', 'South-Eastern Asia', Decimal('714.00'), Decimal('0.003079')),
#  ('Singapore', 'South-Eastern Asia', Decimal('712.00'), Decimal('0.003070')),
#  ('Singapore', 'South-Eastern Asia', Decimal('709.00'), Decimal('0.003057')),
#  ("Lao People's Democratic Republic", 'South-Eastern Asia', None, None),
#  ('Viet Nam', 'South-Eastern Asia', None, None),
#  ('South Africa', 'Southern Africa', Decimal('1213090.00'), Decimal('7.627568')),
#  ('Namibia', 'Southern Africa', Decimal('823290.00'), Decimal('5.176616')),
#  ('Botswana', 'Southern Africa', Decimal('566730.00'), Decimal('3.563439')),
#  ('Lesotho', 'Southern Africa', Decimal('30360.00'), Decimal('0.190895')),
#  ('Eswatini', 'Southern Africa', Decimal('17200.00'), Decimal('0.108149')),
#  ('India', 'Southern Asia', Decimal('2973190.00'), Decimal('10.388210')),
#  ('Pakistan', 'Southern Asia', Decimal('770880.00'), Decimal('2.693425')),
#  ('Afghanistan', 'Southern Asia', Decimal('652230.00'), Decimal('2.278866')),
#  ('Nepal', 'Southern Asia', Decimal('143350.00'), Decimal('0.500859')),
#  ('Bangladesh', 'Southern Asia', Decimal('130170.00'), Decimal('0.454809')),
#  ('Sri Lanka', 'Southern Asia', Decimal('61893.00'), Decimal('0.216252')),
#  ('Sri Lanka', 'Southern Asia', Decimal('61864.47'), Decimal('0.216152')),
#  ('Sri Lanka', 'Southern Asia', Decimal('61864.00'), Decimal('0.216150')),
#  ('Sri Lanka', 'Southern Asia', Decimal('61860.00'), Decimal('0.216136')),
#  ('Bhutan', 'Southern Asia', Decimal('38144.00'), Decimal('0.133274')),
#  ('Bhutan', 'Southern Asia', Decimal('38140.00'), Decimal('0.133260')),
#  ('Bhutan', 'Southern Asia', Decimal('38117.00'), Decimal('0.133179')),
#  ('Maldives', 'Southern Asia', Decimal('300.00'), Decimal('0.001048')),
#  ('Iran (Islamic Republic of)', 'Southern Asia', None, None),
#  ('Niger', 'Western Africa', Decimal('1266700.00'), Decimal('3.680845')),
#  ('Mali', 'Western Africa', Decimal('1220190.00'), Decimal('3.545694')),
#  ('Mauritania', 'Western Africa', Decimal('1030700.00'), Decimal('2.995064')),
#  ('Nigeria', 'Western Africa', Decimal('910770.00'), Decimal('2.646565')),
#  ('Burkina Faso', 'Western Africa', Decimal('273600.00'), Decimal('0.795042')),
#  ('Guinea', 'Western Africa', Decimal('245720.00'), Decimal('0.714026')),
#  ('Ghana', 'Western Africa', Decimal('227540.00'), Decimal('0.661198')),
#  ('Ghana', 'Western Africa', Decimal('227533.00'), Decimal('0.661178')),
#  ('Senegal', 'Western Africa', Decimal('192530.00'), Decimal('0.559464')),
#  ('Benin', 'Western Africa', Decimal('112760.00'), Decimal('0.327664')),
#  ('Liberia', 'Western Africa', Decimal('96320.00'), Decimal('0.279892')),
#  ('Sierra Leone', 'Western Africa', Decimal('72180.00'), Decimal('0.209745')),
#  ('Togo', 'Western Africa', Decimal('54390.00'), Decimal('0.158049')),
#  ('Guinea-Bissau', 'Western Africa', Decimal('28120.00'), Decimal('0.081713')),
#  ('Cabo Verde', 'Western Africa', Decimal('4030.00'), Decimal('0.011711')),
#  ('Gambia', 'Western Africa', None, None),
#  ('Saint Helena', 'Western Africa', None, None),
#  ("Côte d'Ivoire", 'Western Africa', None, None),
#  ('Saudi Arabia', 'Western Asia', Decimal('2149690.00'), Decimal('10.270154')),
#  ('Iraq', 'Western Asia', Decimal('434128.00'), Decimal('2.074048')),
#  ('Oman', 'Western Asia', Decimal('309500.00'), Decimal('1.478638')),
#  ('Syrian Arab Republic', 'Western Asia', Decimal('183630.00'), Decimal('0.877293')),
#  ('Jordan', 'Western Asia', Decimal('88794.00'), Decimal('0.424214')),
#  ('Jordan', 'Western Asia', Decimal('88780.00'), Decimal('0.424147')),
#  ('Azerbaijan', 'Western Asia', Decimal('82670.00'), Decimal('0.394956')),
#  ('Azerbaijan', 'Western Asia', Decimal('82663.00'), Decimal('0.394923')),
#  ('Azerbaijan', 'Western Asia', Decimal('82662.00'), Decimal('0.394918')),
#  ('Azerbaijan', 'Western Asia', Decimal('82654.00'), Decimal('0.394880')),
#  ('Azerbaijan', 'Western Asia', Decimal('82646.00'), Decimal('0.394842')),
#  ('United Arab Emirates', 'Western Asia', Decimal('71020.00'), Decimal('0.339298')),
#  ('Georgia', 'Western Asia', Decimal('69490.00'), Decimal('0.331989')),
#  ('Armenia', 'Western Asia', Decimal('28470.00'), Decimal('0.136016')),
#  ('Israel', 'Western Asia', Decimal('21640.00'), Decimal('0.103385')),
#  ('Kuwait', 'Western Asia', Decimal('17820.00'), Decimal('0.085135')),
#  ('Qatar', 'Western Asia', Decimal('11490.00'), Decimal('0.054894')),
#  ('Lebanon', 'Western Asia', Decimal('10230.00'), Decimal('0.048874')),
#  ('Cyprus', 'Western Asia', Decimal('9240.00'), Decimal('0.044144')),
#  ('Bahrain', 'Western Asia', Decimal('785.00'), Decimal('0.003750')),
#  ('Bahrain', 'Western Asia', Decimal('783.00'), Decimal('0.003741')),
#  ('Bahrain', 'Western Asia', Decimal('780.00'), Decimal('0.003726')),
#  ('Bahrain', 'Western Asia', Decimal('779.00'), Decimal('0.003722')),
#  ('Bahrain', 'Western Asia', Decimal('778.00'), Decimal('0.003717')),
#  ('Yemen', 'Western Asia', None, None),
#  ('Türkiye', 'Western Asia', None, None),
#  ('State of Palestine', 'Western Asia', None, None)]

# %% [markdown]
# ##  Summary
#
#  In this notebook, we learned how to:
# - Use a **subquery inside a JOIN** to make queries more efficient.
# - Avoid recalculating aggregates for every row (as with correlated subqueries).
# - Combine results dynamically by joining on shared columns.
#
#  The result shows each country’s **land area** and **percentage contribution** to its sub-region’s total — calculated once, cleanly, and efficiently.
